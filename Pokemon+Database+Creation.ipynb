# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

pw = "[PASSWORD REMOVED FOR SECURITY]"
db = "pokemondb"

# %%
def create_server_connection(host_name, user_name, user_password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# %%
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password,
            database=db_name
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query successful")
    except Error as err:
        print(f"Error: '{err}'")

# %%
#this is how you actually read data
def read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as err:
        print(f"Error: '{err}'")

# %%
create_pokemon_table = """
CREATE TABLE pokemon(
id INT PRIMARY KEY, 
pokedex_number INT, 
name VARCHAR(40), 
german_name VARCHAR(40), 
japanese_name VARCHAR(40), 
generation INT, 
status VARCHAR(40),
species VARCHAR(40),
type_number INT,
type_1 VARCHAR(20),
type_2 VARCHAR(20),
height_m INT,
weight_kg INT,
abilities_number INT,
ability_1 VARCHAR(40),
ability_2 VARCHAR(40),
ability_hidden VARCHAR(40),
total_points INT,
hp INT,
attack INT,
defense INT,
sp_attack INT,
sp_defense INT,
speed INT,
catch_rate INT,
base_friendship INT,
base_experience INT,
growth_rate VARCHAR(40),
egg_type_number INT,
egg_type_1 VARCHAR(40),
egg_type_2 VARCHAR(40),
percentage_male INT,
egg_cycles INT,
against_normal INT,
against_fire INT,
against_water INT,
against_electric INT,
against_grass INT,
against_ice INT,
against_fight INT,
against_poison INT,
against_ground INT,
against_flying INT,
against_psychic INT,
against_bug INT,
against_rock INT,
against_ghost INT,
against_dragon INT,
against_dark INT,
against_steel INT,
against_fairy INT
);
"""

create_move_table = """
CREATE TABLE move(
id INT PRIMARY KEY,
move VARCHAR(40),
description VARCHAR(200),
type VARCHAR(30),
category VARCHAR(20),
power INT,
accuracy INT,
pp INT,
z_effect VARCHAR(100),
priority INT,
crit INT
);
"""

create_moveset_table = """
CREATE TABLE moveset(
id INT PRIMARY KEY,
ndex INT,
species VARCHAR(40),
forme VARCHAR(40),
move1 VARCHAR(40),
move2 VARCHAR(40),
move3 VARCHAR(40),
move4 VARCHAR(40),
move5 VARCHAR(40),
move6 VARCHAR(40),
move7 VARCHAR(40),
move8 VARCHAR(40),
move9 VARCHAR(40),
move10 VARCHAR(40),
move11 VARCHAR(40),
move12 VARCHAR(40),
move13 VARCHAR(40),
move14 VARCHAR(40),
move15 VARCHAR(40),
move16 VARCHAR(40),
move17 VARCHAR(40),
move18 VARCHAR(40),
move19 VARCHAR(40),
move20 VARCHAR(40),
move21 VARCHAR(40),
move22 VARCHAR(40),
move23 VARCHAR(40),
move24 VARCHAR(40),
move25 VARCHAR(40),
move26 VARCHAR(40),
move27 VARCHAR(40),
move28 VARCHAR(40),
move29 VARCHAR(40),
move30 VARCHAR(40),
move31 VARCHAR(40),
move32 VARCHAR(40),
move33 VARCHAR(40),
move34 VARCHAR(40),
move35 VARCHAR(40),
move36 VARCHAR(40),
move37 VARCHAR(40),
move38 VARCHAR(40),
move39 VARCHAR(40),
move40 VARCHAR(40),
move41 VARCHAR(40),
move42 VARCHAR(40),
move43 VARCHAR(40),
move44 VARCHAR(40),
move45 VARCHAR(40),
move46 VARCHAR(40),
move47 VARCHAR(40),
move48 VARCHAR(40),
move49 VARCHAR(40),
move50 VARCHAR(40),
move51 VARCHAR(40),
move52 VARCHAR(40),
move53 VARCHAR(40),
move54 VARCHAR(40),
move55 VARCHAR(40),
move56 VARCHAR(40),
move57 VARCHAR(40),
move58 VARCHAR(40),
move59 VARCHAR(40),
move60 VARCHAR(40),
move61 VARCHAR(40),
move62 VARCHAR(40),
move63 VARCHAR(40),
move64 VARCHAR(40),
move65 VARCHAR(40),
move66 VARCHAR(40),
move67 VARCHAR(40),
move68 VARCHAR(40),
move69 VARCHAR(40),
move70 VARCHAR(40),
move71 VARCHAR(40),
move72 VARCHAR(40),
move73 VARCHAR(40),
move74 VARCHAR(40),
move75 VARCHAR(40),
move76 VARCHAR(40),
move77 VARCHAR(40),
move78 VARCHAR(40),
move79 VARCHAR(40),
move80 VARCHAR(40),
move81 VARCHAR(40),
move82 VARCHAR(40),
move83 VARCHAR(40),
move84 VARCHAR(40),
move85 VARCHAR(40),
move86 VARCHAR(40),
move87 VARCHAR(40),
move88 VARCHAR(40),
move89 VARCHAR(40),
move90 VARCHAR(40),
move91 VARCHAR(40),
move92 VARCHAR(40),
move93 VARCHAR(40),
move94 VARCHAR(40),
move95 VARCHAR(40),
move96 VARCHAR(40),
move97 VARCHAR(40),
move98 VARCHAR(40),
move99 VARCHAR(40),
move100 VARCHAR(40),
move101 VARCHAR(40),
move102 VARCHAR(40),
move103 VARCHAR(40),
move104 VARCHAR(40),
move105 VARCHAR(40),
move106 VARCHAR(40),
move107 VARCHAR(40),
move108 VARCHAR(40),
move109 VARCHAR(40),
move110 VARCHAR(40),
move111 VARCHAR(40),
move112 VARCHAR(40),
move113 VARCHAR(40),
move114 VARCHAR(40),
move115 VARCHAR(40),
move116 VARCHAR(40),
move117 VARCHAR(40),
move118 VARCHAR(40),
move119 VARCHAR(40),
move120 VARCHAR(40),
move121 VARCHAR(40),
move122 VARCHAR(40),
move123 VARCHAR(40),
move124 VARCHAR(40),
move125 VARCHAR(40),
move126 VARCHAR(40),
move127 VARCHAR(40),
move128 VARCHAR(40),
move129 VARCHAR(40),
move130 VARCHAR(40),
move131 VARCHAR(40),
move132 VARCHAR(40),
move133 VARCHAR(40),
move134 VARCHAR(40),
move135 VARCHAR(40),
move136 VARCHAR(40),
move137 VARCHAR(40),
move138 VARCHAR(40),
move139 VARCHAR(40),
move140 VARCHAR(40),
move141 VARCHAR(40),
move142 VARCHAR(40),
move143 VARCHAR(40),
move144 VARCHAR(40),
move145 VARCHAR(40),
move146 VARCHAR(40),
move147 VARCHAR(40),
move148 VARCHAR(40),
move149 VARCHAR(40),
move150 VARCHAR(40),
move151 VARCHAR(40),
move152 VARCHAR(40),
move153 VARCHAR(40),
move154 VARCHAR(40),
move155 VARCHAR(40),
move156 VARCHAR(40),
move157 VARCHAR(40),
move158 VARCHAR(40),
move159 VARCHAR(40),
move160 VARCHAR(40),
move161 VARCHAR(40),
move162 VARCHAR(40),
move163 VARCHAR(40),
move164 VARCHAR(40),
move165 VARCHAR(40),
move166 VARCHAR(40),
move167 VARCHAR(40),
move168 VARCHAR(40),
move169 VARCHAR(40),
move170 VARCHAR(40),
move171 VARCHAR(40),
move172 VARCHAR(40),
move173 VARCHAR(40),
move174 VARCHAR(40)
);
"""

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database

execute_query(connection, create_pokemon_table) # Execute our defined query

execute_query(connection, create_moveset_table)

execute_query(connection, create_move_table)

# %% [markdown]
# ### My database is now running on my local computer. Now to clean and process some data.

# %%
#create pokemon dataframe using Pandas' read_csv method
#got this CSV from the internet
pokemondf = pd.read_csv("pokedex.csv")

#This csv came with its own index, so set that to the dataframe's index
pokemondf.set_index("id", inplace = True)
pokemondf
# Out:
#       pokedex_number                            name german_name  \
# id
# 0                  1                       Bulbasaur     Bisasam
# 1                  2                         Ivysaur   Bisaknosp
# 2                  3                        Venusaur    Bisaflor
# 3                  3                   Mega Venusaur    Bisaflor
# 4                  4                      Charmander    Glumanda
# 5                  5                      Charmeleon     Glutexo
# 6                  6                       Charizard      Glurak
# 7                  6                Mega Charizard X      Glurak
# 8                  6                Mega Charizard Y      Glurak
# 9                  7                        Squirtle     Schiggy
# 10                 8                       Wartortle    Schillok
# 11                 9                       Blastoise      Turtok
# 12                 9                  Mega Blastoise      Turtok
# ...

# %%
#create moves dataframe
movesdf = pd.read_csv("moves.csv")

#again this data came with its own index
movesdf.set_index("id", inplace = True)


#create movesets dataframe
movesetsdf = pd.read_csv("movesets.csv")
#moveset's index needed to be renamed to "id" to work with the MySQL table already amde
movesetsdf.index.name = "id"

# %% [markdown]
# ### Now need SQLAlchemy to speed up the transfering of the dataframes to SQL code

# %%
import sqlalchemy

# import the module
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = sqlalchemy.create_engine(
    'mysql+mysqlconnector://root:Dollardollarbillyall@localhost:3306/pokemondb')

# %%
# Insert whole pokemon DataFrame into MySQL
pokemondf.to_sql('pokemon', con = engine, if_exists = 'append', chunksize = 1000)

# Insert whole moveset DataFrame into MySQL
movesetsdf.to_sql('moveset', con = engine, if_exists = 'append', chunksize = 1000)

# Insert whole move DataFrame into MySQL
movesdf.to_sql('move', con = engine, if_exists = 'append', chunksize = 1000)

# %% [markdown]
# ### And now the data in my database is ready to be analyzed!
