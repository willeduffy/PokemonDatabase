# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import numpy as np

pw = "Dollardollarbillyall"
db = "pokemondb"

# %%
def create_server_connection(host_name, user_name, user_password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# %%
connection = create_server_connection("localhost", "root", pw)

cursor.close() 

cursor = connection.cursor()
# Out:
# MySQL Database connection successful

# %%
def create_database(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        print("Database created successfully")
    except Error as err:
        print(f"Error: '{err}'")

# %%
def create_db_connection(host_name, user_name, user_password, db_name):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password,
            database=db_name
        )
        print("MySQL Database connection successful")
    except Error as err:
        print(f"Error: '{err}'")

    return connection

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query successful")
    except Error as err:
        print(f"Error: '{err}'")

# %%
#this is how you actually read data
def read_query(connection, query):
    cursor = connection.cursor()
    result = None
    try:
        cursor.execute(query)
        result = cursor.fetchall()
        return result
    except Error as err:
        print(f"Error: '{err}'")

# %%
create_pokemon_table = """
CREATE TABLE pokemon(
id INT PRIMARY KEY, 
pokedex_number INT, 
name VARCHAR(40), 
german_name VARCHAR(40), 
japanese_name VARCHAR(40), 
generation INT, 
status VARCHAR(40),
species VARCHAR(40),
type_number INT,
type_1 VARCHAR(20),
type_2 VARCHAR(20),
height_m INT,
weight_kg INT,
abilities_number INT,
ability_1 VARCHAR(40),
ability_2 VARCHAR(40),
ability_hidden VARCHAR(40),
total_points INT,
hp INT,
attack INT,
defense INT,
sp_attack INT,
sp_defense INT,
speed INT,
catch_rate INT,
base_friendship INT,
base_experience INT,
growth_rate VARCHAR(40),
egg_type_number INT,
egg_type_1 VARCHAR(40),
egg_type_2 VARCHAR(40),
percentage_male INT,
egg_cycles INT,
against_normal INT,
against_fire INT,
against_water INT,
against_electric INT,
against_grass INT,
against_ice INT,
against_fight INT,
against_poison INT,
against_ground INT,
against_flying INT,
against_psychic INT,
against_bug INT,
against_rock INT,
against_ghost INT,
against_dragon INT,
against_dark INT,
against_steel INT,
against_fairy INT
);
"""

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database
execute_query(connection, create_pokemon_table) # Execute our defined query
# Out:
# MySQL Database connection successful
# Query successful

# %% [markdown]
# Create move table and moveset table

# %%
create_move_table = """
CREATE TABLE move(
id INT PRIMARY KEY,
move VARCHAR(40),
description VARCHAR(200),
type VARCHAR(30),
category VARCHAR(20),
power INT,
accuracy INT,
pp INT,
z_effect VARCHAR(100),
priority INT,
crit INT
);
"""

create_moveset_table = """
CREATE TABLE moveset(
id INT PRIMARY KEY,
ndex INT,
species VARCHAR(40),
forme VARCHAR(40),
move1 VARCHAR(40),
move2 VARCHAR(40),
move3 VARCHAR(40),
move4 VARCHAR(40),
move5 VARCHAR(40),
move6 VARCHAR(40),
move7 VARCHAR(40),
move8 VARCHAR(40),
move9 VARCHAR(40),
move10 VARCHAR(40),
move11 VARCHAR(40),
move12 VARCHAR(40),
move13 VARCHAR(40),
move14 VARCHAR(40),
move15 VARCHAR(40),
move16 VARCHAR(40),
move17 VARCHAR(40),
move18 VARCHAR(40),
move19 VARCHAR(40),
move20 VARCHAR(40),
move21 VARCHAR(40),
move22 VARCHAR(40),
move23 VARCHAR(40),
move24 VARCHAR(40),
move25 VARCHAR(40),
move26 VARCHAR(40),
move27 VARCHAR(40),
move28 VARCHAR(40),
move29 VARCHAR(40),
move30 VARCHAR(40),
move31 VARCHAR(40),
move32 VARCHAR(40),
move33 VARCHAR(40),
move34 VARCHAR(40),
move35 VARCHAR(40),
move36 VARCHAR(40),
move37 VARCHAR(40),
move38 VARCHAR(40),
move39 VARCHAR(40),
move40 VARCHAR(40),
move41 VARCHAR(40),
move42 VARCHAR(40),
move43 VARCHAR(40),
move44 VARCHAR(40),
move45 VARCHAR(40),
move46 VARCHAR(40),
move47 VARCHAR(40),
move48 VARCHAR(40),
move49 VARCHAR(40),
move50 VARCHAR(40),
move51 VARCHAR(40),
move52 VARCHAR(40),
move53 VARCHAR(40),
move54 VARCHAR(40),
move55 VARCHAR(40),
move56 VARCHAR(40),
move57 VARCHAR(40),
move58 VARCHAR(40),
move59 VARCHAR(40),
move60 VARCHAR(40),
move61 VARCHAR(40),
move62 VARCHAR(40),
move63 VARCHAR(40),
move64 VARCHAR(40),
move65 VARCHAR(40),
move66 VARCHAR(40),
move67 VARCHAR(40),
move68 VARCHAR(40),
move69 VARCHAR(40),
move70 VARCHAR(40),
move71 VARCHAR(40),
move72 VARCHAR(40),
move73 VARCHAR(40),
move74 VARCHAR(40),
move75 VARCHAR(40),
move76 VARCHAR(40),
move77 VARCHAR(40),
move78 VARCHAR(40),
move79 VARCHAR(40),
move80 VARCHAR(40),
move81 VARCHAR(40),
move82 VARCHAR(40),
move83 VARCHAR(40),
move84 VARCHAR(40),
move85 VARCHAR(40),
move86 VARCHAR(40),
move87 VARCHAR(40),
move88 VARCHAR(40),
move89 VARCHAR(40),
move90 VARCHAR(40),
move91 VARCHAR(40),
move92 VARCHAR(40),
move93 VARCHAR(40),
move94 VARCHAR(40),
move95 VARCHAR(40),
move96 VARCHAR(40),
move97 VARCHAR(40),
move98 VARCHAR(40),
move99 VARCHAR(40),
move100 VARCHAR(40),
move101 VARCHAR(40),
move102 VARCHAR(40),
move103 VARCHAR(40),
move104 VARCHAR(40),
move105 VARCHAR(40),
move106 VARCHAR(40),
move107 VARCHAR(40),
move108 VARCHAR(40),
move109 VARCHAR(40),
move110 VARCHAR(40),
move111 VARCHAR(40),
move112 VARCHAR(40),
move113 VARCHAR(40),
move114 VARCHAR(40),
move115 VARCHAR(40),
move116 VARCHAR(40),
move117 VARCHAR(40),
move118 VARCHAR(40),
move119 VARCHAR(40),
move120 VARCHAR(40),
move121 VARCHAR(40),
move122 VARCHAR(40),
move123 VARCHAR(40),
move124 VARCHAR(40),
move125 VARCHAR(40),
move126 VARCHAR(40),
move127 VARCHAR(40),
move128 VARCHAR(40),
move129 VARCHAR(40),
move130 VARCHAR(40),
move131 VARCHAR(40),
move132 VARCHAR(40),
move133 VARCHAR(40),
move134 VARCHAR(40),
move135 VARCHAR(40),
move136 VARCHAR(40),
move137 VARCHAR(40),
move138 VARCHAR(40),
move139 VARCHAR(40),
move140 VARCHAR(40),
move141 VARCHAR(40),
move142 VARCHAR(40),
move143 VARCHAR(40),
move144 VARCHAR(40),
move145 VARCHAR(40),
move146 VARCHAR(40),
move147 VARCHAR(40),
move148 VARCHAR(40),
move149 VARCHAR(40),
move150 VARCHAR(40),
move151 VARCHAR(40),
move152 VARCHAR(40),
move153 VARCHAR(40),
move154 VARCHAR(40),
move155 VARCHAR(40),
move156 VARCHAR(40),
move157 VARCHAR(40),
move158 VARCHAR(40),
move159 VARCHAR(40),
move160 VARCHAR(40),
move161 VARCHAR(40),
move162 VARCHAR(40),
move163 VARCHAR(40),
move164 VARCHAR(40),
move165 VARCHAR(40),
move166 VARCHAR(40),
move167 VARCHAR(40),
move168 VARCHAR(40),
move169 VARCHAR(40),
move170 VARCHAR(40),
move171 VARCHAR(40),
move172 VARCHAR(40),
move173 VARCHAR(40),
move174 VARCHAR(40)
);
"""

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database
execute_query(connection, create_move_table) # Execute our defined query
# Out:
# MySQL Database connection successful
# Error: '1051 (42S02): Unknown table 'pokemondb.moveset''

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database
execute_query(connection, create_moveset_table) # Execute our defined query
# Out:
# MySQL Database connection successful
# Query successful

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database
execute_query(connection, create_move_table) # Execute our defined query
# Out:
# MySQL Database connection successful
# Query successful

# %% [markdown]
# Now need to write something that will open the pokemon csv, read it, and insert for every line

# %%
#just givves the current working directory so I know where to put the csv file

import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory

print("Files in %r: %s" % (cwd, files))
# Out:
# Files in 'D:\\Python_Projects\\Data analysis practice': ['.ipynb_checkpoints', 'Pokemon database.ipynb', 'Setting up the server.ipynb']

# %%
#create pokemon dataframe
pokemondf = pd.read_csv("pokedex.csv")

# iterating the columns to get column names
#for col in pokemondf.columns:
#    print(col)

pokemondf.set_index("id", inplace = True)
pokemondf
# Out:
#       pokedex_number                            name german_name  \
# id
# 0                  1                       Bulbasaur     Bisasam
# 1                  2                         Ivysaur   Bisaknosp
# 2                  3                        Venusaur    Bisaflor
# 3                  3                   Mega Venusaur    Bisaflor
# 4                  4                      Charmander    Glumanda
# 5                  5                      Charmeleon     Glutexo
# 6                  6                       Charizard      Glurak
# 7                  6                Mega Charizard X      Glurak
# 8                  6                Mega Charizard Y      Glurak
# 9                  7                        Squirtle     Schiggy
# 10                 8                       Wartortle    Schillok
# 11                 9                       Blastoise      Turtok
# 12                 9                  Mega Blastoise      Turtok
# 13                10                        Caterpie       Raupy
# 14                11                         Metapod      Safcon
# 15                12                      Butterfree     Smettbo
# 16                13                          Weedle     Hornliu
# 17                14                          Kakuna      Kokuna
# 18                15                        Beedrill       Bibor
# 19                15                   Mega Beedrill       Bibor
# 20                16                          Pidgey      Taubsi
# 21                17                       Pidgeotto     Tauboga
# 22                18                         Pidgeot     Tauboss
# 23                18                    Mega Pidgeot     Tauboss
# 24                19                         Rattata   Rattfratz
# 25                19                  Alolan Rattata   Rattfratz
# 26                20                        Raticate   Rattikarl
# 27                20                 Alolan Raticate   Rattikarl
# 28                21                         Spearow     Habitak
# 29                22                          Fearow      Ibitak
# ...              ...                             ...         ...
# 1015             876                 Indeedee Female      Servol
# 1016             877         Morpeko Full Belly Mode     Morpeko
# 1017             877             Morpeko Hangry Mode     Morpeko
# 1018             878                          Cufant    Kupfanti
# 1019             879                      Copperajah  Patinaraja
# 1020             880                       Dracozolt   Lectragon
# 1021             881                       Arctozolt   Lecryodon
# 1022             882                       Dracovish   Pescragon
# 1023             883                       Arctovish  Pescryodon
# 1024             884                       Duraludon   Duraludon
# 1025             885                          Dreepy    Grolldra
# 1026             886                        Drakloak     Phandra
# 1027             887                       Dragapult  Katapuldra
# 1028             888            Zacian Crowned Sword      Zacian
# 1029             888     Zacian Hero of Many Battles      Zacian
# 1030             889        Zamazenta Crowned Shield   Zamazenta
# 1031             889  Zamazenta Hero of Many Battles   Zamazenta
# 1032             890                       Eternatus   Endynalos
# 1033             890             Eternatus Eternamax   Endynalos
# 1034             891                           Kubfu      Dakuma
# 1035             892     Urshifu Single Strike Style     Wulaosu
# 1036             892      Urshifu Rapid Strike Style     Wulaosu
# 1037             893                          Zarude      Zarude
# 1038             894                       Regieleki   Regieleki
# 1039             895                       Regidrago   Regidrago
# 1040             896                       Glastrier    Polaross
# 1041             897                       Spectrier  Phantoross
# 1042             898                         Calyrex   Coronospa
# 1043             898               Calyrex Ice Rider   Coronospa
# 1044             898            Calyrex Shadow Rider   Coronospa
#
#              japanese_name  generation         status               species  \
# id
# 0      フシギダネ (Fushigidane)           1         Normal          Seed Pokémon
# 1       フシギソウ (Fushigisou)           1         Normal          Seed Pokémon
# 2      フシギバナ (Fushigibana)           1         Normal          Seed Pokémon
# 3      フシギバナ (Fushigibana)           1         Normal          Seed Pokémon
# 4          ヒトカゲ (Hitokage)           1         Normal        Lizard Pokémon
# 5           リザード (Lizardo)           1         Normal         Flame Pokémon
# 6         リザードン (Lizardon)           1         Normal         Flame Pokémon
# 7         リザードン (Lizardon)           1         Normal         Flame Pokémon
# 8         リザードン (Lizardon)           1         Normal         Flame Pokémon
# 9          ゼニガメ (Zenigame)           1         Normal   Tiny Turtle Pokémon
# 10           カメール (Kameil)           1         Normal        Turtle Pokémon
# 11           カメックス (Kamex)           1         Normal     Shellfish Pokémon
# 12           カメックス (Kamex)           1         Normal     Shellfish Pokémon
# 13        キャタピー (Caterpie)           1         Normal          Worm Pokémon
# 14         トランセル (Transel)           1         Normal        Cocoon Pokémon
# 15      バタフリー (Butterfree)           1         Normal     Butterfly Pokémon
# 16           ビードル (Beedle)           1         Normal     Hairy Bug Pokémon
# 17           コクーン (Cocoon)           1         Normal        Cocoon Pokémon
# 18            スピアー (Spear)           1         Normal    Poison Bee Pokémon
# 19            スピアー (Spear)           1         Normal    Poison Bee Pokémon
# 20             ポッポ (Poppo)           1         Normal     Tiny Bird Pokémon
# 21           ピジョン (Pigeon)           1         Normal          Bird Pokémon
# 22          ピジョット (Pigeot)           1         Normal          Bird Pokémon
# 23          ピジョット (Pigeot)           1         Normal          Bird Pokémon
# 24          コラッタ (Koratta)           1         Normal         Mouse Pokémon
# 25          コラッタ (Koratta)           1         Normal         Mouse Pokémon
# 26             ラッタ (Ratta)           1         Normal         Mouse Pokémon
# 27             ラッタ (Ratta)           1         Normal         Mouse Pokémon
# 28       オニスズメ (Onisuzume)           1         Normal     Tiny Bird Pokémon
# 29        オニドリル (Onidrill)           1         Normal          Beak Pokémon
# ...                    ...         ...            ...                   ...
# 1015        イエッサン (Yessan)           8         Normal       Emotion Pokémon
# 1016        モルペコ (Morpeko)           8         Normal     Two-Sided Pokémon
# 1017        モルペコ (Morpeko)           8         Normal     Two-Sided Pokémon
# 1018         ゾウドウ (Zoudou)           8         Normal    Copperderm Pokémon
# 1019     ダイオウドウ (Daioudou)           8         Normal    Copperderm Pokémon
# 1020  パッチラゴン (Patchiragon)           8         Normal        Fossil Pokémon
# 1021  パッチルドン (Patchilldon)           8         Normal        Fossil Pokémon
# 1022    ウオノラゴン (Ounaragon)           8         Normal        Fossil Pokémon
# 1023   ウオチルドン (Ouchilldon)           8         Normal        Fossil Pokémon
# 1024    ジュラルドン (Duraludon)           8         Normal         Alloy Pokémon
# 1025   ドラメシヤ (Dorameshiya)           8         Normal     Lingering Pokémon
# 1026        ドロンチ (Doronch)           8         Normal     Caretaker Pokémon
# 1027      ドラパルト (Dorapult)           8         Normal       Stealth Pokémon
# 1028         ザシアン (Zacian)           8      Legendary       Warrior Pokémon
# 1029         ザシアン (Zacian)           8      Legendary       Warrior Pokémon
# 1030     ザマゼンタ (Zamazenta)           8      Legendary       Warrior Pokémon
# 1031     ザマゼンタ (Zamazenta)           8      Legendary       Warrior Pokémon
# 1032    ムゲンダイナ (Mugendina)           8      Legendary      Gigantic Pokémon
# 1033    ムゲンダイナ (Mugendina)           8      Legendary      Gigantic Pokémon
# 1034          ダクマ (Dakuma)           8  Sub Legendary         Wushu Pokémon
# 1035       ウーラオス (Wulaosu)           8  Sub Legendary         Wushu Pokémon
# 1036       ウーラオス (Wulaosu)           8  Sub Legendary         Wushu Pokémon
# 1037         ザルード (Zarude)           8       Mythical  Rogue Monkey Pokémon
# 1038     レジエレキ (Regieleki)           8  Sub Legendary      Elektron Pokémon
# 1039     レジドラゴ (Regidrago)           8  Sub Legendary    Dragon Orb Pokémon
# 1040    ブリザポス (Burizaposu)           8  Sub Legendary    Wild Horse Pokémon
# 1041     レイスポス (Reisuposu)           8  Sub Legendary   Swift Horse Pokémon
# 1042       バドレックス (Budrex)           8      Legendary          King Pokémon
# 1043       バドレックス (Budrex)           8      Legendary     High King Pokémon
# 1044       バドレックス (Budrex)           8      Legendary     High King Pokémon
#
#       type_number    type_1  type_2      ...        against_ground  \
# id                                       ...
# 0               2     Grass  Poison      ...                   1.0
# 1               2     Grass  Poison      ...                   1.0
# 2               2     Grass  Poison      ...                   1.0
# 3               2     Grass  Poison      ...                   1.0
# 4               1      Fire     NaN      ...                   2.0
# 5               1      Fire     NaN      ...                   2.0
# 6               2      Fire  Flying      ...                   0.0
# 7               2      Fire  Dragon      ...                   2.0
# 8               2      Fire  Flying      ...                   0.0
# 9               1     Water     NaN      ...                   1.0
# 10              1     Water     NaN      ...                   1.0
# 11              1     Water     NaN      ...                   1.0
# 12              1     Water     NaN      ...                   1.0
# 13              1       Bug     NaN      ...                   0.5
# 14              1       Bug     NaN      ...                   0.5
# 15              2       Bug  Flying      ...                   0.0
# 16              2       Bug  Poison      ...                   1.0
# 17              2       Bug  Poison      ...                   1.0
# 18              2       Bug  Poison      ...                   1.0
# 19              2       Bug  Poison      ...                   1.0
# 20              2    Normal  Flying      ...                   0.0
# 21              2    Normal  Flying      ...                   0.0
# 22              2    Normal  Flying      ...                   0.0
# 23              2    Normal  Flying      ...                   0.0
# 24              1    Normal     NaN      ...                   1.0
# 25              2      Dark  Normal      ...                   1.0
# 26              1    Normal     NaN      ...                   1.0
# 27              2      Dark  Normal      ...                   1.0
# 28              2    Normal  Flying      ...                   0.0
# 29              2    Normal  Flying      ...                   0.0
# ...           ...       ...     ...      ...                   ...
# 1015            2   Psychic  Normal      ...                   1.0
# 1016            2  Electric    Dark      ...                   2.0
# 1017            2  Electric    Dark      ...                   2.0
# 1018            1     Steel     NaN      ...                   2.0
# 1019            1     Steel     NaN      ...                   2.0
# 1020            2  Electric  Dragon      ...                   2.0
# 1021            2  Electric     Ice      ...                   2.0
# 1022            2     Water  Dragon      ...                   1.0
# 1023            2     Water     Ice      ...                   1.0
# 1024            2     Steel  Dragon      ...                   2.0
# 1025            2    Dragon   Ghost      ...                   1.0
# 1026            2    Dragon   Ghost      ...                   1.0
# 1027            2    Dragon   Ghost      ...                   1.0
# 1028            2     Fairy   Steel      ...                   2.0
# 1029            1     Fairy     NaN      ...                   1.0
# 1030            2  Fighting   Steel      ...                   2.0
# 1031            1  Fighting     NaN      ...                   1.0
# 1032            2    Poison  Dragon      ...                   2.0
# 1033            2    Poison  Dragon      ...                   2.0
# 1034            1  Fighting     NaN      ...                   1.0
# 1035            2  Fighting    Dark      ...                   1.0
# 1036            2  Fighting   Water      ...                   1.0
# 1037            2      Dark   Grass      ...                   0.5
# 1038            1  Electric     NaN      ...                   2.0
# 1039            1    Dragon     NaN      ...                   1.0
# 1040            1       Ice     NaN      ...                   1.0
# 1041            1     Ghost     NaN      ...                   1.0
# 1042            2   Psychic   Grass      ...                   0.5
# 1043            2   Psychic     Ice      ...                   1.0
# 1044            2   Psychic   Ghost      ...                   1.0
#
#       against_flying  against_psychic against_bug against_rock against_ghost  \
# id
# 0                2.0              2.0        1.00         1.00           1.0
# 1                2.0              2.0        1.00         1.00           1.0
# 2                2.0              2.0        1.00         1.00           1.0
# 3                2.0              2.0        1.00         1.00           1.0
# 4                1.0              1.0        0.50         2.00           1.0
# 5                1.0              1.0        0.50         2.00           1.0
# 6                1.0              1.0        0.25         4.00           1.0
# 7                1.0              1.0        0.50         2.00           1.0
# 8                1.0              1.0        0.25         4.00           1.0
# 9                1.0              1.0        1.00         1.00           1.0
# 10               1.0              1.0        1.00         1.00           1.0
# 11               1.0              1.0        1.00         1.00           1.0
# 12               1.0              1.0        1.00         1.00           1.0
# 13               2.0              1.0        1.00         2.00           1.0
# 14               2.0              1.0        1.00         2.00           1.0
# 15               2.0              1.0        0.50         4.00           1.0
# 16               2.0              2.0        0.50         2.00           1.0
# 17               2.0              2.0        0.50         2.00           1.0
# 18               2.0              2.0        0.50         2.00           1.0
# 19               2.0              2.0        0.50         2.00           1.0
# 20               1.0              1.0        0.50         2.00           0.0
# 21               1.0              1.0        0.50         2.00           0.0
# 22               1.0              1.0        0.50         2.00           0.0
# 23               1.0              1.0        0.50         2.00           0.0
# 24               1.0              1.0        1.00         1.00           0.0
# 25               1.0              0.0        2.00         1.00           0.0
# 26               1.0              1.0        1.00         1.00           0.0
# 27               1.0              0.0        2.00         1.00           0.0
# 28               1.0              1.0        0.50         2.00           0.0
# 29               1.0              1.0        0.50         2.00           0.0
# ...              ...              ...         ...          ...           ...
# 1015             1.0              0.5        2.00         1.00           0.0
# 1016             0.5              0.0        2.00         1.00           0.5
# 1017             0.5              0.0        2.00         1.00           0.5
# 1018             0.5              0.5        0.50         0.50           1.0
# 1019             0.5              0.5        0.50         0.50           1.0
# 1020             0.5              1.0        1.00         1.00           1.0
# 1021             0.5              1.0        1.00         2.00           1.0
# 1022             1.0              1.0        1.00         1.00           1.0
# 1023             1.0              1.0        1.00         2.00           1.0
# 1024             0.5              0.5        0.50         0.50           1.0
# 1025             1.0              1.0        0.50         1.00           2.0
# 1026             1.0              1.0        0.50         1.00           2.0
# 1027             1.0              1.0        0.50         1.00           2.0
# 1028             0.5              0.5        0.25         0.50           1.0
# 1029             1.0              1.0        0.50         1.00           1.0
# 1030             1.0              1.0        0.25         0.25           1.0
# 1031             2.0              2.0        0.50         0.50           1.0
# 1032             1.0              2.0        0.50         1.00           1.0
# 1033             1.0              2.0        0.50         1.00           1.0
# 1034             2.0              2.0        0.50         0.50           1.0
# 1035             2.0              0.0        1.00         0.50           0.5
# 1036             2.0              2.0        0.50         0.50           1.0
# 1037             2.0              0.0        4.00         1.00           0.5
# 1038             0.5              1.0        1.00         1.00           1.0
# 1039             1.0              1.0        1.00         1.00           1.0
# 1040             1.0              1.0        1.00         2.00           1.0
# 1041             1.0              1.0        0.50         1.00           2.0
# 1042             2.0              0.5        4.00         1.00           2.0
# 1043             1.0              0.5        2.00         2.00           2.0
# 1044             1.0              0.5        1.00         1.00           4.0
#
#       against_dragon  against_dark  against_steel  against_fairy
# id
# 0                1.0          1.00            1.0            0.5
# 1                1.0          1.00            1.0            0.5
# 2                1.0          1.00            1.0            0.5
# 3                1.0          1.00            1.0            0.5
# 4                1.0          1.00            0.5            0.5
# 5                1.0          1.00            0.5            0.5
# 6                1.0          1.00            0.5            0.5
# 7                2.0          1.00            0.5            1.0
# 8                1.0          1.00            0.5            0.5
# 9                1.0          1.00            0.5            1.0
# 10               1.0          1.00            0.5            1.0
# 11               1.0          1.00            0.5            1.0
# 12               1.0          1.00            0.5            1.0
# 13               1.0          1.00            1.0            1.0
# 14               1.0          1.00            1.0            1.0
# 15               1.0          1.00            1.0            1.0
# 16               1.0          1.00            1.0            0.5
# 17               1.0          1.00            1.0            0.5
# 18               1.0          1.00            1.0            0.5
# 19               1.0          1.00            1.0            0.5
# 20               1.0          1.00            1.0            1.0
# 21               1.0          1.00            1.0            1.0
# 22               1.0          1.00            1.0            1.0
# 23               1.0          1.00            1.0            1.0
# 24               1.0          1.00            1.0            1.0
# 25               1.0          0.50            1.0            2.0
# 26               1.0          1.00            1.0            1.0
# 27               1.0          0.50            1.0            2.0
# 28               1.0          1.00            1.0            1.0
# 29               1.0          1.00            1.0            1.0
# ...              ...           ...            ...            ...
# 1015             1.0          2.00            1.0            1.0
# 1016             1.0          0.50            0.5            2.0
# 1017             1.0          0.50            0.5            2.0
# 1018             0.5          1.00            0.5            0.5
# 1019             0.5          1.00            0.5            0.5
# 1020             2.0          1.00            0.5            2.0
# 1021             1.0          1.00            1.0            1.0
# 1022             2.0          1.00            0.5            2.0
# 1023             1.0          1.00            1.0            1.0
# 1024             1.0          1.00            0.5            1.0
# 1025             2.0          2.00            1.0            2.0
# 1026             2.0          2.00            1.0            2.0
# 1027             2.0          2.00            1.0            2.0
# 1028             0.0          0.50            1.0            0.5
# 1029             0.0          0.50            2.0            1.0
# 1030             0.5          0.50            0.5            1.0
# 1031             1.0          0.50            1.0            2.0
# 1032             2.0          1.00            1.0            1.0
# 1033             2.0          1.00            1.0            1.0
# 1034             1.0          0.50            1.0            2.0
# 1035             1.0          0.25            1.0            4.0
# 1036             1.0          0.50            0.5            2.0
# 1037             1.0          0.50            1.0            2.0
# 1038             1.0          1.00            0.5            1.0
# 1039             2.0          1.00            1.0            2.0
# 1040             1.0          1.00            2.0            1.0
# 1041             1.0          2.00            1.0            1.0
# 1042             1.0          2.00            1.0            1.0
# 1043             1.0          2.00            2.0            1.0
# 1044             1.0          4.00            1.0            1.0
#
# [1045 rows x 50 columns]

# %%
#create moves dataframe
movesdf = pd.read_csv("moves.csv")

movesdf.set_index("id", inplace = True)


#create movesets dataframe
movesetsdf = pd.read_csv("movesets.csv")
movesetsdf.index.name = "id"

movesdf
# Out:
#                             move  \
# id
# 1                          Pound
# 2                    Karate Chop
# 3                    Double Slap
# 4                    Comet Punch
# 5                     Mega Punch
# 6                        Pay Day
# 7                     Fire Punch
# 8                      Ice Punch
# 9                  Thunder Punch
# 10                       Scratch
# 11                     Vice Grip
# 12                    Guillotine
# 13                    Razor Wind
# 14                  Swords Dance
# 15                           Cut
# 16                          Gust
# 17                   Wing Attack
# 18                     Whirlwind
# 19                           Fly
# 20                          Bind
# 21                          Slam
# 22                     Vine Whip
# 23                         Stomp
# 24                   Double Kick
# 25                     Mega Kick
# 26                     Jump Kick
# 27                  Rolling Kick
# 28                   Sand Attack
# 29                      Headbutt
# 30                   Horn Attack
# ..                           ...
# 672                   Beak Blast
# 673              Clanging Scales
# 674                Dragon Hammer
# 675                 Brutal Swing
# 676                  Aurora Veil
# 677          Sinister Arrow Raid
# 678          Malicious Moonsault
# 679             Oceanic Operetta
# 680            Guardian of Alola
# 681  Soul-Stealing 7-Star Strike
# 682           Stoked Sparksurfer
# 683          Pulverizing Pancake
# 684             Extreme Evoboost
# 685            Genesis Supernova
# 686                   Shell Trap
# 687                 Fleur Cannon
# 688                Psychic Fangs
# 689             Stomping Tantrum
# 690                  Shadow Bone
# 691                   Accelerock
# 692                  Liquidation
# 693              Prismatic Laser
# 694               Spectral Thief
# 695              Sunsteel Strike
# 696               Moongeist Beam
# 697                 Tearful Look
# 698                     Zing Zap
# 699             Nature’s Madness
# 700                 Multi-Attack
# 701  10,000,000 Volt Thunderbolt
#
#                                            description      type  category  \
# id
# 1    The target is physically pounded with a long t...    Normal  Physical
# 2    The target is attacked with a sharp chop. Crit...  Fighting  Physical
# 3    The target is slapped repeatedly, back and for...    Normal  Physical
# 4    The target is hit with a flurry of punches tha...    Normal  Physical
# 5    The target is slugged by a punch thrown with m...    Normal  Physical
# 6    Numerous coins are hurled at the target to inf...    Normal  Physical
# 7    The target is punched with a fiery fist. This ...      Fire  Physical
# 8    The target is punched with an icy fist. This m...       Ice  Physical
# 9    The target is punched with an electrified fist...  Electric  Physical
# 10   Hard, pointed, sharp claws rake the target to ...    Normal  Physical
# 11   The target is gripped and squeezed from both s...    Normal  Physical
# 12   A vicious, tearing attack with big pincers. Th...    Normal  Physical
# 13   In this two-turn attack, blades of wind hit op...    Normal   Special
# 14   A frenetic dance to uplift the fighting spirit...    Normal    Status
# 15            The target is cut with a scythe or claw.    Normal  Physical
# 16   A gust of wind is whipped up by wings and laun...    Flying   Special
# 17   The target is struck with large, imposing wing...    Flying  Physical
# 18   The target is blown away, and a different Poké...    Normal    Status
# 19   The user soars and then strikes its target on ...    Flying  Physical
# 20   Things such as long bodies or tentacles are us...    Normal  Physical
# 21   The target is slammed with a long tail, vines,...    Normal  Physical
# 22   The target is struck with slender, whiplike vi...     Grass  Physical
# 23   The target is stomped with a big foot. This ma...    Normal  Physical
# 24   The target is quickly kicked twice in successi...  Fighting  Physical
# 25   The target is attacked by a kick launched with...    Normal  Physical
# 26   The user jumps up high, then strikes with a ki...  Fighting  Physical
# 27   The user lashes out with a quick, spinning kic...  Fighting  Physical
# 28   Sand is hurled in the target’s face, reducing ...    Ground    Status
# 29   The user sticks out its head and attacks by ch...    Normal  Physical
# 30   The target is jabbed with a sharply pointed ho...    Normal  Physical
# ..                                                 ...       ...       ...
# 672  The user first heats up its beak, and then it ...    Flying  Physical
# 673  The user rubs the scales on its entire body an...    Dragon   Special
# 674  The user uses its body like a hammer to attack...    Dragon  Physical
# 675  The user swings its body around violently to i...      Dark  Physical
# 676  This move reduces damage from physical and spe...       Ice    Status
# 677  The user, Decidueye, creates countless arrows ...     Ghost  Physical
# 678  The user, Incineroar, strengthens its body usi...      Dark  Physical
# 679  The user, Primarina, summons a massive amount ...     Water   Special
# 680  The user, the Land Spirit Pokémon, obtains Alo...     Fairy   Special
# 681  After obtaining Z-Power, the user, Marshadow, ...     Ghost  Physical
# 682  After obtaining Z-Power, the user, Alolan Raic...  Electric   Special
# 683  Z-Power brings out the true capabilities of th...    Normal  Physical
# 684  After obtaining Z-Power, the user, Eevee, gets...    Normal    Status
# 685  After obtaining Z-Power, the user, Mew, attack...   Psychic   Special
# 686  The user sets a shell trap. If the user is hit...      Fire   Special
# 687  The user unleashes a strong beam. The attack’s...     Fairy   Special
# 688  The user bites the target with its psychic cap...   Psychic  Physical
# 689  Driven by frustration, the user attacks the ta...    Ground  Physical
# 690  The user attacks by beating the target with a ...     Ghost  Physical
# 691  The user smashes into the target at high speed...      Rock  Physical
# 692  The user slams into the target using a full-fo...     Water  Physical
# 693  The user shoots powerful lasers using the powe...   Psychic   Special
# 694  The user hides in the target’s shadow, steals ...     Ghost  Physical
# 695  The user slams into the target with the force ...     Steel  Physical
# 696  The user emits a sinister ray to attack the ta...     Ghost   Special
# 697  The user gets teary eyed to make the target lo...    Normal    Status
# 698  A strong electric blast crashes down on the ta...  Electric  Physical
# 699  The user hits the target with the force of nat...     Fairy   Special
# 700  Cloaking itself in high energy, the user slams...    Normal  Physical
# 701  The user, Pikachu wearing a cap, powers up a j...  Electric   Special
#
#      power  accuracy  pp            z_effect  priority  crit
# id
# 1       40      1.00  35           100 Power         0     0
# 2       50      1.00  25           100 Power         0     1
# 3       15      0.85  10           100 Power         0     0
# 4       18      0.85  15           100 Power         0     0
# 5       80      0.85  20           160 Power         0     0
# 6       40      1.00  20           100 Power         0     0
# 7       75      1.00  15           140 Power         0     0
# 8       75      1.00  15           140 Power         0     0
# 9       75      1.00  15           140 Power         0     0
# 10      40      1.00  35           100 Power         0     0
# 11      55      1.00  30           100 Power         0     0
# 12       0      0.30   5           180 Power         0     0
# 13      80      1.00  10           160 Power         0     1
# 14       0      0.00  20  Reset user's stats         0     0
# 15      50      0.95  30           100 Power         0     0
# 16      40      1.00  35           100 Power         0     0
# 17      60      1.00  35           120 Power         0     0
# 18       0      0.00  20   Special Defense ↑        -6     0
# 19      90      0.95  15           175 Power         0     0
# 20      15      0.85  20           100 Power         0     0
# 21      80      0.75  20           160 Power         0     0
# 22      45      1.00  25           100 Power         0     0
# 23      65      1.00  20           120 Power         0     0
# 24      30      1.00  30           100 Power         0     0
# 25     120      0.75   5           190 Power         0     0
# 26     100      0.95  10           180 Power         0     0
# 27      60      0.85  15           120 Power         0     0
# 28       0      1.00  15       Evasiveness ↑         0     0
# 29      70      1.00  15           140 Power         0     0
# 30      65      1.00  25           120 Power         0     0
# ..     ...       ...  ..                 ...       ...   ...
# 672    100      1.00  15           180 Power        -3     0
# 673    110      1.00   5           185 Power         0     0
# 674     90      1.00  15           175 Power         0     0
# 675     60      1.00  20           120 Power         0     0
# 676      0      0.00  20             Speed ↑         0     0
# 677    180      0.00   1     ~Spirit Shackle         0     0
# 678    180      0.00   1     ~Darkest Lariat         0     0
# 679    195      0.00   1     ~Sparkling Aria         0     0
# 680      0      0.00   1   ~Nature’s Madness         0     0
# 681    195      0.00   1     ~Spectral Thief         0     0
# 682    175      0.00   1        ~Thunderbolt         0     0
# 683    210      0.00   1        ~Giga Impact         0     0
# 684      0      0.00   1        ~Last Resort         0     0
# 685    185      0.00   1            ~Psychic         0     0
# 686    150      1.00   5           200 Power        -3     0
# 687    130      0.90   5           195 Power         0     0
# 688     85      1.00  10           160 Power         0     0
# 689     75      1.00  10           140 Power         0     0
# 690     85      1.00  10           160 Power         0     0
# 691     40      1.00  20           100 Power         1     0
# 692     85      1.00  10           160 Power         0     0
# 693    160      1.00  10           200 Power         0     0
# 694     90      1.00  10           175 Power         0     0
# 695    100      1.00   5           180 Power         0     0
# 696    100      1.00   5           180 Power         0     0
# 697      0      0.00  20           Defense ↑         0     0
# 698     80      1.00  10           160 Power         0     0
# 699      0      1.00  10           100 Power         0     0
# 700     90      1.00  10           185 Power         0     0
# 701    195      0.00   1        ~Thunderbolt         0     2
#
# [701 rows x 10 columns]

# %% [markdown]
# # Need to go through accuracy column in moves dataframe and change percent strings to ints and change --s to 100 (to indicate always hitting). Then the actual table in the database will take an int

# %%
#THIS WORKS ON ITS OWN
#movesdf.loc[movesdf['accuracy'].str.contains('—', na=False), 'accuracy'] = 100

#df.loc[df['column name'] condition, 'new column name'] = 'value if condition is met'

# %%
#movesdf.loc[isinstance(movesdf['accuracy'], str), 'accuracy'] = pd.to_numeric(movesdf['accuracy'].str.strip('%'))

#THIS MIGHT NOT WORK ON ITS OWN BUT WILL NOT WORK UNLESS THE HYPEN SLASHES ARE FILTERED OUT
#movesdf['accuracy'] = pd.to_numeric(movesdf['accuracy'].str.strip('%'))

#for x in movesdf['accuracy']:
#    if x is not int and "—" not in x:
#        movesdf['accuracy'] = pd.to_numeric(movesdf['accuracy'].str.strip('%'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-347-51f038fa2d2f> in <module>()
# ----> 1 movesdf.loc[isinstance(movesdf['accuracy'], str), 'accuracy'] = pd.to_numeric(movesdf['accuracy'].str.strip('%'))
#       2
#       3 #THIS MIGHT NOT WORK ON ITS OWN BUT WILL NOT WORK UNLESS THE HYPEN SLASHES ARE FILTERED OUT
#       4 #movesdf['accuracy'] = pd.to_numeric(movesdf['accuracy'].str.strip('%'))
#       5
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# D:\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# D:\Anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# D:\Anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    1915             # (instead of test for object dtype), but that isn't practical for
#    1916             # performance reasons until we have a str dtype (GH 9343)
# -> 1917             raise AttributeError("Can only use .str accessor with string "
#    1918                                  "values, which use np.object_ dtype in "
#    1919                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %%
import sqlalchemy

# import the module
from sqlalchemy import create_engine

# create sqlalchemy engine
engine = sqlalchemy.create_engine(
    'mysql+mysqlconnector://root:Dollardollarbillyall@localhost:3306/pokemondb')

# %%
# Insert whole pokemon DataFrame into MySQL
pokemondf.to_sql('pokemon', con = engine, if_exists = 'append', chunksize = 1000)

# %%
# Insert whole moveset DataFrame into MySQL
movesetsdf.to_sql('moveset', con = engine, if_exists = 'append', chunksize = 1000)

# %%
# Insert whole move DataFrame into MySQL
movesdf.to_sql('move', con = engine, if_exists = 'append', chunksize = 1000)

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database
results = read_query(connection, "SELECT move FROM move WHERE type = 'fire'")
display(results)
# Out:
# MySQL Database connection successful
# [('Fire Punch',),
#  ('Ember',),
#  ('Flamethrower',),
#  ('Fire Spin',),
#  ('Fire Blast',),
#  ('Flame Wheel',),
#  ('Sacred Fire',),
#  ('Sunny Day',),
#  ('Heat Wave',),
#  ('Will-O-Wisp',),
#  ('Eruption',),
#  ('Blaze Kick',),
#  ('Blast Burn',),
#  ('Overheat',),
#  ('Flare Blitz',),
#  ('Fire Fang',),
#  ('Lava Plume',),
#  ('Magma Storm',),
#  ('Flame Burst',),
#  ('Flame Charge',),
#  ('Incinerate',),
#  ('Inferno',),
#  ('Fire Pledge',),
#  ('Heat Crash',),
#  ('Searing Shot',),
#  ('Blue Flare',),
#  ('Fiery Dance',),
#  ('V-create',),
#  ('Fusion Flare',),
#  ('Mystical Fire',),
#  ('Inferno Overdrive',),
#  ('Fire Lash',),
#  ('Burn Up',),
#  ('Shell Trap',)]

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database
results = read_query(connection, "SELECT * FROM moveset WHERE ndex = 2;")
display(results)
# Out:
# MySQL Database connection successful
# [(1,
#   2,
#   'Ivysaur',
#   'Ivysaur',
#   'Start - Tackle',
#   'Start - Growl',
#   'Start - Leech Seed',
#   'L3 - Growl',
#   'L7 - Leech Seed',
#   'L9 - Vine Whip',
#   'L13 - Poison Powder',
#   'L13 - Sleep Powder',
#   'L15 - Take Down',
#   'L20 - Razor Leaf',
#   'L23 - Sweet Scent',
#   'L28 - Growth',
#   'L31 - Double-Edge',
#   'L36 - Worry Seed',
#   'L39 - Synthesis',
#   'L44 - Solar Beam',
#   'TM01 - Work Up',
#   'TM06 - Toxic',
#   'TM09 - Venoshock',
#   'TM10 - Hidden Power',
#   'TM11 - Sunny Day',
#   'TM16 - Light Screen',
#   'TM17 - Protect',
#   'TM20 - Safeguard',
#   'TM21 - Frustration',
#   'TM22 - Solar Beam',
#   'TM27 - Return',
#   'TM32 - Double Team',
#   'TM36 - Sludge Bomb',
#   'TM42 - Facade',
#   'TM44 - Rest',
#   'TM45 - Attract',
#   'TM48 - Round',
#   'TM49 - Echoed Voice',
#   'TM53 - Energy Ball',
#   'TM75 - Swords Dance',
#   'TM86 - Grass Knot',
#   'TM87 - Swagger',
#   'TM88 - Sleep Talk',
#   'TM90 - Substitute',
#   'TM96 - Nature Power',
#   'TM100 - Confide',
#   'Tutor - Frenzy Plant',
#   'Egg - Skull Bash',
#   'Egg - Charm',
#   'Egg - Petal Dance',
#   'Egg - Magical Leaf',
#   'Egg - Grass Whistle',
#   'Egg - Curse',
#   'Egg - Ingrain',
#   'Egg - Nature Power',
#   'Egg - Amnesia',
#   'Egg - Leaf Storm',
#   'Egg - Power Whip',
#   'Egg - Sludge',
#   'Egg - Endure',
#   'Egg - Giga Drain',
#   'Egg - Grassy Terrain',
#   'ORAS - Seed Bomb',
#   'ORAS - Bind',
#   'ORAS - Snore',
#   'ORAS - Knock Off',
#   'ORAS - Synthesis',
#   'ORAS - Giga Drain',
#   'ORAS - Worry Seed',
#   'Prev - Seed Bomb',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None)]

# %%
#order types by average total base stats

#fetchall method (used by read_query) returns a list of tuples
stats_data = read_query(connection, "SELECT type_1, AVG(total_points) FROM pokemon GROUP BY type_1 ORDER BY AVG(total_points) DESC;")
display(stats_data)
# Out:
# [('Dragon', Decimal('536.3659')),
#  ('Psychic', Decimal('489.3704')),
#  ('Steel', Decimal('481.4722')),
#  ('Fire', Decimal('455.0154')),
#  ('Electric', Decimal('451.4355')),
#  ('Rock', Decimal('448.6833')),
#  ('Fighting', Decimal('446.4048')),
#  ('Ghost', Decimal('444.0714')),
#  ('Flying', Decimal('440.0000')),
#  ('Fairy', Decimal('439.2727')),
#  ('Poison', Decimal('435.5122')),
#  ('Dark', Decimal('434.5435')),
#  ('Water', Decimal('431.7388')),
#  ('Ground', Decimal('431.1463')),
#  ('Ice', Decimal('430.8649')),
#  ('Grass', Decimal('418.2418')),
#  ('Normal', Decimal('404.8696')),
#  ('Bug', Decimal('384.6173'))]

# %% [markdown]
# Now take the results of that SQL query and get it into a nice looking graph. Might want to put it into a pandas dataframe first for practice

# %%
x_val = [x[0] for x in stats_data]
y_val = [x[1] for x in stats_data]

#print x_val
plt.plot(x_val,y_val)
plt.plot(x_val,y_val,'or')
plt.title('Average stats by type')
plt.xlabel('Type')
plt.ylabel('Average stat total')
plt.show()

# %%
#fig = plt.figure()
plt.bar(x_val,y_val,align='center')
plt.xlabel('Type')
plt.ylabel('Average stat total')
figure(figsize=(50, 12), dpi=80)
plt.show()

# %%
# plotting a line plot after changing it's width and height
f = plt.figure()
f.set_figwidth(16)
f.set_figheight(8)
  
print("Plot after re-sizing: ")
plt.bar(x_val,y_val,align='center')
plt.xlabel('Type')
plt.ylabel('Average stat total')
plt.title("Average stat totals by type")
plt.show()
# Out:
# Plot after re-sizing:

# %% [markdown]
# Now let's get number of pokemon based on primary type

# %%
q2 = """SELECT type_1, COUNT(name) FROM pokemon GROUP BY type_1 ORDER BY COUNT(name) DESC;

"""

#fetchall method (used by read_query) returns a list of tuples
amount_by_type_data = read_query(connection, q2)
display(amount_by_type_data)
# Out:
# [('Water', 134),
#  ('Normal', 115),
#  ('Grass', 91),
#  ('Bug', 81),
#  ('Psychic', 81),
#  ('Fire', 65),
#  ('Electric', 62),
#  ('Rock', 60),
#  ('Dark', 46),
#  ('Fighting', 42),
#  ('Ghost', 42),
#  ('Poison', 41),
#  ('Ground', 41),
#  ('Dragon', 41),
#  ('Ice', 37),
#  ('Steel', 36),
#  ('Fairy', 22),
#  ('Flying', 8)]

# %%
x_val2 = [x[0] for x in amount_by_type_data]
y_val2 = [x[1] for x in amount_by_type_data]

amount_graph = plt.figure()
amount_graph.set_figwidth(16)
amount_graph.set_figheight(8)
  
plt.bar(x_val2,y_val2,align='center')
plt.xlabel('Type')
plt.ylabel('Number of Pokemon')
plt.title("Number of Pokemon by primary type")
plt.show()

# %%
print([x[0] for x in amount_by_type_data])
# Out:
# ['Water', 'Normal', 'Grass', 'Bug', 'Psychic', 'Fire', 'Electric', 'Rock', 'Dark', 'Fighting', 'Ghost', 'Poison', 'Ground', 'Dragon', 'Ice', 'Steel', 'Fairy', 'Flying']

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = [x[0] for x in amount_by_type_data]
sizes = [x[1] for x in amount_by_type_data]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax1.legend(loc="upper right", fontsize=20, bbox_to_anchor=(1.25, 1.25))
fig1.set_size_inches(18.5, 10.5)

plt.show()

# %% [markdown]
# Get number of legendary Pokemon per generation

# %%
q3 = """SELECT generation, COUNT(DISTINCT pokedex_number) FROM pokemon 
WHERE status = 'Legendary' OR status = 'Sub legendary' OR status = 'Mythical'
GROUP BY generation 
ORDER BY generation;

"""

#fetchall method (used by read_query) returns a list of tuples
legendary_amount_data = read_query(connection, q3)
display(legendary_amount_data)
# Out:
# [(1, 5), (2, 6), (3, 10), (4, 14), (5, 13), (6, 6), (7, 27), (8, 14)]

# %%
x_val3 = [x[0] for x in legendary_amount_data]
y_val3 = [x[1] for x in legendary_amount_data]

amount_graph = plt.figure()
amount_graph.set_figwidth(16)
amount_graph.set_figheight(8)
  
plt.bar(x_val3,y_val3,align='center')
plt.xlabel('Generation')
plt.ylabel('Number of legendary Pokemon')
plt.title("Number of Legendary Pokemon by Generation")
plt.show()

# %% [markdown]
# Now plot average attack stat of each type

# %%
q4 = """SELECT type_1, AVG(attack) FROM pokemon
GROUP BY type_1
ORDER BY AVG(ATTACK) DESC;

"""

#fetchall method (used by read_query) returns a list of tuples
attack_data = read_query(connection, q4)
display(attack_data)
# Out:
# [('Dragon', Decimal('107.0244')),
#  ('Fighting', Decimal('102.9286')),
#  ('Ground', Decimal('94.1220')),
#  ('Steel', Decimal('94.0833')),
#  ('Rock', Decimal('91.7833')),
#  ('Fire', Decimal('85.4000')),
#  ('Dark', Decimal('81.9348')),
#  ('Ice', Decimal('78.4865')),
#  ('Psychic', Decimal('76.2346')),
#  ('Poison', Decimal('75.8780')),
#  ('Normal', Decimal('75.2609')),
#  ('Flying', Decimal('75.1250')),
#  ('Water', Decimal('74.9925')),
#  ('Electric', Decimal('74.9839')),
#  ('Grass', Decimal('74.8132')),
#  ('Ghost', Decimal('73.9762')),
#  ('Bug', Decimal('71.0741')),
#  ('Fairy', Decimal('68.0909'))]

# %%
x_val4 = [x[0] for x in attack_data]
y_val4 = [x[1] for x in attack_data]

attack_graph = plt.figure()
attack_graph.set_figwidth(16)
attack_graph.set_figheight(8)
  
plt.bar(x_val4,y_val4,align='center')
plt.xlabel('Type')
plt.ylabel('Average base attack')
plt.title("Average base attack by primary type")
plt.show()

# %%
q4 = """SELECT type, COUNT(move) FROM move GROUP BY type ORDER BY COUNT(move) DESC;

"""

#fetchall method (used by read_query) returns a list of tuples
move_type_data = read_query(connection, q4)
display(move_type_data)
# Out:
# [('Normal', 180),
#  ('Psychic', 61),
#  ('Fighting', 43),
#  ('Grass', 42),
#  ('Dark', 38),
#  ('Fire', 34),
#  ('Water', 33),
#  ('Electric', 32),
#  ('Bug', 29),
#  ('Poison', 27),
#  ('Flying', 26),
#  ('Ground', 26),
#  ('Ghost', 25),
#  ('Ice', 24),
#  ('Steel', 24),
#  ('Fairy', 22),
#  ('Rock', 18),
#  ('Dragon', 17)]

# %%
x_val5 = [x[0] for x in move_type_data]
y_val5 = [x[1] for x in move_type_data]

move_type_graph = plt.figure()
move_type_graph.set_figwidth(16)
move_type_graph.set_figheight(8)
  
plt.bar(x_val5,y_val5,align='center')
plt.xlabel('Type')
plt.ylabel('Number ov moves')
plt.title("Number of moves by type")
plt.show()

# %% [markdown]
# ### Find all pokemon who can learn Aerial Ace

# %%
aerial_ace_string = ""

for x in range(174): 
    aerial_ace_string += "OR move"+str(x)+" LIKE '%Aerial Ace' \n"

# %%
test_string = "test"
test_string += "testo"
print(aerial_ace_string)
# Out:
# testtesto

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database

q6 = """SELECT 'Aerial Ace', COUNT(species) FROM moveset
WHERE move1 LIKE '%Aerial Ace' 
OR move2 LIKE '%Aerial Ace' 
OR move3 LIKE '%Aerial Ace' 
OR move4 LIKE '%Aerial Ace' 
OR move5 LIKE '%Aerial Ace' 
OR move6 LIKE '%Aerial Ace' 
OR move7 LIKE '%Aerial Ace' 
OR move8 LIKE '%Aerial Ace' 
OR move9 LIKE '%Aerial Ace' 
OR move10 LIKE '%Aerial Ace' 
OR move11 LIKE '%Aerial Ace' 
OR move12 LIKE '%Aerial Ace' 
OR move13 LIKE '%Aerial Ace' 
OR move14 LIKE '%Aerial Ace' 
OR move15 LIKE '%Aerial Ace' 
OR move16 LIKE '%Aerial Ace' 
OR move17 LIKE '%Aerial Ace' 
OR move18 LIKE '%Aerial Ace' 
OR move19 LIKE '%Aerial Ace' 
OR move20 LIKE '%Aerial Ace' 
OR move21 LIKE '%Aerial Ace' 
OR move22 LIKE '%Aerial Ace' 
OR move23 LIKE '%Aerial Ace' 
OR move24 LIKE '%Aerial Ace' 
OR move25 LIKE '%Aerial Ace' 
OR move26 LIKE '%Aerial Ace' 
OR move27 LIKE '%Aerial Ace' 
OR move28 LIKE '%Aerial Ace' 
OR move29 LIKE '%Aerial Ace' 
OR move30 LIKE '%Aerial Ace' 
OR move31 LIKE '%Aerial Ace' 
OR move32 LIKE '%Aerial Ace' 
OR move33 LIKE '%Aerial Ace' 
OR move34 LIKE '%Aerial Ace' 
OR move35 LIKE '%Aerial Ace' 
OR move36 LIKE '%Aerial Ace' 
OR move37 LIKE '%Aerial Ace' 
OR move38 LIKE '%Aerial Ace' 
OR move39 LIKE '%Aerial Ace' 
OR move40 LIKE '%Aerial Ace' 
OR move41 LIKE '%Aerial Ace' 
OR move42 LIKE '%Aerial Ace' 
OR move43 LIKE '%Aerial Ace' 
OR move44 LIKE '%Aerial Ace' 
OR move45 LIKE '%Aerial Ace' 
OR move46 LIKE '%Aerial Ace' 
OR move47 LIKE '%Aerial Ace' 
OR move48 LIKE '%Aerial Ace' 
OR move49 LIKE '%Aerial Ace' 
OR move50 LIKE '%Aerial Ace' 
OR move51 LIKE '%Aerial Ace' 
OR move52 LIKE '%Aerial Ace' 
OR move53 LIKE '%Aerial Ace' 
OR move54 LIKE '%Aerial Ace' 
OR move55 LIKE '%Aerial Ace' 
OR move56 LIKE '%Aerial Ace' 
OR move57 LIKE '%Aerial Ace' 
OR move58 LIKE '%Aerial Ace' 
OR move59 LIKE '%Aerial Ace' 
OR move60 LIKE '%Aerial Ace' 
OR move61 LIKE '%Aerial Ace' 
OR move62 LIKE '%Aerial Ace' 
OR move63 LIKE '%Aerial Ace' 
OR move64 LIKE '%Aerial Ace' 
OR move65 LIKE '%Aerial Ace' 
OR move66 LIKE '%Aerial Ace' 
OR move67 LIKE '%Aerial Ace' 
OR move68 LIKE '%Aerial Ace' 
OR move69 LIKE '%Aerial Ace' 
OR move70 LIKE '%Aerial Ace' 
OR move71 LIKE '%Aerial Ace' 
OR move72 LIKE '%Aerial Ace' 
OR move73 LIKE '%Aerial Ace' 
OR move74 LIKE '%Aerial Ace' 
OR move75 LIKE '%Aerial Ace' 
OR move76 LIKE '%Aerial Ace' 
OR move77 LIKE '%Aerial Ace' 
OR move78 LIKE '%Aerial Ace' 
OR move79 LIKE '%Aerial Ace' 
OR move80 LIKE '%Aerial Ace' 
OR move81 LIKE '%Aerial Ace' 
OR move82 LIKE '%Aerial Ace' 
OR move83 LIKE '%Aerial Ace' 
OR move84 LIKE '%Aerial Ace' 
OR move85 LIKE '%Aerial Ace' 
OR move86 LIKE '%Aerial Ace' 
OR move87 LIKE '%Aerial Ace' 
OR move88 LIKE '%Aerial Ace' 
OR move89 LIKE '%Aerial Ace' 
OR move90 LIKE '%Aerial Ace' 
OR move91 LIKE '%Aerial Ace' 
OR move92 LIKE '%Aerial Ace' 
OR move93 LIKE '%Aerial Ace' 
OR move94 LIKE '%Aerial Ace' 
OR move95 LIKE '%Aerial Ace' 
OR move96 LIKE '%Aerial Ace' 
OR move97 LIKE '%Aerial Ace' 
OR move98 LIKE '%Aerial Ace' 
OR move99 LIKE '%Aerial Ace' 
OR move100 LIKE '%Aerial Ace' 
OR move101 LIKE '%Aerial Ace' 
OR move102 LIKE '%Aerial Ace' 
OR move103 LIKE '%Aerial Ace' 
OR move104 LIKE '%Aerial Ace' 
OR move105 LIKE '%Aerial Ace' 
OR move106 LIKE '%Aerial Ace' 
OR move107 LIKE '%Aerial Ace' 
OR move108 LIKE '%Aerial Ace' 
OR move109 LIKE '%Aerial Ace' 
OR move110 LIKE '%Aerial Ace' 
OR move111 LIKE '%Aerial Ace' 
OR move112 LIKE '%Aerial Ace' 
OR move113 LIKE '%Aerial Ace' 
OR move114 LIKE '%Aerial Ace' 
OR move115 LIKE '%Aerial Ace' 
OR move116 LIKE '%Aerial Ace' 
OR move117 LIKE '%Aerial Ace' 
OR move118 LIKE '%Aerial Ace' 
OR move119 LIKE '%Aerial Ace' 
OR move120 LIKE '%Aerial Ace' 
OR move121 LIKE '%Aerial Ace' 
OR move122 LIKE '%Aerial Ace' 
OR move123 LIKE '%Aerial Ace' 
OR move124 LIKE '%Aerial Ace' 
OR move125 LIKE '%Aerial Ace' 
OR move126 LIKE '%Aerial Ace' 
OR move127 LIKE '%Aerial Ace' 
OR move128 LIKE '%Aerial Ace' 
OR move129 LIKE '%Aerial Ace' 
OR move130 LIKE '%Aerial Ace' 
OR move131 LIKE '%Aerial Ace' 
OR move132 LIKE '%Aerial Ace' 
OR move133 LIKE '%Aerial Ace' 
OR move134 LIKE '%Aerial Ace' 
OR move135 LIKE '%Aerial Ace' 
OR move136 LIKE '%Aerial Ace' 
OR move137 LIKE '%Aerial Ace' 
OR move138 LIKE '%Aerial Ace' 
OR move139 LIKE '%Aerial Ace' 
OR move140 LIKE '%Aerial Ace' 
OR move141 LIKE '%Aerial Ace' 
OR move142 LIKE '%Aerial Ace' 
OR move143 LIKE '%Aerial Ace' 
OR move144 LIKE '%Aerial Ace' 
OR move145 LIKE '%Aerial Ace' 
OR move146 LIKE '%Aerial Ace' 
OR move147 LIKE '%Aerial Ace' 
OR move148 LIKE '%Aerial Ace' 
OR move149 LIKE '%Aerial Ace' 
OR move150 LIKE '%Aerial Ace' 
OR move151 LIKE '%Aerial Ace' 
OR move152 LIKE '%Aerial Ace' 
OR move153 LIKE '%Aerial Ace' 
OR move154 LIKE '%Aerial Ace' 
OR move155 LIKE '%Aerial Ace' 
OR move156 LIKE '%Aerial Ace' 
OR move157 LIKE '%Aerial Ace' 
OR move158 LIKE '%Aerial Ace' 
OR move159 LIKE '%Aerial Ace' 
OR move160 LIKE '%Aerial Ace' 
OR move161 LIKE '%Aerial Ace' 
OR move162 LIKE '%Aerial Ace' 
OR move163 LIKE '%Aerial Ace' 
OR move164 LIKE '%Aerial Ace' 
OR move165 LIKE '%Aerial Ace' 
OR move166 LIKE '%Aerial Ace' 
OR move167 LIKE '%Aerial Ace' 
OR move168 LIKE '%Aerial Ace' 
OR move169 LIKE '%Aerial Ace' 
OR move170 LIKE '%Aerial Ace' 
OR move171 LIKE '%Aerial Ace' 
OR move172 LIKE '%Aerial Ace' 
OR move173 LIKE '%Aerial Ace';
"""

#fetchall method (used by read_query) returns a list of tuples
aerial_ace_learners = read_query(connection, q6)
display(aerial_ace_learners)
# Out:
# MySQL Database connection successful
# [('Aerial Ace', 327)]

# %%
shockwave_string = ""

for x in range(174): 
    shockwave_string += "OR move"+str(x)+" LIKE '%Shock wave' \n"

# %%
print(shockwave_string)
# Out:
# OR move0 LIKE '%Shock wave'
# OR move1 LIKE '%Shock wave'
# OR move2 LIKE '%Shock wave'
# OR move3 LIKE '%Shock wave'
# OR move4 LIKE '%Shock wave'
# OR move5 LIKE '%Shock wave'
# OR move6 LIKE '%Shock wave'
# OR move7 LIKE '%Shock wave'
# OR move8 LIKE '%Shock wave'
# OR move9 LIKE '%Shock wave'
# OR move10 LIKE '%Shock wave'
# OR move11 LIKE '%Shock wave'
# OR move12 LIKE '%Shock wave'
# OR move13 LIKE '%Shock wave'
# OR move14 LIKE '%Shock wave'
# OR move15 LIKE '%Shock wave'
# OR move16 LIKE '%Shock wave'
# OR move17 LIKE '%Shock wave'
# OR move18 LIKE '%Shock wave'
# OR move19 LIKE '%Shock wave'
# OR move20 LIKE '%Shock wave'
# OR move21 LIKE '%Shock wave'
# OR move22 LIKE '%Shock wave'
# OR move23 LIKE '%Shock wave'
# OR move24 LIKE '%Shock wave'
# OR move25 LIKE '%Shock wave'
# OR move26 LIKE '%Shock wave'
# OR move27 LIKE '%Shock wave'
# OR move28 LIKE '%Shock wave'
# OR move29 LIKE '%Shock wave'
# OR move30 LIKE '%Shock wave'
# OR move31 LIKE '%Shock wave'
# OR move32 LIKE '%Shock wave'
# OR move33 LIKE '%Shock wave'
# OR move34 LIKE '%Shock wave'
# OR move35 LIKE '%Shock wave'
# OR move36 LIKE '%Shock wave'
# OR move37 LIKE '%Shock wave'
# OR move38 LIKE '%Shock wave'
# OR move39 LIKE '%Shock wave'
# OR move40 LIKE '%Shock wave'
# OR move41 LIKE '%Shock wave'
# OR move42 LIKE '%Shock wave'
# OR move43 LIKE '%Shock wave'
# OR move44 LIKE '%Shock wave'
# OR move45 LIKE '%Shock wave'
# OR move46 LIKE '%Shock wave'
# OR move47 LIKE '%Shock wave'
# OR move48 LIKE '%Shock wave'
# OR move49 LIKE '%Shock wave'
# OR move50 LIKE '%Shock wave'
# OR move51 LIKE '%Shock wave'
# OR move52 LIKE '%Shock wave'
# OR move53 LIKE '%Shock wave'
# OR move54 LIKE '%Shock wave'
# OR move55 LIKE '%Shock wave'
# OR move56 LIKE '%Shock wave'
# OR move57 LIKE '%Shock wave'
# OR move58 LIKE '%Shock wave'
# OR move59 LIKE '%Shock wave'
# OR move60 LIKE '%Shock wave'
# OR move61 LIKE '%Shock wave'
# OR move62 LIKE '%Shock wave'
# OR move63 LIKE '%Shock wave'
# OR move64 LIKE '%Shock wave'
# OR move65 LIKE '%Shock wave'
# OR move66 LIKE '%Shock wave'
# OR move67 LIKE '%Shock wave'
# OR move68 LIKE '%Shock wave'
# OR move69 LIKE '%Shock wave'
# OR move70 LIKE '%Shock wave'
# OR move71 LIKE '%Shock wave'
# OR move72 LIKE '%Shock wave'
# OR move73 LIKE '%Shock wave'
# OR move74 LIKE '%Shock wave'
# OR move75 LIKE '%Shock wave'
# OR move76 LIKE '%Shock wave'
# OR move77 LIKE '%Shock wave'
# OR move78 LIKE '%Shock wave'
# OR move79 LIKE '%Shock wave'
# OR move80 LIKE '%Shock wave'
# OR move81 LIKE '%Shock wave'
# OR move82 LIKE '%Shock wave'
# OR move83 LIKE '%Shock wave'
# OR move84 LIKE '%Shock wave'
# OR move85 LIKE '%Shock wave'
# OR move86 LIKE '%Shock wave'
# OR move87 LIKE '%Shock wave'
# OR move88 LIKE '%Shock wave'
# OR move89 LIKE '%Shock wave'
# OR move90 LIKE '%Shock wave'
# OR move91 LIKE '%Shock wave'
# OR move92 LIKE '%Shock wave'
# OR move93 LIKE '%Shock wave'
# OR move94 LIKE '%Shock wave'
# OR move95 LIKE '%Shock wave'
# OR move96 LIKE '%Shock wave'
# OR move97 LIKE '%Shock wave'
# OR move98 LIKE '%Shock wave'
# OR move99 LIKE '%Shock wave'
# OR move100 LIKE '%Shock wave'
# OR move101 LIKE '%Shock wave'
# OR move102 LIKE '%Shock wave'
# OR move103 LIKE '%Shock wave'
# OR move104 LIKE '%Shock wave'
# OR move105 LIKE '%Shock wave'
# OR move106 LIKE '%Shock wave'
# OR move107 LIKE '%Shock wave'
# OR move108 LIKE '%Shock wave'
# OR move109 LIKE '%Shock wave'
# OR move110 LIKE '%Shock wave'
# OR move111 LIKE '%Shock wave'
# OR move112 LIKE '%Shock wave'
# OR move113 LIKE '%Shock wave'
# OR move114 LIKE '%Shock wave'
# OR move115 LIKE '%Shock wave'
# OR move116 LIKE '%Shock wave'
# OR move117 LIKE '%Shock wave'
# OR move118 LIKE '%Shock wave'
# OR move119 LIKE '%Shock wave'
# OR move120 LIKE '%Shock wave'
# OR move121 LIKE '%Shock wave'
# OR move122 LIKE '%Shock wave'
# OR move123 LIKE '%Shock wave'
# OR move124 LIKE '%Shock wave'
# OR move125 LIKE '%Shock wave'
# OR move126 LIKE '%Shock wave'
# OR move127 LIKE '%Shock wave'
# OR move128 LIKE '%Shock wave'
# OR move129 LIKE '%Shock wave'
# OR move130 LIKE '%Shock wave'
# OR move131 LIKE '%Shock wave'
# OR move132 LIKE '%Shock wave'
# OR move133 LIKE '%Shock wave'
# OR move134 LIKE '%Shock wave'
# OR move135 LIKE '%Shock wave'
# OR move136 LIKE '%Shock wave'
# OR move137 LIKE '%Shock wave'
# OR move138 LIKE '%Shock wave'
# OR move139 LIKE '%Shock wave'
# OR move140 LIKE '%Shock wave'
# OR move141 LIKE '%Shock wave'
# OR move142 LIKE '%Shock wave'
# OR move143 LIKE '%Shock wave'
# OR move144 LIKE '%Shock wave'
# OR move145 LIKE '%Shock wave'
# OR move146 LIKE '%Shock wave'
# OR move147 LIKE '%Shock wave'
# OR move148 LIKE '%Shock wave'
# OR move149 LIKE '%Shock wave'
# OR move150 LIKE '%Shock wave'
# OR move151 LIKE '%Shock wave'
# OR move152 LIKE '%Shock wave'
# OR move153 LIKE '%Shock wave'
# OR move154 LIKE '%Shock wave'
# OR move155 LIKE '%Shock wave'
# OR move156 LIKE '%Shock wave'
# OR move157 LIKE '%Shock wave'
# OR move158 LIKE '%Shock wave'
# OR move159 LIKE '%Shock wave'
# OR move160 LIKE '%Shock wave'
# OR move161 LIKE '%Shock wave'
# OR move162 LIKE '%Shock wave'
# OR move163 LIKE '%Shock wave'
# OR move164 LIKE '%Shock wave'
# OR move165 LIKE '%Shock wave'
# OR move166 LIKE '%Shock wave'
# OR move167 LIKE '%Shock wave'
# OR move168 LIKE '%Shock wave'
# OR move169 LIKE '%Shock wave'
# OR move170 LIKE '%Shock wave'
# OR move171 LIKE '%Shock wave'
# OR move172 LIKE '%Shock wave'
# OR move173 LIKE '%Shock wave'

# %%
q7 = """SELECT 'Shock wave', COUNT(species) FROM moveset
WHERE move1 LIKE '%Shock wave'
OR move2 LIKE '%Shock wave' 
OR move3 LIKE '%Shock wave' 
OR move4 LIKE '%Shock wave' 
OR move5 LIKE '%Shock wave' 
OR move6 LIKE '%Shock wave' 
OR move7 LIKE '%Shock wave' 
OR move8 LIKE '%Shock wave' 
OR move9 LIKE '%Shock wave' 
OR move10 LIKE '%Shock wave' 
OR move11 LIKE '%Shock wave' 
OR move12 LIKE '%Shock wave' 
OR move13 LIKE '%Shock wave' 
OR move14 LIKE '%Shock wave' 
OR move15 LIKE '%Shock wave' 
OR move16 LIKE '%Shock wave' 
OR move17 LIKE '%Shock wave' 
OR move18 LIKE '%Shock wave' 
OR move19 LIKE '%Shock wave' 
OR move20 LIKE '%Shock wave' 
OR move21 LIKE '%Shock wave' 
OR move22 LIKE '%Shock wave' 
OR move23 LIKE '%Shock wave' 
OR move24 LIKE '%Shock wave' 
OR move25 LIKE '%Shock wave' 
OR move26 LIKE '%Shock wave' 
OR move27 LIKE '%Shock wave' 
OR move28 LIKE '%Shock wave' 
OR move29 LIKE '%Shock wave' 
OR move30 LIKE '%Shock wave' 
OR move31 LIKE '%Shock wave' 
OR move32 LIKE '%Shock wave' 
OR move33 LIKE '%Shock wave' 
OR move34 LIKE '%Shock wave' 
OR move35 LIKE '%Shock wave' 
OR move36 LIKE '%Shock wave' 
OR move37 LIKE '%Shock wave' 
OR move38 LIKE '%Shock wave' 
OR move39 LIKE '%Shock wave' 
OR move40 LIKE '%Shock wave' 
OR move41 LIKE '%Shock wave' 
OR move42 LIKE '%Shock wave' 
OR move43 LIKE '%Shock wave' 
OR move44 LIKE '%Shock wave' 
OR move45 LIKE '%Shock wave' 
OR move46 LIKE '%Shock wave' 
OR move47 LIKE '%Shock wave' 
OR move48 LIKE '%Shock wave' 
OR move49 LIKE '%Shock wave' 
OR move50 LIKE '%Shock wave' 
OR move51 LIKE '%Shock wave' 
OR move52 LIKE '%Shock wave' 
OR move53 LIKE '%Shock wave' 
OR move54 LIKE '%Shock wave' 
OR move55 LIKE '%Shock wave' 
OR move56 LIKE '%Shock wave' 
OR move57 LIKE '%Shock wave' 
OR move58 LIKE '%Shock wave' 
OR move59 LIKE '%Shock wave' 
OR move60 LIKE '%Shock wave' 
OR move61 LIKE '%Shock wave' 
OR move62 LIKE '%Shock wave' 
OR move63 LIKE '%Shock wave' 
OR move64 LIKE '%Shock wave' 
OR move65 LIKE '%Shock wave' 
OR move66 LIKE '%Shock wave' 
OR move67 LIKE '%Shock wave' 
OR move68 LIKE '%Shock wave' 
OR move69 LIKE '%Shock wave' 
OR move70 LIKE '%Shock wave' 
OR move71 LIKE '%Shock wave' 
OR move72 LIKE '%Shock wave' 
OR move73 LIKE '%Shock wave' 
OR move74 LIKE '%Shock wave' 
OR move75 LIKE '%Shock wave' 
OR move76 LIKE '%Shock wave' 
OR move77 LIKE '%Shock wave' 
OR move78 LIKE '%Shock wave' 
OR move79 LIKE '%Shock wave' 
OR move80 LIKE '%Shock wave' 
OR move81 LIKE '%Shock wave' 
OR move82 LIKE '%Shock wave' 
OR move83 LIKE '%Shock wave' 
OR move84 LIKE '%Shock wave' 
OR move85 LIKE '%Shock wave' 
OR move86 LIKE '%Shock wave' 
OR move87 LIKE '%Shock wave' 
OR move88 LIKE '%Shock wave' 
OR move89 LIKE '%Shock wave' 
OR move90 LIKE '%Shock wave' 
OR move91 LIKE '%Shock wave' 
OR move92 LIKE '%Shock wave' 
OR move93 LIKE '%Shock wave' 
OR move94 LIKE '%Shock wave' 
OR move95 LIKE '%Shock wave' 
OR move96 LIKE '%Shock wave' 
OR move97 LIKE '%Shock wave' 
OR move98 LIKE '%Shock wave' 
OR move99 LIKE '%Shock wave' 
OR move100 LIKE '%Shock wave' 
OR move101 LIKE '%Shock wave' 
OR move102 LIKE '%Shock wave' 
OR move103 LIKE '%Shock wave' 
OR move104 LIKE '%Shock wave' 
OR move105 LIKE '%Shock wave' 
OR move106 LIKE '%Shock wave' 
OR move107 LIKE '%Shock wave' 
OR move108 LIKE '%Shock wave' 
OR move109 LIKE '%Shock wave' 
OR move110 LIKE '%Shock wave' 
OR move111 LIKE '%Shock wave' 
OR move112 LIKE '%Shock wave' 
OR move113 LIKE '%Shock wave' 
OR move114 LIKE '%Shock wave' 
OR move115 LIKE '%Shock wave' 
OR move116 LIKE '%Shock wave' 
OR move117 LIKE '%Shock wave' 
OR move118 LIKE '%Shock wave' 
OR move119 LIKE '%Shock wave' 
OR move120 LIKE '%Shock wave' 
OR move121 LIKE '%Shock wave' 
OR move122 LIKE '%Shock wave' 
OR move123 LIKE '%Shock wave' 
OR move124 LIKE '%Shock wave' 
OR move125 LIKE '%Shock wave' 
OR move126 LIKE '%Shock wave' 
OR move127 LIKE '%Shock wave' 
OR move128 LIKE '%Shock wave' 
OR move129 LIKE '%Shock wave' 
OR move130 LIKE '%Shock wave' 
OR move131 LIKE '%Shock wave' 
OR move132 LIKE '%Shock wave' 
OR move133 LIKE '%Shock wave' 
OR move134 LIKE '%Shock wave' 
OR move135 LIKE '%Shock wave' 
OR move136 LIKE '%Shock wave' 
OR move137 LIKE '%Shock wave' 
OR move138 LIKE '%Shock wave' 
OR move139 LIKE '%Shock wave' 
OR move140 LIKE '%Shock wave' 
OR move141 LIKE '%Shock wave' 
OR move142 LIKE '%Shock wave' 
OR move143 LIKE '%Shock wave' 
OR move144 LIKE '%Shock wave' 
OR move145 LIKE '%Shock wave' 
OR move146 LIKE '%Shock wave' 
OR move147 LIKE '%Shock wave' 
OR move148 LIKE '%Shock wave' 
OR move149 LIKE '%Shock wave' 
OR move150 LIKE '%Shock wave' 
OR move151 LIKE '%Shock wave' 
OR move152 LIKE '%Shock wave' 
OR move153 LIKE '%Shock wave' 
OR move154 LIKE '%Shock wave' 
OR move155 LIKE '%Shock wave' 
OR move156 LIKE '%Shock wave' 
OR move157 LIKE '%Shock wave' 
OR move158 LIKE '%Shock wave' 
OR move159 LIKE '%Shock wave' 
OR move160 LIKE '%Shock wave' 
OR move161 LIKE '%Shock wave' 
OR move162 LIKE '%Shock wave' 
OR move163 LIKE '%Shock wave' 
OR move164 LIKE '%Shock wave' 
OR move165 LIKE '%Shock wave' 
OR move166 LIKE '%Shock wave' 
OR move167 LIKE '%Shock wave' 
OR move168 LIKE '%Shock wave' 
OR move169 LIKE '%Shock wave' 
OR move170 LIKE '%Shock wave' 
OR move171 LIKE '%Shock wave' 
OR move172 LIKE '%Shock wave' 
OR move173 LIKE '%Shock wave';
"""

#fetchall method (used by read_query) returns a list of tuples
shockwave_learners = read_query(connection, q7)
display(shockwave_learners)
# Out:
# [('Shock wave', 273)]

# %%
aura_sphere_string = ""

for x in range(174): 
    aura_sphere_string += "OR move"+str(x)+" LIKE '%Aura sphere' \n"

# %%
q8 = """SELECT 'Aura sphere', COUNT(species) FROM moveset
WHERE move1 LIKE '%Aura sphere'
OR move2 LIKE '%Aura sphere' 
OR move3 LIKE '%Aura sphere' 
OR move4 LIKE '%Aura sphere' 
OR move5 LIKE '%Aura sphere' 
OR move6 LIKE '%Aura sphere' 
OR move7 LIKE '%Aura sphere' 
OR move8 LIKE '%Aura sphere' 
OR move9 LIKE '%Aura sphere' 
OR move10 LIKE '%Aura sphere' 
OR move11 LIKE '%Aura sphere' 
OR move12 LIKE '%Aura sphere' 
OR move13 LIKE '%Aura sphere' 
OR move14 LIKE '%Aura sphere' 
OR move15 LIKE '%Aura sphere' 
OR move16 LIKE '%Aura sphere' 
OR move17 LIKE '%Aura sphere' 
OR move18 LIKE '%Aura sphere' 
OR move19 LIKE '%Aura sphere' 
OR move20 LIKE '%Aura sphere' 
OR move21 LIKE '%Aura sphere' 
OR move22 LIKE '%Aura sphere' 
OR move23 LIKE '%Aura sphere' 
OR move24 LIKE '%Aura sphere' 
OR move25 LIKE '%Aura sphere' 
OR move26 LIKE '%Aura sphere' 
OR move27 LIKE '%Aura sphere' 
OR move28 LIKE '%Aura sphere' 
OR move29 LIKE '%Aura sphere' 
OR move30 LIKE '%Aura sphere' 
OR move31 LIKE '%Aura sphere' 
OR move32 LIKE '%Aura sphere' 
OR move33 LIKE '%Aura sphere' 
OR move34 LIKE '%Aura sphere' 
OR move35 LIKE '%Aura sphere' 
OR move36 LIKE '%Aura sphere' 
OR move37 LIKE '%Aura sphere' 
OR move38 LIKE '%Aura sphere' 
OR move39 LIKE '%Aura sphere' 
OR move40 LIKE '%Aura sphere' 
OR move41 LIKE '%Aura sphere' 
OR move42 LIKE '%Aura sphere' 
OR move43 LIKE '%Aura sphere' 
OR move44 LIKE '%Aura sphere' 
OR move45 LIKE '%Aura sphere' 
OR move46 LIKE '%Aura sphere' 
OR move47 LIKE '%Aura sphere' 
OR move48 LIKE '%Aura sphere' 
OR move49 LIKE '%Aura sphere' 
OR move50 LIKE '%Aura sphere' 
OR move51 LIKE '%Aura sphere' 
OR move52 LIKE '%Aura sphere' 
OR move53 LIKE '%Aura sphere' 
OR move54 LIKE '%Aura sphere' 
OR move55 LIKE '%Aura sphere' 
OR move56 LIKE '%Aura sphere' 
OR move57 LIKE '%Aura sphere' 
OR move58 LIKE '%Aura sphere' 
OR move59 LIKE '%Aura sphere' 
OR move60 LIKE '%Aura sphere' 
OR move61 LIKE '%Aura sphere' 
OR move62 LIKE '%Aura sphere' 
OR move63 LIKE '%Aura sphere' 
OR move64 LIKE '%Aura sphere' 
OR move65 LIKE '%Aura sphere' 
OR move66 LIKE '%Aura sphere' 
OR move67 LIKE '%Aura sphere' 
OR move68 LIKE '%Aura sphere' 
OR move69 LIKE '%Aura sphere' 
OR move70 LIKE '%Aura sphere' 
OR move71 LIKE '%Aura sphere' 
OR move72 LIKE '%Aura sphere' 
OR move73 LIKE '%Aura sphere' 
OR move74 LIKE '%Aura sphere' 
OR move75 LIKE '%Aura sphere' 
OR move76 LIKE '%Aura sphere' 
OR move77 LIKE '%Aura sphere' 
OR move78 LIKE '%Aura sphere' 
OR move79 LIKE '%Aura sphere' 
OR move80 LIKE '%Aura sphere' 
OR move81 LIKE '%Aura sphere' 
OR move82 LIKE '%Aura sphere' 
OR move83 LIKE '%Aura sphere' 
OR move84 LIKE '%Aura sphere' 
OR move85 LIKE '%Aura sphere' 
OR move86 LIKE '%Aura sphere' 
OR move87 LIKE '%Aura sphere' 
OR move88 LIKE '%Aura sphere' 
OR move89 LIKE '%Aura sphere' 
OR move90 LIKE '%Aura sphere' 
OR move91 LIKE '%Aura sphere' 
OR move92 LIKE '%Aura sphere' 
OR move93 LIKE '%Aura sphere' 
OR move94 LIKE '%Aura sphere' 
OR move95 LIKE '%Aura sphere' 
OR move96 LIKE '%Aura sphere' 
OR move97 LIKE '%Aura sphere' 
OR move98 LIKE '%Aura sphere' 
OR move99 LIKE '%Aura sphere' 
OR move100 LIKE '%Aura sphere' 
OR move101 LIKE '%Aura sphere' 
OR move102 LIKE '%Aura sphere' 
OR move103 LIKE '%Aura sphere' 
OR move104 LIKE '%Aura sphere' 
OR move105 LIKE '%Aura sphere' 
OR move106 LIKE '%Aura sphere' 
OR move107 LIKE '%Aura sphere' 
OR move108 LIKE '%Aura sphere' 
OR move109 LIKE '%Aura sphere' 
OR move110 LIKE '%Aura sphere' 
OR move111 LIKE '%Aura sphere' 
OR move112 LIKE '%Aura sphere' 
OR move113 LIKE '%Aura sphere' 
OR move114 LIKE '%Aura sphere' 
OR move115 LIKE '%Aura sphere' 
OR move116 LIKE '%Aura sphere' 
OR move117 LIKE '%Aura sphere' 
OR move118 LIKE '%Aura sphere' 
OR move119 LIKE '%Aura sphere' 
OR move120 LIKE '%Aura sphere' 
OR move121 LIKE '%Aura sphere' 
OR move122 LIKE '%Aura sphere' 
OR move123 LIKE '%Aura sphere' 
OR move124 LIKE '%Aura sphere' 
OR move125 LIKE '%Aura sphere' 
OR move126 LIKE '%Aura sphere' 
OR move127 LIKE '%Aura sphere' 
OR move128 LIKE '%Aura sphere' 
OR move129 LIKE '%Aura sphere' 
OR move130 LIKE '%Aura sphere' 
OR move131 LIKE '%Aura sphere' 
OR move132 LIKE '%Aura sphere' 
OR move133 LIKE '%Aura sphere' 
OR move134 LIKE '%Aura sphere' 
OR move135 LIKE '%Aura sphere' 
OR move136 LIKE '%Aura sphere' 
OR move137 LIKE '%Aura sphere' 
OR move138 LIKE '%Aura sphere' 
OR move139 LIKE '%Aura sphere' 
OR move140 LIKE '%Aura sphere' 
OR move141 LIKE '%Aura sphere' 
OR move142 LIKE '%Aura sphere' 
OR move143 LIKE '%Aura sphere' 
OR move144 LIKE '%Aura sphere' 
OR move145 LIKE '%Aura sphere' 
OR move146 LIKE '%Aura sphere' 
OR move147 LIKE '%Aura sphere' 
OR move148 LIKE '%Aura sphere' 
OR move149 LIKE '%Aura sphere' 
OR move150 LIKE '%Aura sphere' 
OR move151 LIKE '%Aura sphere' 
OR move152 LIKE '%Aura sphere' 
OR move153 LIKE '%Aura sphere' 
OR move154 LIKE '%Aura sphere' 
OR move155 LIKE '%Aura sphere' 
OR move156 LIKE '%Aura sphere' 
OR move157 LIKE '%Aura sphere' 
OR move158 LIKE '%Aura sphere' 
OR move159 LIKE '%Aura sphere' 
OR move160 LIKE '%Aura sphere' 
OR move161 LIKE '%Aura sphere' 
OR move162 LIKE '%Aura sphere' 
OR move163 LIKE '%Aura sphere' 
OR move164 LIKE '%Aura sphere' 
OR move165 LIKE '%Aura sphere' 
OR move166 LIKE '%Aura sphere' 
OR move167 LIKE '%Aura sphere' 
OR move168 LIKE '%Aura sphere' 
OR move169 LIKE '%Aura sphere' 
OR move170 LIKE '%Aura sphere' 
OR move171 LIKE '%Aura sphere' 
OR move172 LIKE '%Aura sphere' 
OR move173 LIKE '%Aura sphere' 
;
"""

#fetchall method (used by read_query) returns a list of tuples
aura_sphere_learners = read_query(connection, q8)
display(aura_sphere_learners)
# Out:
# [('Aura sphere', 20)]

# %%
magical_leaf_string = ""

for x in range(174): 
    magical_leaf_string += "OR move"+str(x)+" LIKE '%Magical leaf' \n"

# %%
q9 = """SELECT 'Magical leaf', COUNT(species) FROM moveset
WHERE move1 LIKE '%Magical leaf'
OR move2 LIKE '%Magical leaf' 
OR move3 LIKE '%Magical leaf' 
OR move4 LIKE '%Magical leaf' 
OR move5 LIKE '%Magical leaf' 
OR move6 LIKE '%Magical leaf' 
OR move7 LIKE '%Magical leaf' 
OR move8 LIKE '%Magical leaf' 
OR move9 LIKE '%Magical leaf' 
OR move10 LIKE '%Magical leaf' 
OR move11 LIKE '%Magical leaf' 
OR move12 LIKE '%Magical leaf' 
OR move13 LIKE '%Magical leaf' 
OR move14 LIKE '%Magical leaf' 
OR move15 LIKE '%Magical leaf' 
OR move16 LIKE '%Magical leaf' 
OR move17 LIKE '%Magical leaf' 
OR move18 LIKE '%Magical leaf' 
OR move19 LIKE '%Magical leaf' 
OR move20 LIKE '%Magical leaf' 
OR move21 LIKE '%Magical leaf' 
OR move22 LIKE '%Magical leaf' 
OR move23 LIKE '%Magical leaf' 
OR move24 LIKE '%Magical leaf' 
OR move25 LIKE '%Magical leaf' 
OR move26 LIKE '%Magical leaf' 
OR move27 LIKE '%Magical leaf' 
OR move28 LIKE '%Magical leaf' 
OR move29 LIKE '%Magical leaf' 
OR move30 LIKE '%Magical leaf' 
OR move31 LIKE '%Magical leaf' 
OR move32 LIKE '%Magical leaf' 
OR move33 LIKE '%Magical leaf' 
OR move34 LIKE '%Magical leaf' 
OR move35 LIKE '%Magical leaf' 
OR move36 LIKE '%Magical leaf' 
OR move37 LIKE '%Magical leaf' 
OR move38 LIKE '%Magical leaf' 
OR move39 LIKE '%Magical leaf' 
OR move40 LIKE '%Magical leaf' 
OR move41 LIKE '%Magical leaf' 
OR move42 LIKE '%Magical leaf' 
OR move43 LIKE '%Magical leaf' 
OR move44 LIKE '%Magical leaf' 
OR move45 LIKE '%Magical leaf' 
OR move46 LIKE '%Magical leaf' 
OR move47 LIKE '%Magical leaf' 
OR move48 LIKE '%Magical leaf' 
OR move49 LIKE '%Magical leaf' 
OR move50 LIKE '%Magical leaf' 
OR move51 LIKE '%Magical leaf' 
OR move52 LIKE '%Magical leaf' 
OR move53 LIKE '%Magical leaf' 
OR move54 LIKE '%Magical leaf' 
OR move55 LIKE '%Magical leaf' 
OR move56 LIKE '%Magical leaf' 
OR move57 LIKE '%Magical leaf' 
OR move58 LIKE '%Magical leaf' 
OR move59 LIKE '%Magical leaf' 
OR move60 LIKE '%Magical leaf' 
OR move61 LIKE '%Magical leaf' 
OR move62 LIKE '%Magical leaf' 
OR move63 LIKE '%Magical leaf' 
OR move64 LIKE '%Magical leaf' 
OR move65 LIKE '%Magical leaf' 
OR move66 LIKE '%Magical leaf' 
OR move67 LIKE '%Magical leaf' 
OR move68 LIKE '%Magical leaf' 
OR move69 LIKE '%Magical leaf' 
OR move70 LIKE '%Magical leaf' 
OR move71 LIKE '%Magical leaf' 
OR move72 LIKE '%Magical leaf' 
OR move73 LIKE '%Magical leaf' 
OR move74 LIKE '%Magical leaf' 
OR move75 LIKE '%Magical leaf' 
OR move76 LIKE '%Magical leaf' 
OR move77 LIKE '%Magical leaf' 
OR move78 LIKE '%Magical leaf' 
OR move79 LIKE '%Magical leaf' 
OR move80 LIKE '%Magical leaf' 
OR move81 LIKE '%Magical leaf' 
OR move82 LIKE '%Magical leaf' 
OR move83 LIKE '%Magical leaf' 
OR move84 LIKE '%Magical leaf' 
OR move85 LIKE '%Magical leaf' 
OR move86 LIKE '%Magical leaf' 
OR move87 LIKE '%Magical leaf' 
OR move88 LIKE '%Magical leaf' 
OR move89 LIKE '%Magical leaf' 
OR move90 LIKE '%Magical leaf' 
OR move91 LIKE '%Magical leaf' 
OR move92 LIKE '%Magical leaf' 
OR move93 LIKE '%Magical leaf' 
OR move94 LIKE '%Magical leaf' 
OR move95 LIKE '%Magical leaf' 
OR move96 LIKE '%Magical leaf' 
OR move97 LIKE '%Magical leaf' 
OR move98 LIKE '%Magical leaf' 
OR move99 LIKE '%Magical leaf' 
OR move100 LIKE '%Magical leaf' 
OR move101 LIKE '%Magical leaf' 
OR move102 LIKE '%Magical leaf' 
OR move103 LIKE '%Magical leaf' 
OR move104 LIKE '%Magical leaf' 
OR move105 LIKE '%Magical leaf' 
OR move106 LIKE '%Magical leaf' 
OR move107 LIKE '%Magical leaf' 
OR move108 LIKE '%Magical leaf' 
OR move109 LIKE '%Magical leaf' 
OR move110 LIKE '%Magical leaf' 
OR move111 LIKE '%Magical leaf' 
OR move112 LIKE '%Magical leaf' 
OR move113 LIKE '%Magical leaf' 
OR move114 LIKE '%Magical leaf' 
OR move115 LIKE '%Magical leaf' 
OR move116 LIKE '%Magical leaf' 
OR move117 LIKE '%Magical leaf' 
OR move118 LIKE '%Magical leaf' 
OR move119 LIKE '%Magical leaf' 
OR move120 LIKE '%Magical leaf' 
OR move121 LIKE '%Magical leaf' 
OR move122 LIKE '%Magical leaf' 
OR move123 LIKE '%Magical leaf' 
OR move124 LIKE '%Magical leaf' 
OR move125 LIKE '%Magical leaf' 
OR move126 LIKE '%Magical leaf' 
OR move127 LIKE '%Magical leaf' 
OR move128 LIKE '%Magical leaf' 
OR move129 LIKE '%Magical leaf' 
OR move130 LIKE '%Magical leaf' 
OR move131 LIKE '%Magical leaf' 
OR move132 LIKE '%Magical leaf' 
OR move133 LIKE '%Magical leaf' 
OR move134 LIKE '%Magical leaf' 
OR move135 LIKE '%Magical leaf' 
OR move136 LIKE '%Magical leaf' 
OR move137 LIKE '%Magical leaf' 
OR move138 LIKE '%Magical leaf' 
OR move139 LIKE '%Magical leaf' 
OR move140 LIKE '%Magical leaf' 
OR move141 LIKE '%Magical leaf' 
OR move142 LIKE '%Magical leaf' 
OR move143 LIKE '%Magical leaf' 
OR move144 LIKE '%Magical leaf' 
OR move145 LIKE '%Magical leaf' 
OR move146 LIKE '%Magical leaf' 
OR move147 LIKE '%Magical leaf' 
OR move148 LIKE '%Magical leaf' 
OR move149 LIKE '%Magical leaf' 
OR move150 LIKE '%Magical leaf' 
OR move151 LIKE '%Magical leaf' 
OR move152 LIKE '%Magical leaf' 
OR move153 LIKE '%Magical leaf' 
OR move154 LIKE '%Magical leaf' 
OR move155 LIKE '%Magical leaf' 
OR move156 LIKE '%Magical leaf' 
OR move157 LIKE '%Magical leaf' 
OR move158 LIKE '%Magical leaf' 
OR move159 LIKE '%Magical leaf' 
OR move160 LIKE '%Magical leaf' 
OR move161 LIKE '%Magical leaf' 
OR move162 LIKE '%Magical leaf' 
OR move163 LIKE '%Magical leaf' 
OR move164 LIKE '%Magical leaf' 
OR move165 LIKE '%Magical leaf' 
OR move166 LIKE '%Magical leaf' 
OR move167 LIKE '%Magical leaf' 
OR move168 LIKE '%Magical leaf' 
OR move169 LIKE '%Magical leaf' 
OR move170 LIKE '%Magical leaf' 
OR move171 LIKE '%Magical leaf' 
OR move172 LIKE '%Magical leaf' 
OR move173 LIKE '%Magical leaf';"""

magical_leaf_learners = read_query(connection, q9)
display(magical_leaf_learners)
# Out:
# [('Magical leaf', 65)]

# %%
swift_string = ""

for x in range(174): 
    swift_string += "OR move"+str(x)+" LIKE '%Swift' \n"

# %%
q10 = """SELECT 'Swift', COUNT(species) FROM moveset
WHERE move1 LIKE '%Swift'
OR move2 LIKE '%Swift' 
OR move3 LIKE '%Swift' 
OR move4 LIKE '%Swift' 
OR move5 LIKE '%Swift' 
OR move6 LIKE '%Swift' 
OR move7 LIKE '%Swift' 
OR move8 LIKE '%Swift' 
OR move9 LIKE '%Swift' 
OR move10 LIKE '%Swift' 
OR move11 LIKE '%Swift' 
OR move12 LIKE '%Swift' 
OR move13 LIKE '%Swift' 
OR move14 LIKE '%Swift' 
OR move15 LIKE '%Swift' 
OR move16 LIKE '%Swift' 
OR move17 LIKE '%Swift' 
OR move18 LIKE '%Swift' 
OR move19 LIKE '%Swift' 
OR move20 LIKE '%Swift' 
OR move21 LIKE '%Swift' 
OR move22 LIKE '%Swift' 
OR move23 LIKE '%Swift' 
OR move24 LIKE '%Swift' 
OR move25 LIKE '%Swift' 
OR move26 LIKE '%Swift' 
OR move27 LIKE '%Swift' 
OR move28 LIKE '%Swift' 
OR move29 LIKE '%Swift' 
OR move30 LIKE '%Swift' 
OR move31 LIKE '%Swift' 
OR move32 LIKE '%Swift' 
OR move33 LIKE '%Swift' 
OR move34 LIKE '%Swift' 
OR move35 LIKE '%Swift' 
OR move36 LIKE '%Swift' 
OR move37 LIKE '%Swift' 
OR move38 LIKE '%Swift' 
OR move39 LIKE '%Swift' 
OR move40 LIKE '%Swift' 
OR move41 LIKE '%Swift' 
OR move42 LIKE '%Swift' 
OR move43 LIKE '%Swift' 
OR move44 LIKE '%Swift' 
OR move45 LIKE '%Swift' 
OR move46 LIKE '%Swift' 
OR move47 LIKE '%Swift' 
OR move48 LIKE '%Swift' 
OR move49 LIKE '%Swift' 
OR move50 LIKE '%Swift' 
OR move51 LIKE '%Swift' 
OR move52 LIKE '%Swift' 
OR move53 LIKE '%Swift' 
OR move54 LIKE '%Swift' 
OR move55 LIKE '%Swift' 
OR move56 LIKE '%Swift' 
OR move57 LIKE '%Swift' 
OR move58 LIKE '%Swift' 
OR move59 LIKE '%Swift' 
OR move60 LIKE '%Swift' 
OR move61 LIKE '%Swift' 
OR move62 LIKE '%Swift' 
OR move63 LIKE '%Swift' 
OR move64 LIKE '%Swift' 
OR move65 LIKE '%Swift' 
OR move66 LIKE '%Swift' 
OR move67 LIKE '%Swift' 
OR move68 LIKE '%Swift' 
OR move69 LIKE '%Swift' 
OR move70 LIKE '%Swift' 
OR move71 LIKE '%Swift' 
OR move72 LIKE '%Swift' 
OR move73 LIKE '%Swift' 
OR move74 LIKE '%Swift' 
OR move75 LIKE '%Swift' 
OR move76 LIKE '%Swift' 
OR move77 LIKE '%Swift' 
OR move78 LIKE '%Swift' 
OR move79 LIKE '%Swift' 
OR move80 LIKE '%Swift' 
OR move81 LIKE '%Swift' 
OR move82 LIKE '%Swift' 
OR move83 LIKE '%Swift' 
OR move84 LIKE '%Swift' 
OR move85 LIKE '%Swift' 
OR move86 LIKE '%Swift' 
OR move87 LIKE '%Swift' 
OR move88 LIKE '%Swift' 
OR move89 LIKE '%Swift' 
OR move90 LIKE '%Swift' 
OR move91 LIKE '%Swift' 
OR move92 LIKE '%Swift' 
OR move93 LIKE '%Swift' 
OR move94 LIKE '%Swift' 
OR move95 LIKE '%Swift' 
OR move96 LIKE '%Swift' 
OR move97 LIKE '%Swift' 
OR move98 LIKE '%Swift' 
OR move99 LIKE '%Swift' 
OR move100 LIKE '%Swift' 
OR move101 LIKE '%Swift' 
OR move102 LIKE '%Swift' 
OR move103 LIKE '%Swift' 
OR move104 LIKE '%Swift' 
OR move105 LIKE '%Swift' 
OR move106 LIKE '%Swift' 
OR move107 LIKE '%Swift' 
OR move108 LIKE '%Swift' 
OR move109 LIKE '%Swift' 
OR move110 LIKE '%Swift' 
OR move111 LIKE '%Swift' 
OR move112 LIKE '%Swift' 
OR move113 LIKE '%Swift' 
OR move114 LIKE '%Swift' 
OR move115 LIKE '%Swift' 
OR move116 LIKE '%Swift' 
OR move117 LIKE '%Swift' 
OR move118 LIKE '%Swift' 
OR move119 LIKE '%Swift' 
OR move120 LIKE '%Swift' 
OR move121 LIKE '%Swift' 
OR move122 LIKE '%Swift' 
OR move123 LIKE '%Swift' 
OR move124 LIKE '%Swift' 
OR move125 LIKE '%Swift' 
OR move126 LIKE '%Swift' 
OR move127 LIKE '%Swift' 
OR move128 LIKE '%Swift' 
OR move129 LIKE '%Swift' 
OR move130 LIKE '%Swift' 
OR move131 LIKE '%Swift' 
OR move132 LIKE '%Swift' 
OR move133 LIKE '%Swift' 
OR move134 LIKE '%Swift' 
OR move135 LIKE '%Swift' 
OR move136 LIKE '%Swift' 
OR move137 LIKE '%Swift' 
OR move138 LIKE '%Swift' 
OR move139 LIKE '%Swift' 
OR move140 LIKE '%Swift' 
OR move141 LIKE '%Swift' 
OR move142 LIKE '%Swift' 
OR move143 LIKE '%Swift' 
OR move144 LIKE '%Swift' 
OR move145 LIKE '%Swift' 
OR move146 LIKE '%Swift' 
OR move147 LIKE '%Swift' 
OR move148 LIKE '%Swift' 
OR move149 LIKE '%Swift' 
OR move150 LIKE '%Swift' 
OR move151 LIKE '%Swift' 
OR move152 LIKE '%Swift' 
OR move153 LIKE '%Swift' 
OR move154 LIKE '%Swift' 
OR move155 LIKE '%Swift' 
OR move156 LIKE '%Swift' 
OR move157 LIKE '%Swift' 
OR move158 LIKE '%Swift' 
OR move159 LIKE '%Swift' 
OR move160 LIKE '%Swift' 
OR move161 LIKE '%Swift' 
OR move162 LIKE '%Swift' 
OR move163 LIKE '%Swift' 
OR move164 LIKE '%Swift' 
OR move165 LIKE '%Swift' 
OR move166 LIKE '%Swift' 
OR move167 LIKE '%Swift' 
OR move168 LIKE '%Swift' 
OR move169 LIKE '%Swift' 
OR move170 LIKE '%Swift' 
OR move171 LIKE '%Swift' 
OR move172 LIKE '%Swift' 
OR move173 LIKE '%Swift';"""

swift_learners = read_query(connection, q10)
display(swift_learners)
# Out:
# [('Swift', 84)]

# %% [markdown]
# # Now display graph of number of pokemon who can learn shockwave vs. number that can learn aerial ace

# %% [markdown]
# Need to smash two lists together to make plotting easier

# %%
guaranteed_hit_data = [] 
for x in aerial_ace_learners:
    guaranteed_hit_data.append(x)

for x in shockwave_learners:
    guaranteed_hit_data.append(x)
    
for x in swift_learners:
    guaranteed_hit_data.append(x)
    
for x in magical_leaf_learners:
    guaranteed_hit_data.append(x)
    
for x in aura_sphere_learners:
    guaranteed_hit_data.append(x)
    
print(guaranteed_hit_data)
# Out:
# [('Aerial Ace', 327), ('Shock wave', 273), ('Swift', 84), ('Magical leaf', 65), ('Aura sphere', 20)]

# %%
x_val6 = [x[0] for x in guaranteed_hit_data]
y_val6 = [x[1] for x in guaranteed_hit_data]

guaranteed_hit_graph = plt.figure()
guaranteed_hit_graph.set_figwidth(12)
guaranteed_hit_graph.set_figheight(8)
  
plt.bar(x_val6,y_val6,align='center')
plt.xlabel('Move name')
plt.ylabel('Number of Pokemon that can learn')
plt.title("Number of Pokemon that can learn Guaranteed-Hit Moves")
plt.show()

# %% [markdown]
# # Get names of Pokemon that can learn moves with base power 150 or higher

# %%
#join test

q11 = """SELECT name, type_1, type_2, move1 FROM pokemon
JOIN moveset ON pokemon.name = moveset.species
WHERE type_2 = 'dark';
"""

join_test = read_query(connection, q11)
display(join_test)
# Out:
# [('Tyranitar', 'Rock', 'Dark', 'Start - Thunder Fang'),
#  ('Tyranitar', 'Rock', 'Dark', 'Start - Thunder Fang'),
#  ('Nuzleaf', 'Grass', 'Dark', 'Start - Razor Leaf'),
#  ('Shiftry', 'Grass', 'Dark', 'Start - Razor Leaf'),
#  ('Carvanha', 'Water', 'Dark', 'Start - Leer'),
#  ('Sharpedo', 'Water', 'Dark', 'Start - Slash'),
#  ('Sharpedo', 'Water', 'Dark', 'Start - Slash'),
#  ('Cacturne', 'Grass', 'Dark', 'Start - Spiky Shield'),
#  ('Crawdaunt', 'Water', 'Dark', 'Start - Swift'),
#  ('Stunky', 'Poison', 'Dark', 'Start - Scratch'),
#  ('Skuntank', 'Poison', 'Dark', 'Start - Flamethrower'),
#  ('Spiritomb', 'Ghost', 'Dark', 'Start - Curse'),
#  ('Drapion', 'Poison', 'Dark', 'Start - Thunder Fang'),
#  ('Sandile', 'Ground', 'Dark', 'Start - Leer'),
#  ('Krokorok', 'Ground', 'Dark', 'Start - Leer'),
#  ('Krookodile', 'Ground', 'Dark', 'Start - Power Trip'),
#  ('Greninja', 'Water', 'Dark', 'Start - Water Shuriken'),
#  ('Greninja', 'Water', 'Dark', 'Start - Water Shuriken'),
#  ('Greninja', 'Water', 'Dark', 'Start - Water Shuriken'),
#  ('Pangoro', 'Fighting', 'Dark', 'Start - Bullet Punch'),
#  ('Incineroar', 'Fire', 'Dark', 'Start - Darkest Lariat')]

# %% [markdown]
# ## easier way to search through multiple columns

# %%
q12 = """SELECT species FROM moveset
WHERE CONCAT_WS(" ", move1, move2, move3, move4, move5, move6, move7, move8, move9, move10, move11, move12, move13, move14, move15, move16, move17, move18, move19, move20, move21, move22, move23, move24, move25, move26, move27, move28, move29, move30, move31, move32, move33, move34, move35, move36, move37, move38, move39, move40, move41, move42, move43, move44, move45, move46, move47, move48, move49, move50, move51, move52, move53, move54, move55, move56, move57, move58, move59, move60, move61, move62, move63, move64, move65, move66, move67, move68, move69, move70, move71, move72, move73, move74, move75, move76, move77, move78, move79, move80, move81, move82, move83, move84, move85, move86, move87, move88, move89, move90, move91, move92, move93, move94, move95, move96, move97, move98, move99, move100, move101, move102, move103, move104, move105, move106, move107, move108, move109, move110, move111, move112, move113, move114, move115, move116, move117, move118, move119, move120, move121, move122, move123, move124, move125, move126, move127, move128, move129, move130, move131, move132, move133, move134, move135, move136, move137, move138, move139, move140, move141, move142, move143, move144, move145, move146, move147, move148, move149, move150, move151, move152, move153, move154, move155, move156, move157, move158, move159, move160, move161, move162, move163, move164, move165, move166, move167, move168, move169, move170, move171, move172, move173, move174) 
LIKE '%Transform%'
;
"""

new_column_search_test = read_query(connection, q12)
display(new_column_search_test)
# Out:
# [('Ditto',), ('Mew',)]

# %%
q14 = """SELECT moveset.species, move. name, move.power FROM moveset
JOIN move ON 
WHERE CONCAT_WS(" ", move1, move2, move3, move4, move5, move6, move7, move8, move9, move10, move11, move12, move13, move14, move15, move16, move17, move18, move19, move20, move21, move22, move23, move24, move25, move26, move27, move28, move29, move30, move31, move32, move33, move34, move35, move36, move37, move38, move39, move40, move41, move42, move43, move44, move45, move46, move47, move48, move49, move50, move51, move52, move53, move54, move55, move56, move57, move58, move59, move60, move61, move62, move63, move64, move65, move66, move67, move68, move69, move70, move71, move72, move73, move74, move75, move76, move77, move78, move79, move80, move81, move82, move83, move84, move85, move86, move87, move88, move89, move90, move91, move92, move93, move94, move95, move96, move97, move98, move99, move100, move101, move102, move103, move104, move105, move106, move107, move108, move109, move110, move111, move112, move113, move114, move115, move116, move117, move118, move119, move120, move121, move122, move123, move124, move125, move126, move127, move128, move129, move130, move131, move132, move133, move134, move135, move136, move137, move138, move139, move140, move141, move142, move143, move144, move145, move146, move147, move148, move149, move150, move151, move152, move153, move154, move155, move156, move157, move158, move159, move160, move161, move162, move163, move164, move165, move166, move167, move168, move169, move170, move171, move172, move173, move174) 
LIKE '%Roar of Time%'
;
"""

# %%
#THIS WORKS FOR GETTING POKEMON NAME, THEIR FIRST MOVE, AND THE MOVE'S INFO FROM THE MOVE TABLE
#SUCCESSFUL DOUBLE JOIN BABY

q13 = """SELECT pokemon.name, move.move, move.power FROM pokemon
JOIN move
JOIN moveset ON pokemon.name = moveset.species AND moveset.move1 LIKE CONCAT('%', move.move, '%')
;
"""

#WHERE move.power > 140

double_join = read_query(connection, q13)
display(double_join)
# Out:
# [('Bulbasaur', 'Tackle', 40),
#  ('Ivysaur', 'Tackle', 40),
#  ('Venusaur', 'Petal Dance', 120),
#  ('Venusaur', 'Petal Dance', 120),
#  ('Charmander', 'Scratch', 40),
#  ('Charmeleon', 'Scratch', 40),
#  ('Charizard', 'Wing Attack', 60),
#  ('Charizard', 'Wing Attack', 60),
#  ('Charizard', 'Wing Attack', 60),
#  ('Squirtle', 'Tackle', 40),
#  ('Wartortle', 'Tackle', 40),
#  ('Blastoise', 'Flash', 0),
#  ('Blastoise', 'Flash Cannon', 80),
#  ('Blastoise', 'Flash', 0),
#  ('Blastoise', 'Flash Cannon', 80),
#  ('Caterpie', 'Tackle', 40),
#  ('Metapod', 'Harden', 0),
#  ('Butterfree', 'Gust', 40),
#  ('Weedle', 'Poison Sting', 15),
#  ('Kakuna', 'Harden', 0),
#  ('Beedrill', 'Twineedle', 25),
#  ('Beedrill', 'Twineedle', 25),
#  ('Pidgey', 'Tackle', 40),
#  ('Pidgeotto', 'Tackle', 40),
#  ('Pidgeot', 'Hurricane', 110),
#  ('Pidgeot', 'Hurricane', 110),
#  ('Rattata', 'Tackle', 40),
#  ('Rattata', 'Tackle', 40),
#  ('Raticate', 'Scary Face', 0),
#  ('Raticate', 'Scary Face', 0),
#  ('Raticate', 'Scary Face', 0),
#  ('Spearow', 'Peck', 35),
#  ('Fearow', 'Drill Run', 80),
#  ('Ekans', 'Wrap', 15),
#  ('Arbok', 'Crunch', 80),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Pikachu', 'Tail Whip', 0),
#  ('Raichu', 'Psychic', 90),
#  ('Raichu', 'Thunder Shock', 40),
#  ('Raichu', 'Thunder', 110),
#  ('Sandshrew', 'Scratch', 40),
#  ('Sandshrew', 'Scratch', 40),
#  ('Sandslash', 'Icicle Spear', 25),
#  ('Sandslash', 'Crush Claw', 75),
#  ('Nidoran♀', 'Growl', 0),
#  ('Nidorina', 'Growl', 0),
#  ('Nidoqueen', 'Superpower', 120),
#  ('Nidoran♂', 'Leer', 0),
#  ('Nidorino', 'Leer', 0),
#  ('Nidoking', 'Megahorn', 120),
#  ('Clefairy', 'Spotlight', 0),
#  ('Clefable', 'Spotlight', 0),
#  ('Vulpix', 'Powder Snow', 40),
#  ('Vulpix', 'Powder', 0),
#  ('Vulpix', 'Ember', 40),
#  ('Ninetales', 'Dazzling Gleam', 80),
#  ('Ninetales', 'Imprison', 0),
#  ('Jigglypuff', 'Sing', 0),
#  ('Wigglytuff', 'Double-Edge', 120),
#  ('Zubat', 'Absorb', 20),
#  ('Golbat', 'Screech', 0),
#  ('Oddish', 'Absorb', 20),
#  ('Gloom', 'Absorb', 20),
#  ('Vileplume', 'Mega Drain', 40),
#  ('Paras', 'Scratch', 40),
#  ('Parasect', 'Cross Poison', 70),
#  ('Venonat', 'Tackle', 40),
#  ('Venomoth', 'Gust', 40),
#  ('Diglett', 'Sand Attack', 0),
#  ('Diglett', 'Sand Attack', 0),
#  ('Dugtrio', 'Sand Tomb', 35),
#  ('Dugtrio', 'Sand Tomb', 35),
#  ('Meowth', 'Scratch', 40),
#  ('Meowth', 'Scratch', 40),
#  ('Persian', 'Swift', 60),
#  ('Persian', 'Swift', 60),
#  ('Psyduck', 'Water Sport', 0),
#  ('Golduck', 'Me First', 0),
#  ('Mankey', 'Covet', 60),
#  ('Primeape', 'Rage', 20),
#  ('Growlithe', 'Bite', 60),
#  ('Arcanine', 'Thunder', 110),
#  ('Arcanine', 'Thunder Fang', 65),
#  ('Poliwag', 'Water Sport', 0),
#  ('Poliwhirl', 'Water Sport', 0),
#  ('Poliwrath', 'Submission', 80),
#  ('Abra', 'Teleport', 0),
#  ('Kadabra', 'Kinesis', 0),
#  ('Alakazam', 'Kinesis', 0),
#  ('Alakazam', 'Kinesis', 0),
#  ('Machop', 'Low Kick', 0),
#  ('Machoke', 'Low Kick', 0),
#  ('Machamp', 'Strength', 80),
#  ('Bellsprout', 'Vine Whip', 45),
#  ('Weepinbell', 'Vine Whip', 45),
#  ('Victreebel', 'Leaf Tornado', 65),
#  ('Tentacool', 'Poison Sting', 15),
#  ('Tentacruel', 'Reflect', 0),
#  ('Tentacruel', 'Reflect Type', 0),
#  ('Geodude', 'Tackle', 40),
#  ('Geodude', 'Tackle', 40),
#  ('Graveler', 'Tackle', 40),
#  ('Graveler', 'Tackle', 40),
#  ('Golem', 'Slam', 80),
#  ('Golem', 'Heavy Slam', 0),
#  ('Golem', 'Slam', 80),
#  ('Golem', 'Heavy Slam', 0),
#  ('Ponyta', 'Growl', 0),
#  ('Rapidash', 'Fury Attack', 15),
#  ('Slowpoke', 'Curse', 0),
#  ('Slowbro', 'Withdraw', 0),
#  ('Slowbro', 'Withdraw', 0),
#  ('Magnemite', 'Tackle', 40),
#  ('Magneton', 'Tri Attack', 80),
#  ('Doduo', 'Peck', 35),
#  ('Dodrio', 'Tri Attack', 80),
#  ('Seel', 'Headbutt', 70),
#  ('Dewgong', 'Sheer Cold', 0),
#  ('Grimer', 'Pound', 40),
#  ('Grimer', 'Pound', 40),
#  ('Muk', 'Venom Drench', 0),
#  ('Muk', 'Venom Drench', 0),
#  ('Shellder', 'Tackle', 40),
#  ('Cloyster', 'Hydro Pump', 110),
#  ('Gastly', 'Hypnosis', 0),
#  ('Haunter', 'Shadow Punch', 60),
#  ('Gengar', 'Shadow Punch', 60),
#  ('Gengar', 'Shadow Punch', 60),
#  ('Onix', 'Mud Sport', 0),
#  ('Drowzee', 'Pound', 40),
#  ('Hypno', 'Future Sight', 120),
#  ('Krabby', 'Mud Sport', 0),
#  ('Kingler', 'Wide Guard', 0),
#  ('Voltorb', 'Charge', 0),
#  ('Electrode', 'Magnetic Flux', 0),
#  ('Exeggcute', 'Rage', 20),
#  ('Exeggcute', 'Barrage', 15),
#  ('Exeggutor', 'Dragon Hammer', 90),
#  ('Exeggutor', 'Stomp', 65),
#  ('Cubone', 'Growl', 0),
#  ('Marowak', 'Growl', 0),
#  ('Marowak', 'Growl', 0),
#  ('Hitmonlee', 'Double Kick', 30),
#  ('Hitmonchan', 'Comet Punch', 18),
#  ('Lickitung', 'Lick', 30),
#  ('Koffing', 'Poison Gas', 0),
#  ('Weezing', 'Double Hit', 35),
#  ('Rhyhorn', 'Horn Attack', 65),
#  ('Rhydon', 'Hammer Arm', 100),
#  ('Chansey', 'Double-Edge', 120),
#  ('Tangela', 'Ingrain', 0),
#  ('Kangaskhan', 'Comet Punch', 18),
#  ('Kangaskhan', 'Comet Punch', 18),
#  ('Horsea', 'Bubble', 40),
#  ('Seadra', 'Hydro Pump', 110),
#  ('Goldeen', 'Peck', 35),
#  ('Seaking', 'Megahorn', 120),
#  ('Staryu', 'Tackle', 40),
#  ('Starmie', 'Hydro Pump', 110),
#  ('Mr. Mime', 'Mist', 0),
#  ('Mr. Mime', 'Misty Terrain', 0),
#  ('Scyther', 'Vacuum Wave', 40),
#  ('Jynx', 'Draining Kiss', 50),
#  ('Electabuzz', 'Quick Attack', 40),
#  ('Magmar', 'Smog', 30),
#  ('Pinsir', 'Vice Grip', 55),
#  ('Pinsir', 'Vice Grip', 55),
#  ('Tauros', 'Tackle', 40),
#  ('Magikarp', 'Splash', 0),
#  ('Gyarados', 'Bite', 60),
#  ('Gyarados', 'Bite', 60),
#  ('Lapras', 'Sing', 0),
#  ('Ditto', 'Transform', 0),
#  ('Eevee', 'Covet', 60),
#  ('Vaporeon', 'Water Gun', 40),
#  ('Jolteon', 'Thunder Shock', 40),
#  ('Jolteon', 'Thunder', 110),
#  ('Flareon', 'Ember', 40),
#  ('Porygon', 'Conversion', 0),
#  ('Porygon', 'Conversion 2', 0),
#  ('Omanyte', 'Constrict', 10),
#  ('Omastar', 'Spike Cannon', 20),
#  ('Kabuto', 'Scratch', 40),
#  ('Kabutops', 'Slash', 70),
#  ('Aerodactyl', 'Iron Head', 80),
#  ('Aerodactyl', 'Iron Head', 80),
#  ('Snorlax', 'Tackle', 40),
#  ('Articuno', 'Gust', 40),
#  ('Zapdos', 'Peck', 35),
#  ('Moltres', 'Wing Attack', 60),
#  ('Dratini', 'Wrap', 15),
#  ('Dragonair', 'Wrap', 15),
#  ('Dragonite', 'Wing Attack', 60),
#  ('Mewtwo', 'Laser Focus', 0),
#  ('Mewtwo', 'Laser Focus', 0),
#  ('Mewtwo', 'Laser Focus', 0),
#  ('Mew', 'Pound', 40),
#  ('Chikorita', 'Tackle', 40),
#  ('Bayleef', 'Tackle', 40),
#  ('Meganium', 'Petal Dance', 120),
#  ('Cyndaquil', 'Tackle', 40),
#  ('Quilava', 'Tackle', 40),
#  ('Typhlosion', 'Eruption', 0),
#  ('Totodile', 'Scratch', 40),
#  ('Croconaw', 'Scratch', 40),
#  ('Feraligatr', 'Agility', 0),
#  ('Sentret', 'Scratch', 40),
#  ('Furret', 'Agility', 0),
#  ('Hoothoot', 'Tackle', 40),
#  ('Noctowl', 'Dream Eater', 100),
#  ('Ledyba', 'Tackle', 40),
#  ('Ledian', 'Tackle', 40),
#  ('Spinarak', 'Poison Sting', 15),
#  ('Ariados', 'Swords Dance', 0),
#  ('Crobat', 'Cross Poison', 70),
#  ('Chinchou', 'Bubble', 40),
#  ('Lanturn', 'Stockpile', 0),
#  ('Pichu', 'Thunder Shock', 40),
#  ('Pichu', 'Thunder', 110),
#  ('Cleffa', 'Pound', 40),
#  ('Igglybuff', 'Sing', 0),
#  ('Togepi', 'Growl', 0),
#  ('Togetic', 'Magical Leaf', 60),
#  ('Natu', 'Peck', 35),
#  ('Xatu', 'Slash', 70),
#  ('Xatu', 'Air Slash', 75),
#  ('Mareep', 'Tackle', 40),
#  ('Flaaffy', 'Tackle', 40),
#  ('Ampharos', 'Thunder Punch', 75),
#  ('Ampharos', 'Thunder', 110),
#  ('Ampharos', 'Thunder Punch', 75),
#  ('Ampharos', 'Thunder', 110),
#  ('Bellossom', 'Magical Leaf', 60),
#  ('Marill', 'Tackle', 40),
#  ('Azumarill', 'Tackle', 40),
#  ('Sudowoodo', 'Slam', 80),
#  ('Politoed', 'Bubble Beam', 65),
#  ('Politoed', 'Bubble', 40),
#  ('Hoppip', 'Splash', 0),
#  ('Skiploom', 'Splash', 0),
#  ('Jumpluff', 'Splash', 0),
#  ('Aipom', 'Scratch', 40),
#  ('Sunkern', 'Absorb', 20),
#  ('Sunflora', 'Flower Shield', 0),
#  ('Yanma', 'Tackle', 40),
#  ('Wooper', 'Water Gun', 40),
#  ('Quagsire', 'Water Gun', 40),
#  ('Espeon', 'Confusion', 50),
#  ('Umbreon', 'Pursuit', 40),
#  ('Murkrow', 'Peck', 35),
#  ('Slowking', 'Heal Pulse', 0),
#  ('Misdreavus', 'Growl', 0),
#  ('Unown', 'Hidden Power', 60),
#  ('Wobbuffet', 'Counter', 0),
#  ('Girafarig', 'Power Swap', 0),
#  ('Pineco', 'Tackle', 40),
#  ('Forretress', 'Mirror Shot', 65),
#  ('Dunsparce', 'Rage', 20),
#  ('Gligar', 'Poison Sting', 15),
#  ('Steelix', 'Thunder', 110),
#  ('Steelix', 'Thunder Fang', 65),
#  ('Steelix', 'Thunder', 110),
#  ('Steelix', 'Thunder Fang', 65),
#  ('Snubbull', 'Ice Fang', 65),
#  ('Granbull', 'Rage', 20),
#  ('Granbull', 'Outrage', 120),
#  ('Qwilfish', 'Fell Stinger', 50),
#  ('Scizor', 'Feint', 30),
#  ('Scizor', 'Feint', 30),
#  ('Shuckle', 'Sticky Web', 0),
#  ('Heracross', 'Arm Thrust', 15),
#  ('Heracross', 'Arm Thrust', 15),
#  ('Sneasel', 'Scratch', 40),
#  ('Teddiursa', 'Fling', 0),
#  ('Ursaring', 'Hammer Arm', 100),
#  ('Slugma', 'Yawn', 0),
#  ('Magcargo', 'Shell Smash', 0),
#  ('Swinub', 'Tackle', 40),
#  ('Piloswine', 'Fury Attack', 15),
#  ('Corsola', 'Tackle', 40),
#  ('Remoraid', 'Water Gun', 40),
#  ('Octillery', 'Octazooka', 65),
#  ('Delibird', 'Present', 0),
#  ('Mantine', 'Psybeam', 65),
#  ('Skarmory', 'Leer', 0),
#  ('Houndour', 'Leer', 0),
#  ('Houndoom', 'Inferno', 100),
#  ('Houndoom', 'Inferno', 100),
#  ('Kingdra', 'Hydro Pump', 110),
#  ('Phanpy', 'Odor Sleuth', 0),
#  ('Donphan', 'Fury Attack', 15),
#  ('Porygon2', 'Zap Cannon', 120),
#  ('Stantler', 'Me First', 0),
#  ('Smeargle', 'Sketch', 0),
#  ('Tyrogue', 'Tackle', 40),
#  ('Hitmontop', 'Rolling Kick', 60),
#  ('Smoochum', 'Pound', 40),
#  ('Elekid', 'Quick Attack', 40),
#  ('Magby', 'Smog', 30),
#  ('Miltank', 'Tackle', 40),
#  ('Blissey', 'Double-Edge', 120),
#  ('Raikou', 'Extrasensory', 80),
#  ('Entei', 'Sacred Fire', 100),
#  ('Suicune', 'Sheer Cold', 0),
#  ('Larvitar', 'Bite', 60),
#  ('Pupitar', 'Bite', 60),
#  ('Tyranitar', 'Thunder', 110),
#  ('Tyranitar', 'Thunder Fang', 65),
#  ('Tyranitar', 'Thunder', 110),
#  ('Tyranitar', 'Thunder Fang', 65),
#  ('Lugia', 'Whirlwind', 0),
#  ('Ho-oh', 'Whirlwind', 0),
#  ('Celebi', 'Leech Seed', 0),
#  ('Treecko', 'Pound', 40),
#  ('Grovyle', 'Cut', 50),
#  ('Grovyle', 'Fury Cutter', 40),
#  ('Sceptile', 'Dual Chop', 40),
#  ('Sceptile', 'Dual Chop', 40),
#  ('Torchic', 'Scratch', 40),
#  ('Combusken', 'Double Kick', 30),
#  ('Blaziken', 'Blaze Kick', 85),
#  ('Blaziken', 'Blaze Kick', 85),
#  ('Mudkip', 'Tackle', 40),
#  ('Marshtomp', 'Mud Shot', 55),
#  ('Swampert', 'Mud Shot', 55),
#  ('Swampert', 'Mud Shot', 55),
#  ('Poochyena', 'Tackle', 40),
#  ('Mightyena', 'Snarl', 55),
#  ('Zigzagoon', 'Tackle', 40),
#  ('Linoone', 'Play Rough', 90),
#  ('Wurmple', 'Tackle', 40),
#  ('Silcoon', 'Harden', 0),
#  ('Beautifly', 'Gust', 40),
#  ('Cascoon', 'Harden', 0),
#  ('Dustox', 'Gust', 40),
#  ('Lotad', 'Astonish', 30),
#  ('Lombre', 'Astonish', 30),
#  ('Ludicolo', 'Astonish', 30),
#  ('Seedot', 'Bide', 0),
#  ('Nuzleaf', 'Razor Leaf', 55),
#  ('Shiftry', 'Razor Leaf', 55),
#  ('Taillow', 'Peck', 35),
#  ('Swellow', 'Brave Bird', 120),
#  ('Wingull', 'Growl', 0),
#  ('Pelipper', 'Protect', 0),
#  ('Ralts', 'Growl', 0),
#  ('Kirlia', 'Growl', 0),
#  ('Gardevoir', 'Moonblast', 95),
#  ('Gardevoir', 'Moonblast', 95),
#  ('Surskit', 'Bubble', 40),
#  ('Masquerain', 'Quiver Dance', 0),
#  ('Shroomish', 'Absorb', 20),
#  ('Breloom', 'Mach Punch', 40),
#  ('Slakoth', 'Scratch', 40),
#  ('Vigoroth', 'Reversal', 0),
#  ('Slaking', 'Swagger', 0),
#  ('Nincada', 'Scratch', 40),
#  ('Ninjask', 'Double Team', 0),
#  ('Shedinja', 'Scratch', 40),
#  ('Whismur', 'Pound', 40),
#  ('Loudred', 'Bite', 60),
#  ('Exploud', 'Crunch', 80),
#  ('Makuhita', 'Tackle', 40),
#  ('Hariyama', 'Brine', 65),
#  ('Azurill', 'Splash', 0),
#  ('Nosepass', 'Tackle', 40),
#  ('Skitty', 'Fake Out', 40),
#  ('Delcatty', 'Fake Out', 40),
#  ('Sableye', 'Leer', 0),
#  ('Sableye', 'Leer', 0),
#  ('Mawile', 'Play Rough', 90),
#  ('Mawile', 'Play Rough', 90),
#  ('Aron', 'Tackle', 40),
#  ('Lairon', 'Tackle', 40),
#  ('Aggron', 'Tackle', 40),
#  ('Aggron', 'Tackle', 40),
#  ('Meditite', 'Bide', 0),
#  ('Medicham', 'Headbutt', 70),
#  ('Medicham', 'Zen Headbutt', 80),
#  ('Medicham', 'Headbutt', 70),
#  ('Medicham', 'Zen Headbutt', 80),
#  ('Electrike', 'Tackle', 40),
#  ('Manectric', 'Electric Terrain', 0),
#  ('Manectric', 'Electric Terrain', 0),
#  ('Plusle', 'Nuzzle', 20),
#  ('Minun', 'Nuzzle', 20),
#  ('Volbeat', 'Flash', 0),
#  ('Illumise', 'Play Nice', 0),
#  ('Roselia', 'Absorb', 20),
#  ('Gulpin', 'Pound', 40),
#  ('Swalot', 'Slam', 80),
#  ('Swalot', 'Body Slam', 85),
#  ('Carvanha', 'Leer', 0),
#  ('Sharpedo', 'Slash', 70),
#  ('Sharpedo', 'Slash', 70),
#  ('Wailmer', 'Splash', 0),
#  ('Wailord', 'Soak', 0),
#  ('Numel', 'Growl', 0),
#  ('Camerupt', 'Rock Slide', 75),
#  ('Camerupt', 'Rock Slide', 75),
#  ('Torkoal', 'Ember', 40),
#  ('Spoink', 'Splash', 0),
#  ('Grumpig', 'Teeter Dance', 0),
#  ('Spinda', 'Tackle', 40),
#  ('Trapinch', 'Sand Attack', 0),
#  ('Vibrava', 'Dragon Breath', 60),
#  ('Flygon', 'Dragon Claw', 80),
#  ('Cacnea', 'Poison Sting', 15),
#  ('Cacturne', 'Spiky Shield', 0),
#  ('Swablu', 'Peck', 35),
#  ('Altaria', 'Dragon Breath', 60),
#  ('Altaria', 'Dragon Breath', 60),
#  ('Zangoose', 'Scratch', 40),
#  ('Seviper', 'Wrap', 15),
#  ('Lunatone', 'Power Gem', 80),
#  ('Solrock', 'Flare Blitz', 120),
#  ('Barboach', 'Mud-Slap', 20),
#  ('Whiscash', 'Thrash', 120),
#  ('Corphish', 'Bubble', 40),
#  ('Crawdaunt', 'Swift', 60),
#  ('Baltoy', 'Harden', 0),
#  ('Claydol', 'Hyper Beam', 150),
#  ('Lileep', 'Astonish', 30),
#  ('Cradily', 'Wring Out', 0),
#  ('Anorith', 'Scratch', 40),
#  ('Armaldo', 'Scratch', 40),
#  ('Feebas', 'Splash', 0),
#  ('Milotic', 'Water Pulse', 60),
#  ('Castform', 'Tackle', 40),
#  ('Castform', 'Tackle', 40),
#  ('Castform', 'Tackle', 40),
#  ('Castform', 'Tackle', 40),
#  ('Kecleon', 'Thief', 60),
#  ('Shuppet', 'Knock Off', 65),
#  ('Banette', 'Phantom Force', 90),
#  ('Banette', 'Phantom Force', 90),
#  ('Duskull', 'Leer', 0),
#  ('Dusclops', 'Shadow Punch', 60),
#  ('Tropius', 'Leaf Storm', 130),
#  ('Chimecho', 'Wish', 0),
#  ('Chimecho', 'Healing Wish', 0),
#  ('Absol', 'Perish Song', 0),
#  ('Absol', 'Perish Song', 0),
#  ('Wynaut', 'Splash', 0),
#  ('Snorunt', 'Powder Snow', 40),
#  ('Snorunt', 'Powder', 0),
#  ('Glalie', 'Freeze-Dry', 70),
#  ('Glalie', 'Freeze-Dry', 70),
#  ('Spheal', 'Defense Curl', 0),
#  ('Sealeo', 'Swagger', 0),
#  ('Walrein', 'Ice Fang', 65),
#  ('Clamperl', 'Clamp', 35),
#  ('Huntail', 'Whirlpool', 35),
#  ('Gorebyss', 'Whirlpool', 35),
#  ('Relicanth', 'Flail', 0),
#  ('Luvdisc', 'Tackle', 40),
#  ('Bagon', 'Rage', 20),
#  ('Shelgon', 'Protect', 0),
#  ('Salamence', 'Fly', 90),
#  ('Salamence', 'Fly', 90),
#  ('Beldum', 'Take Down', 90),
#  ('Metang', 'Confusion', 50),
#  ('Metagross', 'Hammer Arm', 100),
#  ('Metagross', 'Hammer Arm', 100),
#  ('Regirock', 'Explosion', 250),
#  ('Regice', 'Explosion', 250),
#  ('Registeel', 'Explosion', 250),
#  ('Latias', 'Wish', 0),
#  ('Latias', 'Healing Wish', 0),
#  ('Latias', 'Wish', 0),
#  ('Latias', 'Healing Wish', 0),
#  ('Latios', 'Memento', 0),
#  ('Latios', 'Memento', 0),
#  ('Kyogre', 'Ancient Power', 60),
#  ('Kyogre', 'Ancient Power', 60),
#  ('Groudon', 'Ancient Power', 60),
#  ('Groudon', 'Ancient Power', 60),
#  ('Rayquaza', 'Twister', 40),
#  ('Rayquaza', 'Twister', 40),
#  ('Jirachi', 'Wish', 0),
#  ('Turtwig', 'Tackle', 40),
#  ('Grotle', 'Tackle', 40),
#  ('Torterra', 'Earthquake', 100),
#  ('Chimchar', 'Scratch', 40),
#  ('Monferno', 'Mach Punch', 40),
#  ('Infernape', 'Close Combat', 120),
#  ('Piplup', 'Pound', 40),
#  ('Prinplup', 'Metal Claw', 50),
#  ('Empoleon', 'Aqua Jet', 40),
#  ('Starly', 'Tackle', 40),
#  ('Staravia', 'Tackle', 40),
#  ('Staraptor', 'Close Combat', 120),
#  ('Bidoof', 'Tackle', 40),
#  ('Bibarel', 'Water Gun', 40),
#  ('Kricketot', 'Growl', 0),
#  ('Kricketune', 'Cut', 50),
#  ('Kricketune', 'Fury Cutter', 40),
#  ('Shinx', 'Tackle', 40),
#  ('Luxio', 'Tackle', 40),
#  ('Luxray', 'Electric Terrain', 0),
#  ('Budew', 'Absorb', 20),
#  ('Roserade', 'Venom Drench', 0),
#  ('Cranidos', 'Headbutt', 70),
#  ('Rampardos', 'Endeavor', 0),
#  ('Shieldon', 'Tackle', 40),
#  ('Bastiodon', 'Block', 0),
#  ('Burmy', 'Protect', 0),
#  ('Mothim', 'Quiver Dance', 0),
#  ('Combee', 'Sweet Scent', 0),
#  ('Vespiquen', 'Slash', 70),
#  ('Pachirisu', 'Growl', 0),
#  ('Buizel', 'Sonic Boom', 0),
#  ('Floatzel', 'Ice Fang', 65),
#  ('Cherubi', 'Morning Sun', 0),
#  ('Cherrim', 'Petal Dance', 120),
#  ('Cherrim', 'Petal Dance', 120),
#  ('Shellos', 'Mud-Slap', 20),
#  ('Shellos', 'Mud-Slap', 20),
#  ('Gastrodon', 'Mud-Slap', 20),
#  ('Gastrodon', 'Mud-Slap', 20),
#  ('Ambipom', 'Dual Chop', 40),
#  ('Drifloon', 'Constrict', 10),
#  ('Drifblim', 'Phantom Force', 90),
#  ('Buneary', 'Frustration', 0),
#  ('Lopunny', 'Return', 0),
#  ('Lopunny', 'Return', 0),
#  ('Mismagius', 'Mystical Fire', 75),
#  ('Honchkrow', 'Slash', 70),
#  ('Honchkrow', 'Night Slash', 70),
#  ('Glameow', 'Fake Out', 40),
#  ('Purugly', 'Swagger', 0),
#  ('Chingling', 'Wrap', 15),
#  ('Stunky', 'Scratch', 40),
#  ('Skuntank', 'Flamethrower', 90),
#  ('Bronzor', 'Tackle', 40),
#  ('Bronzong', 'Block', 0),
#  ('Bonsly', 'Fake Tears', 0),
#  ('Mime Jr.', 'Tickle', 0),
#  ('Happiny', 'Pound', 40),
#  ('Chatot', 'Hyper Voice', 90),
#  ('Spiritomb', 'Curse', 0),
#  ('Gible', 'Tackle', 40),
#  ('Gabite', 'Dual Chop', 40),
#  ('Garchomp', 'Crunch', 80),
#  ('Garchomp', 'Crunch', 80),
#  ('Munchlax', 'Last Resort', 140),
#  ('Riolu', 'Foresight', 0),
#  ('Lucario', 'Aura Sphere', 80),
#  ('Lucario', 'Aura Sphere', 80),
#  ('Hippopotas', 'Tackle', 40),
#  ('Hippowdon', 'Ice Fang', 65),
#  ('Skorupi', 'Bite', 60),
#  ('Drapion', 'Thunder', 110),
#  ('Drapion', 'Thunder Fang', 65),
#  ('Croagunk', 'Astonish', 30),
#  ('Toxicroak', 'Astonish', 30),
#  ('Carnivine', 'Bind', 15),
#  ('Finneon', 'Pound', 40),
#  ('Lumineon', 'Soak', 0),
#  ('Mantyke', 'Tackle', 40),
#  ('Snover', 'Powder Snow', 40),
#  ('Snover', 'Powder', 0),
#  ('Abomasnow', 'Ice Punch', 75),
#  ('Abomasnow', 'Ice Punch', 75),
#  ('Weavile', 'Embargo', 0),
#  ('Magnezone', 'Tri Attack', 80),
#  ('Lickilicky', 'Wring Out', 0),
#  ('Rhyperior', 'Hammer Arm', 100),
#  ('Tangrowth', 'Block', 0),
#  ('Electivire', 'Electric Terrain', 0),
#  ('Magmortar', 'Thunder Punch', 75),
#  ('Magmortar', 'Thunder', 110),
#  ('Togekiss', 'After You', 0),
#  ('Yanmega', 'Bug Buzz', 90),
#  ('Leafeon', 'Razor Leaf', 55),
#  ('Glaceon', 'Icy Wind', 55),
#  ('Gliscor', 'Guillotine', 0),
#  ('Mamoswine', 'Fury Attack', 15),
#  ('Porygon-Z', 'Trick', 0),
#  ('Porygon-Z', 'Trick Room', 0),
#  ('Gallade', 'Slash', 70),
#  ('Gallade', 'Slash', 70),
#  ('Probopass', 'Tri Attack', 80),
#  ('Dusknoir', 'Shadow Punch', 60),
#  ('Froslass', 'Ominous Wind', 60),
#  ('Rotom', 'Charge', 0),
#  ('Rotom', 'Discharge', 80),
#  ('Rotom', 'Charge', 0),
#  ('Rotom', 'Discharge', 80),
#  ('Rotom', 'Charge', 0),
#  ('Rotom', 'Discharge', 80),
#  ('Rotom', 'Charge', 0),
#  ('Rotom', 'Discharge', 80),
#  ('Rotom', 'Charge', 0),
#  ('Rotom', 'Discharge', 80),
#  ('Rotom', 'Charge', 0),
#  ('Rotom', 'Discharge', 80),
#  ('Uxie', 'Memento', 0),
#  ('Mesprit', 'Wish', 0),
#  ('Mesprit', 'Healing Wish', 0),
#  ('Azelf', 'Natural Gift', 0),
#  ('Dialga', 'Dragon Breath', 60),
#  ('Palkia', 'Dragon Breath', 60),
#  ('Heatran', 'Magma Storm', 100),
#  ('Regigigas', 'Slam', 80),
#  ('Regigigas', 'Heavy Slam', 0),
#  ('Cresselia', 'Lunar Dance', 0),
#  ('Phione', 'Bubble', 40),
#  ('Manaphy', 'Tail Glow', 0),
#  ('Darkrai', 'Ominous Wind', 60),
#  ('Arceus', 'Seismic Toss', 0),
#  ('Victini', 'Searing Shot', 100),
#  ('Snivy', 'Tackle', 40),
#  ('Servine', 'Tackle', 40),
#  ('Serperior', 'Tackle', 40),
#  ('Tepig', 'Tackle', 40),
#  ('Pignite', 'Arm Thrust', 15),
#  ('Emboar', 'Arm Thrust', 15),
#  ('Oshawott', 'Tackle', 40),
#  ('Dewott', 'Tackle', 40),
#  ('Samurott', 'Slash', 70),
#  ('Patrat', 'Tackle', 40),
#  ('Watchog', 'Confuse Ray', 0),
#  ('Lillipup', 'Leer', 0),
#  ('Herdier', 'Leer', 0),
#  ('Stoutland', 'Ice Fang', 65),
#  ('Purrloin', 'Scratch', 40),
#  ('Liepard', 'Scratch', 40),
#  ('Pansage', 'Scratch', 40),
#  ('Simisage', 'Leer', 0),
#  ('Pansear', 'Scratch', 40),
#  ('Simisear', 'Leer', 0),
#  ('Panpour', 'Scratch', 40),
#  ('Simipour', 'Leer', 0),
#  ('Munna', 'Psywave', 0),
#  ('Musharna', 'Psychic', 90),
#  ('Musharna', 'Psychic Terrain', 0),
#  ('Pidove', 'Gust', 40),
#  ('Tranquill', 'Gust', 40),
#  ('Unfezant', 'Gust', 40),
#  ('Blitzle', 'Quick Attack', 40),
#  ('Zebstrika', 'Ion Deluge', 0),
#  ('Roggenrola', 'Tackle', 40),
#  ('Boldore', 'Power Gem', 80),
#  ('Gigalith', 'Power Gem', 80),
#  ('Woobat', 'Confusion', 50),
#  ('Swoobat', 'Confusion', 50),
#  ('Drilbur', 'Scratch', 40),
#  ('Excadrill', 'Horn Drill', 0),
#  ('Audino', 'Last Resort', 140),
#  ('Audino', 'Last Resort', 140),
#  ('Timburr', 'Pound', 40),
#  ('Gurdurr', 'Pound', 40),
#  ('Conkeldurr', 'Pound', 40),
#  ('Tympole', 'Bubble', 40),
#  ('Palpitoad', 'Bubble', 40),
#  ('Seismitoad', 'Acid', 40),
#  ('Throh', 'Block', 0),
#  ('Throh', 'Mat Block', 0),
#  ('Sawk', 'Rock Smash', 40),
#  ('Sewaddle', 'Tackle', 40),
#  ('Swadloon', 'Protect', 0),
#  ('Leavanny', 'Slash', 70),
#  ('Venipede', 'Defense Curl', 0),
#  ('Whirlipede', 'Iron Defense', 0),
#  ('Scolipede', 'Baton Pass', 0),
#  ('Cottonee', 'Absorb', 20),
#  ('Whimsicott', 'Growth', 0),
#  ('Petilil', 'Absorb', 20),
#  ('Lilligant', 'Growth', 0),
#  ('Sandile', 'Leer', 0),
#  ('Krokorok', 'Leer', 0),
#  ('Krookodile', 'Power Trip', 20),
#  ('Darumaka', 'Tackle', 40),
#  ('Maractus', 'Spiky Shield', 0),
#  ('Dwebble', 'Cut', 50),
#  ('Dwebble', 'Fury Cutter', 40),
#  ('Crustle', 'Shell Smash', 0),
#  ('Scraggy', 'Leer', 0),
#  ('Scrafty', 'Leer', 0),
#  ('Sigilyph', 'Gust', 40),
#  ('Yamask', 'Astonish', 30),
#  ('Cofagrigus', 'Scary Face', 0),
#  ('Tirtouga', 'Bide', 0),
#  ('Carracosta', 'Bide', 0),
#  ('Archen', 'Quick Attack', 40),
#  ('Archeops', 'Quick Attack', 40),
#  ('Trubbish', 'Pound', 40),
#  ('Garbodor', 'Pound', 40),
#  ('Zorua', 'Scratch', 40),
#  ('Zoroark', 'Slash', 70),
#  ('Zoroark', 'Night Slash', 70),
#  ('Minccino', 'Pound', 40),
#  ('Cinccino', 'Bullet Seed', 25),
#  ('Gothita', 'Pound', 40),
#  ('Gothorita', 'Pound', 40),
#  ('Gothitelle', 'Pound', 40),
#  ('Solosis', 'Psywave', 0),
#  ('Duosion', 'Psywave', 0),
#  ('Reuniclus', 'Dizzy Punch', 70),
#  ('Ducklett', 'Water Gun', 40),
#  ('Swanna', 'Water Gun', 40),
#  ('Vanillite', 'Icicle Spear', 25),
#  ('Vanillish', 'Icicle Spear', 25),
#  ('Vanilluxe', 'Sheer Cold', 0),
#  ('Deerling', 'Tackle', 40),
#  ('Sawsbuck', 'Horn Leech', 75),
#  ('Emolga', 'Thunder Shock', 40),
#  ('Emolga', 'Thunder', 110),
#  ('Karrablast', 'Peck', 35),
#  ('Escavalier', 'Double-Edge', 120),
#  ('Foongus', 'Absorb', 20),
#  ('Amoonguss', 'Absorb', 20),
#  ('Frillish', 'Bubble', 40),
#  ('Jellicent', 'Water Spout', 0),
#  ('Alomomola', 'Play Nice', 0),
#  ('Joltik', 'String Shot', 0),
#  ('Galvantula', 'Sticky Web', 0),
#  ('Ferroseed', 'Tackle', 40),
#  ('Ferrothorn', 'Power Whip', 120),
#  ('Klink', 'Vice Grip', 55),
#  ('Klang', 'Vice Grip', 55),
#  ('Klinklang', 'Magnetic Flux', 0),
#  ('Tynamo', 'Tackle', 40),
#  ('Eelektrik', 'Crunch', 80),
#  ('Eelektross', 'Crunch', 80),
#  ('Elgyem', 'Confusion', 50),
#  ('Beheeyem', 'Psychic', 90),
#  ('Beheeyem', 'Psychic Terrain', 0),
#  ('Litwick', 'Ember', 40),
#  ('Lampent', 'Ember', 40),
#  ('Chandelure', 'Pain Split', 0),
#  ('Axew', 'Scratch', 40),
#  ('Fraxure', 'Scratch', 40),
#  ('Haxorus', 'Rage', 20),
#  ('Haxorus', 'Outrage', 120),
#  ('Cubchoo', 'Growl', 0),
#  ('Beartic', 'Icicle Crash', 85),
#  ('Cryogonal', 'Sheer Cold', 0),
#  ('Shelmet', 'Absorb', 20),
#  ('Accelgor', 'Water Shuriken', 15),
#  ('Stunfisk', 'Fissure', 0),
#  ('Mienfoo', 'Pound', 40),
#  ('Mienshao', 'Aura Sphere', 80),
#  ('Druddigon', 'Leer', 0),
#  ('Golett', 'Pound', 40),
#  ('Golurk', 'Slam', 80),
#  ('Golurk', 'Heavy Slam', 0),
#  ('Pawniard', 'Scratch', 40),
#  ('Bisharp', 'Guillotine', 0),
#  ('Bouffalant', 'Pursuit', 40),
#  ('Rufflet', 'Peck', 35),
#  ('Braviary', 'Superpower', 120),
#  ('Vullaby', 'Gust', 40),
#  ('Mandibuzz', 'Bone Rush', 25),
#  ('Heatmor', 'Hone Claws', 0),
#  ('Durant', 'Metal Sound', 0),
#  ('Deino', 'Tackle', 40),
#  ('Zweilous', 'Double Hit', 35),
#  ('Hydreigon', 'Rage', 20),
#  ('Hydreigon', 'Outrage', 120),
#  ('Larvesta', 'Ember', 40),
#  ('Volcarona', 'Quiver Dance', 0),
#  ('Cobalion', 'Close Combat', 120),
#  ('Terrakion', 'Close Combat', 120),
#  ('Virizion', 'Close Combat', 120),
#  ('Reshiram', 'Fire Fang', 65),
#  ('Zekrom', 'Thunder', 110),
#  ('Zekrom', 'Thunder Fang', 65),
#  ('Kyurem', 'Icy Wind', 55),
#  ('Kyurem', 'Icy Wind', 55),
#  ('Kyurem', 'Icy Wind', 55),
#  ('Genesect', 'Fell Stinger', 50),
#  ('Chespin', 'Growl', 0),
#  ('Quilladin', 'Needle Arm', 60),
#  ('Chesnaught', 'Spiky Shield', 0),
#  ('Fennekin', 'Scratch', 40),
#  ('Braixen', 'Scratch', 40),
#  ('Delphox', 'Mystical Fire', 75),
#  ('Froakie', 'Pound', 40),
#  ('Frogadier', 'Pound', 40),
#  ('Greninja', 'Water Shuriken', 15),
#  ('Greninja', 'Water Shuriken', 15),
#  ('Greninja', 'Water Shuriken', 15),
#  ('Bunnelby', 'Tackle', 40),
#  ('Diggersby', 'Hammer Arm', 100),
#  ('Fletchling', 'Tackle', 40),
#  ('Fletchinder', 'Ember', 40),
#  ('Talonflame', 'Ember', 40),
#  ('Scatterbug', 'Tackle', 40),
#  ('Spewpa', 'Protect', 0),
#  ('Vivillon', 'Gust', 40),
#  ('Litleo', 'Tackle', 40),
#  ('Pyroar', 'Hyper Beam', 150),
#  ('Flabébé', 'Tackle', 40),
#  ('Floette', 'Tackle', 40),
#  ('Floette', 'Tackle', 40),
#  ('Floette', 'Tackle', 40),
#  ('Floette', 'Tackle', 40),
#  ('Floette', 'Tackle', 40),
#  ('Floette', 'Tackle', 40),
#  ('Florges', 'Disarming Voice', 40),
#  ('Skiddo', 'Tackle', 40),
#  ('Gogoat', 'Aerial Ace', 60),
#  ('Pancham', 'Tackle', 40),
#  ('Pangoro', 'Bullet Punch', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Furfrou', 'Tackle', 40),
#  ('Espurr', 'Scratch', 40),
#  ('Honedge', 'Tackle', 40),
#  ('Doublade', 'Tackle', 40),
#  ('Spritzee', 'Sweet Scent', 0),
#  ('Aromatisse', 'Mist', 0),
#  ('Aromatisse', 'Aromatic Mist', 0),
#  ('Swirlix', 'Sweet Scent', 0),
#  ('Slurpuff', 'Sweet Scent', 0),
#  ('Inkay', 'Tackle', 40),
#  ('Malamar', 'Reversal', 0),
#  ('Binacle', 'Shell Smash', 0),
#  ('Barbaracle', 'Skull Bash', 130),
#  ('Skrelp', 'Tackle', 40),
#  ('Dragalge', 'Twister', 40),
#  ('Clauncher', 'Splash', 0),
#  ('Clawitzer', 'Aura Sphere', 80),
#  ('Helioptile', 'Pound', 40),
#  ('Heliolisk', 'Eerie Impulse', 0),
#  ('Tyrunt', 'Tail Whip', 0),
#  ('Tyrantrum', 'Rock Slide', 75),
#  ('Amaura', 'Growl', 0),
#  ('Aurorus', 'Freeze-Dry', 70),
#  ('Sylveon', 'Fairy Wind', 40),
#  ('Hawlucha', 'Detect', 0),
#  ('Dedenne', 'Tackle', 40),
#  ('Carbink', 'Tackle', 40),
#  ('Goomy', 'Tackle', 40),
#  ('Sliggoo', 'Tackle', 40),
#  ('Goodra', 'Aqua Tail', 90),
#  ('Klefki', 'Fairy Lock', 0),
#  ('Phantump', 'Tackle', 40),
#  ('Trevenant', 'Shadow Claw', 70),
#  ('Bergmite', 'Tackle', 40),
#  ('Avalugg', 'Slam', 80),
#  ('Avalugg', 'Body Slam', 85),
#  ('Noibat', 'Screech', 0),
#  ('Noivern', 'Boomburst', 140),
#  ('Xerneas', 'Heal Pulse', 0),
#  ('Yveltal', 'Hurricane', 110),
#  ('Diancie', 'Tackle', 40),
#  ('Diancie', 'Tackle', 40),
#  ('Volcanion', 'Eruption', 0),
#  ('Volcanion', 'Steam Eruption', 110),
#  ('Rowlet', 'Tackle', 40),
#  ('Dartrix', 'Tackle', 40),
#  ('Decidueye', 'Spirit Shackle', 80),
#  ('Litten', 'Scratch', 40),
#  ('Torracat', 'Scratch', 40),
#  ('Incineroar', 'Darkest Lariat', 85),
#  ('Popplio', 'Pound', 40),
#  ('Brionne', 'Pound', 40),
#  ('Primarina', 'Spark', 65),
#  ('Primarina', 'Sparkling Aria', 90),
#  ('Pikipek', 'Peck', 35),
#  ('Trumbeak', 'Rock Blast', 25),
#  ('Toucannon', 'Beak Blast', 100),
#  ('Yungoos', 'Tackle', 40),
#  ('Gumshoos', 'Tackle', 40),
#  ('Gumshoos', 'Tackle', 40),
#  ('Grubbin', 'Vice Grip', 55),
#  ('Charjabug', 'Charge', 0),
#  ('Vikavolt', 'Thunderbolt', 90),
#  ('Vikavolt', 'Thunder', 110),
#  ('Vikavolt', 'Thunderbolt', 90),
#  ('Vikavolt', 'Thunder', 110),
#  ('Crabrawler', 'Bubble', 40),
#  ('Crabominable', 'Ice Punch', 75),
#  ('Cutiefly', 'Absorb', 20),
#  ('Ribombee', 'Pollen Puff', 90),
#  ('Rockruff', 'Tackle', 40),
#  ('Mareanie', 'Poison Sting', 15),
#  ('Toxapex', 'Baneful Bunker', 0),
#  ('Mudbray', 'Mud-Slap', 20),
#  ('Mudsdale', 'Mud-Slap', 20),
#  ('Dewpider', 'Water Sport', 0),
#  ('Araquanid', 'Wide Guard', 0),
#  ('Fomantis', 'Cut', 50),
#  ('Fomantis', 'Fury Cutter', 40),
#  ('Lurantis', 'Blizzard', 110),
#  ('Lurantis', 'Petal Blizzard', 90),
#  ('Lurantis', 'Blizzard', 110),
#  ('Lurantis', 'Petal Blizzard', 90),
#  ('Morelull', 'Absorb', 20),
#  ('Shiinotic', 'Absorb', 20),
#  ('Salandit', 'Scratch', 40),
#  ('Salazzle', 'Captivate', 0),
#  ('Salazzle', 'Captivate', 0),
#  ('Stufful', 'Tackle', 40),
#  ('Bewear', 'Bind', 15),
#  ('Bounsweet', 'Splash', 0),
#  ('Steenee', 'Double Slap', 15),
#  ('Tsareena', 'Trop Kick', 70),
#  ('Comfey', 'Helping Hand', 0),
#  ('Oranguru', 'Confusion', 50),
#  ('Passimian', 'Tackle', 40),
#  ('Wimpod', 'Struggle', 50),
#  ('Wimpod', 'Struggle Bug', 50),
#  ('Golisopod', 'First Impression', 90),
#  ('Sandygast', 'Harden', 0),
#  ('Palossand', 'Harden', 0),
#  ('Pyukumuku', 'Baton Pass', 0),
#  ('Type: Null', 'Tackle', 40),
#  ('Silvally', 'Multi-Attack', 90),
#  ('Komala', 'Defense Curl', 0),
#  ('Turtonator', 'Ember', 40),
#  ('Togedemaru', 'Tackle', 40),
#  ('Mimikyu', 'Wood Hammer', 120),
#  ('Mimikyu', 'Wood Hammer', 120),
#  ('Mimikyu', 'Wood Hammer', 120),
#  ('Mimikyu', 'Wood Hammer', 120),
#  ('Bruxish', 'Water Gun', 40),
#  ('Drampa', 'Play Nice', 0),
#  ('Dhelmise', 'Switcheroo', 0),
#  ('Jangmo-o', 'Tackle', 40),
#  ('Hakamo-o', 'Cut', 50),
#  ('Hakamo-o', 'Sky Uppercut', 85),
#  ('Kommo-o', 'Clanging Scales', 110),
#  ('Kommo-o', 'Clanging Scales', 110),
#  ('Tapu Koko', 'Electric Terrain', 0),
#  ('Tapu Lele', 'Psychic', 90),
#  ('Tapu Lele', 'Psychic Terrain', 0),
#  ('Tapu Bulu', 'Grassy Terrain', 0),
#  ('Tapu Fini', 'Mist', 0),
#  ('Tapu Fini', 'Misty Terrain', 0),
#  ('Cosmog', 'Splash', 0),
#  ('Cosmoem', 'Cosmic Power', 0),
#  ('Solgaleo', 'Sunsteel Strike', 100),
#  ('Lunala', 'Moongeist Beam', 100),
#  ('Nihilego', 'Power Split', 0),
#  ('Buzzwole', 'Fell Stinger', 50),
#  ('Pheromosa', 'Quiver Dance', 0),
#  ('Xurkitree', 'Tail Glow', 0),
#  ('Celesteela', 'Wide Guard', 0),
#  ('Kartana', 'Sacred Sword', 90),
#  ('Guzzlord', 'Belch', 120),
#  ('Necrozma', 'Moonlight', 0),
#  ('Magearna', 'Crafty Shield', 0),
#  ('Magearna', 'Crafty Shield', 0),
#  ('Marshadow', 'Laser Focus', 0)]

# %%
q14 = """SELECT pokemon.name, move.move, move.power FROM pokemon
JOIN move
WHERE (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move1 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
) 

OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move2 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
;
"""

#WHERE move.power > 140

move_power_test = read_query(connection, q14)
display(move_power_test)
# Out:
# [('Claydol', 'Hyper Beam', 150),
#  ('Relicanth', 'Head Smash', 150),
#  ('Regirock', 'Explosion', 250),
#  ('Regice', 'Explosion', 250),
#  ('Registeel', 'Explosion', 250),
#  ('Rhyperior', 'Rock Wrecker', 150),
#  ('Pyroar', 'Hyper Beam', 150),
#  ('Tyrantrum', 'Head Smash', 150)]

# %%
stupid_string = ""

for x in range(175): 
    stupid_string += ("""OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move""" +str(x)+""" LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)\n""")

# %%
q15 = """SELECT pokemon.name, move.move, move.power FROM pokemon
JOIN move
WHERE (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move1 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
) 

OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move2 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move3 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move4 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move5 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move6 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move7 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move8 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move9 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move10 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move11 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move12 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move13 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move14 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move15 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move16 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move17 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move18 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move19 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move20 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move21 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move22 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move23 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move24 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move25 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move26 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move27 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move28 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move29 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move30 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move31 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move32 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move33 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move34 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move35 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move36 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move37 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move38 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move39 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move40 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move41 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move42 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move43 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move44 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move45 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move46 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move47 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move48 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move49 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move50 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move51 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move52 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move53 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move54 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move55 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move56 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move57 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move58 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move59 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move60 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move61 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move62 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move63 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move64 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move65 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move66 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move67 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move68 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move69 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move70 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move71 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move72 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move73 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move74 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move75 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move76 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move77 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move78 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move79 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move80 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move81 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move82 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move83 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move84 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move85 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move86 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move87 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move88 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move89 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move90 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move91 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move92 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move93 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move94 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move95 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move96 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move97 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move98 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move99 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move100 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move101 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move102 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move103 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move104 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move105 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move106 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move107 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move108 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move109 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move110 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move111 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move112 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move113 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move114 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move115 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move116 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move117 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move118 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move119 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move120 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move121 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move122 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move123 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move124 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move125 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move126 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move127 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move128 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move129 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move130 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move131 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move132 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move133 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move134 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move135 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move136 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move137 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move138 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move139 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move140 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move141 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move142 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move143 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move144 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move145 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move146 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move147 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move148 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move149 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move150 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move151 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move152 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move153 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move154 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move155 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move156 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move157 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move158 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move159 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move160 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move161 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move162 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move163 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move164 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move165 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move166 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move167 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move168 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move169 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move170 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move171 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move172 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move173 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
OR (pokemon.name, move.move, move.power) IN(
    SELECT pokemon.name, move.move, move.power FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move174 LIKE CONCAT('%', move.move, '%')
        WHERE move.power > 140
)
;
"""

#WHERE move.power > 140

move_power_test = read_query(connection, q15)
display(move_power_test)
# Out:
# [('Bulbasaur', 'Frenzy Plant', 150),
#  ('Ivysaur', 'Frenzy Plant', 150),
#  ('Venusaur', 'Giga Impact', 150),
#  ('Venusaur', 'Frenzy Plant', 150),
#  ('Venusaur', 'Hyper Beam', 150),
#  ('Charmander', 'Blast Burn', 150),
#  ('Charmander', 'Focus Punch', 150),
#  ('Charmeleon', 'Blast Burn', 150),
#  ('Charmeleon', 'Focus Punch', 150),
#  ('Charizard', 'Giga Impact', 150),
#  ('Charizard', 'Blast Burn', 150),
#  ('Charizard', 'Focus Punch', 150),
#  ('Charizard', 'Hyper Beam', 150),
#  ('Squirtle', 'Hydro Cannon', 150),
#  ('Squirtle', 'Focus Punch', 150),
#  ('Wartortle', 'Hydro Cannon', 150),
#  ('Wartortle', 'Focus Punch', 150),
#  ('Blastoise', 'Giga Impact', 150),
#  ('Blastoise', 'Hydro Cannon', 150),
#  ('Blastoise', 'Focus Punch', 150),
#  ('Blastoise', 'Hyper Beam', 150),
#  ('Butterfree', 'Giga Impact', 150),
#  ('Butterfree', 'Hyper Beam', 150),
#  ('Beedrill', 'Giga Impact', 150),
#  ('Beedrill', 'Hyper Beam', 150),
#  ('Pidgeot', 'Giga Impact', 150),
#  ('Pidgeot', 'Hyper Beam', 150),
#  ('Raticate', 'Giga Impact', 150),
#  ('Raticate', 'Hyper Beam', 150),
#  ('Fearow', 'Giga Impact', 150),
#  ('Fearow', 'Hyper Beam', 150),
#  ('Arbok', 'Giga Impact', 150),
#  ('Arbok', 'Hyper Beam', 150),
#  ('Raichu', 'Giga Impact', 150),
#  ('Raichu', 'Focus Punch', 150),
#  ('Raichu', 'Hyper Beam', 150),
#  ('Sandshrew', 'Focus Punch', 150),
#  ('Sandslash', 'Giga Impact', 150),
#  ('Sandslash', 'Focus Punch', 150),
#  ('Sandslash', 'Hyper Beam', 150),
#  ('Nidoqueen', 'Giga Impact', 150),
#  ('Nidoqueen', 'Focus Punch', 150),
#  ('Nidoqueen', 'Hyper Beam', 150),
#  ('Nidoran♂', 'Head Smash', 150),
#  ('Nidorino', 'Head Smash', 150),
#  ('Nidoking', 'Head Smash', 150),
#  ('Nidoking', 'Giga Impact', 150),
#  ('Nidoking', 'Focus Punch', 150),
#  ('Nidoking', 'Hyper Beam', 150),
#  ('Clefairy', 'Focus Punch', 150),
#  ('Clefable', 'Giga Impact', 150),
#  ('Clefable', 'Focus Punch', 150),
#  ('Clefable', 'Hyper Beam', 150),
#  ('Ninetales', 'Giga Impact', 150),
#  ('Ninetales', 'Hyper Beam', 150),
#  ('Jigglypuff', 'Focus Punch', 150),
#  ('Wigglytuff', 'Giga Impact', 150),
#  ('Wigglytuff', 'Focus Punch', 150),
#  ('Wigglytuff', 'Hyper Beam', 150),
#  ('Golbat', 'Giga Impact', 150),
#  ('Golbat', 'Hyper Beam', 150),
#  ('Vileplume', 'Giga Impact', 150),
#  ('Vileplume', 'Hyper Beam', 150),
#  ('Parasect', 'Giga Impact', 150),
#  ('Parasect', 'Hyper Beam', 150),
#  ('Venomoth', 'Giga Impact', 150),
#  ('Venomoth', 'Hyper Beam', 150),
#  ('Dugtrio', 'Giga Impact', 150),
#  ('Dugtrio', 'Hyper Beam', 150),
#  ('Persian', 'Giga Impact', 150),
#  ('Persian', 'Hyper Beam', 150),
#  ('Psyduck', 'Focus Punch', 150),
#  ('Golduck', 'Giga Impact', 150),
#  ('Golduck', 'Focus Punch', 150),
#  ('Golduck', 'Hyper Beam', 150),
#  ('Mankey', 'Focus Punch', 150),
#  ('Primeape', 'Giga Impact', 150),
#  ('Primeape', 'Focus Punch', 150),
#  ('Primeape', 'Hyper Beam', 150),
#  ('Arcanine', 'Giga Impact', 150),
#  ('Arcanine', 'Hyper Beam', 150),
#  ('Poliwhirl', 'Focus Punch', 150),
#  ('Poliwrath', 'Giga Impact', 150),
#  ('Poliwrath', 'Focus Punch', 150),
#  ('Poliwrath', 'Hyper Beam', 150),
#  ('Abra', 'Focus Punch', 150),
#  ('Kadabra', 'Focus Punch', 150),
#  ('Alakazam', 'Giga Impact', 150),
#  ('Alakazam', 'Focus Punch', 150),
#  ('Alakazam', 'Hyper Beam', 150),
#  ('Machop', 'Focus Punch', 150),
#  ('Machoke', 'Focus Punch', 150),
#  ('Machamp', 'Giga Impact', 150),
#  ('Machamp', 'Focus Punch', 150),
#  ('Machamp', 'Hyper Beam', 150),
#  ('Victreebel', 'Giga Impact', 150),
#  ('Victreebel', 'Hyper Beam', 150),
#  ('Tentacruel', 'Giga Impact', 150),
#  ('Tentacruel', 'Hyper Beam', 150),
#  ('Geodude', 'Focus Punch', 150),
#  ('Geodude', 'Explosion', 250),
#  ('Geodude', 'Self-Destruct', 200),
#  ('Graveler', 'Focus Punch', 150),
#  ('Graveler', 'Explosion', 250),
#  ('Graveler', 'Self-Destruct', 200),
#  ('Golem', 'Giga Impact', 150),
#  ('Golem', 'Focus Punch', 150),
#  ('Golem', 'Explosion', 250),
#  ('Golem', 'Self-Destruct', 200),
#  ('Golem', 'Hyper Beam', 150),
#  ('Rapidash', 'Giga Impact', 150),
#  ('Rapidash', 'Hyper Beam', 150),
#  ('Slowbro', 'Giga Impact', 150),
#  ('Slowbro', 'Focus Punch', 150),
#  ('Slowbro', 'Hyper Beam', 150),
#  ('Magnemite', 'Explosion', 250),
#  ('Magneton', 'Giga Impact', 150),
#  ('Magneton', 'Explosion', 250),
#  ('Magneton', 'Hyper Beam', 150),
#  ('Dodrio', 'Giga Impact', 150),
#  ('Dodrio', 'Hyper Beam', 150),
#  ('Dewgong', 'Giga Impact', 150),
#  ('Dewgong', 'Hyper Beam', 150),
#  ('Grimer', 'Explosion', 250),
#  ('Muk', 'Giga Impact', 150),
#  ('Muk', 'Focus Punch', 150),
#  ('Muk', 'Explosion', 250),
#  ('Muk', 'Hyper Beam', 150),
#  ('Shellder', 'Explosion', 250),
#  ('Cloyster', 'Giga Impact', 150),
#  ('Cloyster', 'Explosion', 250),
#  ('Cloyster', 'Hyper Beam', 150),
#  ('Gastly', 'Explosion', 250),
#  ('Haunter', 'Explosion', 250),
#  ('Gengar', 'Giga Impact', 150),
#  ('Gengar', 'Focus Punch', 150),
#  ('Gengar', 'Explosion', 250),
#  ('Gengar', 'Hyper Beam', 150),
#  ('Onix', 'Explosion', 250),
#  ('Drowzee', 'Focus Punch', 150),
#  ('Hypno', 'Giga Impact', 150),
#  ('Hypno', 'Focus Punch', 150),
#  ('Hypno', 'Hyper Beam', 150),
#  ('Kingler', 'Giga Impact', 150),
#  ('Kingler', 'Hyper Beam', 150),
#  ('Voltorb', 'Explosion', 250),
#  ('Voltorb', 'Self-Destruct', 200),
#  ('Electrode', 'Giga Impact', 150),
#  ('Electrode', 'Explosion', 250),
#  ('Electrode', 'Self-Destruct', 200),
#  ('Electrode', 'Hyper Beam', 150),
#  ('Exeggcute', 'Explosion', 250),
#  ('Exeggutor', 'Giga Impact', 150),
#  ('Exeggutor', 'Explosion', 250),
#  ('Exeggutor', 'Hyper Beam', 150),
#  ('Cubone', 'Focus Punch', 150),
#  ('Marowak', 'Giga Impact', 150),
#  ('Marowak', 'Focus Punch', 150),
#  ('Marowak', 'Hyper Beam', 150),
#  ('Hitmonlee', 'Focus Punch', 150),
#  ('Hitmonchan', 'Focus Punch', 150),
#  ('Lickitung', 'Giga Impact', 150),
#  ('Lickitung', 'Focus Punch', 150),
#  ('Lickitung', 'Hyper Beam', 150),
#  ('Koffing', 'Explosion', 250),
#  ('Koffing', 'Self-Destruct', 200),
#  ('Weezing', 'Giga Impact', 150),
#  ('Weezing', 'Explosion', 250),
#  ('Weezing', 'Self-Destruct', 200),
#  ('Weezing', 'Hyper Beam', 150),
#  ('Rhydon', 'Giga Impact', 150),
#  ('Rhydon', 'Focus Punch', 150),
#  ('Rhydon', 'Hyper Beam', 150),
#  ('Chansey', 'Giga Impact', 150),
#  ('Chansey', 'Focus Punch', 150),
#  ('Chansey', 'Hyper Beam', 150),
#  ('Tangela', 'Giga Impact', 150),
#  ('Tangela', 'Hyper Beam', 150),
#  ('Kangaskhan', 'Giga Impact', 150),
#  ('Kangaskhan', 'Focus Punch', 150),
#  ('Kangaskhan', 'Hyper Beam', 150),
#  ('Seadra', 'Giga Impact', 150),
#  ('Seadra', 'Hyper Beam', 150),
#  ('Seaking', 'Giga Impact', 150),
#  ('Seaking', 'Hyper Beam', 150),
#  ('Starmie', 'Giga Impact', 150),
#  ('Starmie', 'Hyper Beam', 150),
#  ('Mr. Mime', 'Giga Impact', 150),
#  ('Mr. Mime', 'Focus Punch', 150),
#  ('Mr. Mime', 'Hyper Beam', 150),
#  ('Scyther', 'Giga Impact', 150),
#  ('Scyther', 'Hyper Beam', 150),
#  ('Jynx', 'Giga Impact', 150),
#  ('Jynx', 'Focus Punch', 150),
#  ('Jynx', 'Hyper Beam', 150),
#  ('Electabuzz', 'Giga Impact', 150),
#  ('Electabuzz', 'Focus Punch', 150),
#  ('Electabuzz', 'Hyper Beam', 150),
#  ('Magmar', 'Giga Impact', 150),
#  ('Magmar', 'Focus Punch', 150),
#  ('Magmar', 'Hyper Beam', 150),
#  ('Pinsir', 'Giga Impact', 150),
#  ('Pinsir', 'Focus Punch', 150),
#  ('Pinsir', 'Hyper Beam', 150),
#  ('Tauros', 'Giga Impact', 150),
#  ('Tauros', 'Hyper Beam', 150),
#  ('Gyarados', 'Giga Impact', 150),
#  ('Gyarados', 'Hyper Beam', 150),
#  ('Lapras', 'Giga Impact', 150),
#  ('Lapras', 'Hyper Beam', 150),
#  ('Vaporeon', 'Giga Impact', 150),
#  ('Vaporeon', 'Hyper Beam', 150),
#  ('Jolteon', 'Giga Impact', 150),
#  ('Jolteon', 'Hyper Beam', 150),
#  ('Flareon', 'Giga Impact', 150),
#  ('Flareon', 'Hyper Beam', 150),
#  ('Porygon', 'Giga Impact', 150),
#  ('Porygon', 'Hyper Beam', 150),
#  ('Omastar', 'Giga Impact', 150),
#  ('Omastar', 'Hyper Beam', 150),
#  ('Kabutops', 'Giga Impact', 150),
#  ('Kabutops', 'Hyper Beam', 150),
#  ('Aerodactyl', 'Giga Impact', 150),
#  ('Aerodactyl', 'Hyper Beam', 150),
#  ('Snorlax', 'Giga Impact', 150),
#  ('Snorlax', 'Focus Punch', 150),
#  ('Snorlax', 'Self-Destruct', 200),
#  ('Snorlax', 'Hyper Beam', 150),
#  ('Articuno', 'Giga Impact', 150),
#  ('Articuno', 'Hyper Beam', 150),
#  ('Zapdos', 'Giga Impact', 150),
#  ('Zapdos', 'Hyper Beam', 150),
#  ('Moltres', 'Giga Impact', 150),
#  ('Moltres', 'Hyper Beam', 150),
#  ('Dratini', 'Hyper Beam', 150),
#  ('Dragonair', 'Hyper Beam', 150),
#  ('Dragonite', 'Giga Impact', 150),
#  ('Dragonite', 'Focus Punch', 150),
#  ('Dragonite', 'Hyper Beam', 150),
#  ('Mewtwo', 'Giga Impact', 150),
#  ('Mewtwo', 'Focus Punch', 150),
#  ('Mewtwo', 'Hyper Beam', 150),
#  ('Mew', 'Giga Impact', 150),
#  ('Mew', 'Focus Punch', 150),
#  ('Mew', 'Explosion', 250),
#  ('Mew', 'Hyper Beam', 150),
#  ('Chikorita', 'Frenzy Plant', 150),
#  ('Bayleef', 'Frenzy Plant', 150),
#  ('Meganium', 'Giga Impact', 150),
#  ('Meganium', 'Frenzy Plant', 150),
#  ('Meganium', 'Hyper Beam', 150),
#  ('Cyndaquil', 'Blast Burn', 150),
#  ('Quilava', 'Blast Burn', 150),
#  ('Quilava', 'Focus Punch', 150),
#  ('Typhlosion', 'Giga Impact', 150),
#  ('Typhlosion', 'Blast Burn', 150),
#  ('Typhlosion', 'Focus Punch', 150),
#  ('Typhlosion', 'Hyper Beam', 150),
#  ('Totodile', 'Hydro Cannon', 150),
#  ('Totodile', 'Focus Punch', 150),
#  ('Croconaw', 'Hydro Cannon', 150),
#  ('Croconaw', 'Focus Punch', 150),
#  ('Feraligatr', 'Giga Impact', 150),
#  ('Feraligatr', 'Hydro Cannon', 150),
#  ('Feraligatr', 'Focus Punch', 150),
#  ('Feraligatr', 'Hyper Beam', 150),
#  ('Sentret', 'Focus Punch', 150),
#  ('Furret', 'Giga Impact', 150),
#  ('Furret', 'Focus Punch', 150),
#  ('Furret', 'Hyper Beam', 150),
#  ('Noctowl', 'Giga Impact', 150),
#  ('Noctowl', 'Hyper Beam', 150),
#  ('Ledyba', 'Focus Punch', 150),
#  ('Ledian', 'Giga Impact', 150),
#  ('Ledian', 'Focus Punch', 150),
#  ('Ledian', 'Hyper Beam', 150),
#  ('Ariados', 'Giga Impact', 150),
#  ('Ariados', 'Hyper Beam', 150),
#  ('Crobat', 'Giga Impact', 150),
#  ('Crobat', 'Hyper Beam', 150),
#  ('Lanturn', 'Giga Impact', 150),
#  ('Lanturn', 'Hyper Beam', 150),
#  ('Togetic', 'Giga Impact', 150),
#  ('Togetic', 'Focus Punch', 150),
#  ('Togetic', 'Hyper Beam', 150),
#  ('Xatu', 'Giga Impact', 150),
#  ('Xatu', 'Hyper Beam', 150),
#  ('Flaaffy', 'Focus Punch', 150),
#  ('Ampharos', 'Giga Impact', 150),
#  ('Ampharos', 'Focus Punch', 150),
#  ('Ampharos', 'Hyper Beam', 150),
#  ('Bellossom', 'Giga Impact', 150),
#  ('Bellossom', 'Hyper Beam', 150),
#  ('Marill', 'Focus Punch', 150),
#  ('Azumarill', 'Giga Impact', 150),
#  ('Azumarill', 'Focus Punch', 150),
#  ('Azumarill', 'Hyper Beam', 150),
#  ('Sudowoodo', 'Head Smash', 150),
#  ('Sudowoodo', 'Focus Punch', 150),
#  ('Sudowoodo', 'Explosion', 250),
#  ('Sudowoodo', 'Self-Destruct', 200),
#  ('Politoed', 'Giga Impact', 150),
#  ('Politoed', 'Focus Punch', 150),
#  ('Politoed', 'Hyper Beam', 150),
#  ('Jumpluff', 'Giga Impact', 150),
#  ('Jumpluff', 'Hyper Beam', 150),
#  ('Aipom', 'Focus Punch', 150),
#  ('Sunflora', 'Giga Impact', 150),
#  ('Sunflora', 'Hyper Beam', 150),
#  ('Quagsire', 'Giga Impact', 150),
#  ('Quagsire', 'Focus Punch', 150),
#  ('Quagsire', 'Hyper Beam', 150),
#  ('Espeon', 'Giga Impact', 150),
#  ('Espeon', 'Hyper Beam', 150),
#  ('Umbreon', 'Giga Impact', 150),
#  ('Umbreon', 'Hyper Beam', 150),
#  ('Slowking', 'Giga Impact', 150),
#  ('Slowking', 'Focus Punch', 150),
#  ('Slowking', 'Hyper Beam', 150),
#  ('Pineco', 'Explosion', 250),
#  ('Pineco', 'Self-Destruct', 200),
#  ('Forretress', 'Giga Impact', 150),
#  ('Forretress', 'Explosion', 250),
#  ('Forretress', 'Self-Destruct', 200),
#  ('Forretress', 'Hyper Beam', 150),
#  ('Steelix', 'Giga Impact', 150),
#  ('Steelix', 'Explosion', 250),
#  ('Steelix', 'Hyper Beam', 150),
#  ('Snubbull', 'Focus Punch', 150),
#  ('Granbull', 'Giga Impact', 150),
#  ('Granbull', 'Focus Punch', 150),
#  ('Granbull', 'Hyper Beam', 150),
#  ('Qwilfish', 'Explosion', 250),
#  ('Scizor', 'Giga Impact', 150),
#  ('Scizor', 'Hyper Beam', 150),
#  ('Heracross', 'Giga Impact', 150),
#  ('Heracross', 'Focus Punch', 150),
#  ('Heracross', 'Hyper Beam', 150),
#  ('Sneasel', 'Focus Punch', 150),
#  ('Teddiursa', 'Focus Punch', 150),
#  ('Ursaring', 'Giga Impact', 150),
#  ('Ursaring', 'Focus Punch', 150),
#  ('Ursaring', 'Hyper Beam', 150),
#  ('Magcargo', 'Giga Impact', 150),
#  ('Magcargo', 'Explosion', 250),
#  ('Magcargo', 'Hyper Beam', 150),
#  ('Piloswine', 'Giga Impact', 150),
#  ('Piloswine', 'Hyper Beam', 150),
#  ('Corsola', 'Head Smash', 150),
#  ('Corsola', 'Explosion', 250),
#  ('Remoraid', 'Hyper Beam', 150),
#  ('Octillery', 'Giga Impact', 150),
#  ('Octillery', 'Hyper Beam', 150),
#  ('Delibird', 'Focus Punch', 150),
#  ('Mantine', 'Giga Impact', 150),
#  ('Mantine', 'Hyper Beam', 150),
#  ('Houndoom', 'Giga Impact', 150),
#  ('Houndoom', 'Hyper Beam', 150),
#  ('Kingdra', 'Giga Impact', 150),
#  ('Kingdra', 'Hyper Beam', 150),
#  ('Phanpy', 'Head Smash', 150),
#  ('Donphan', 'Head Smash', 150),
#  ('Donphan', 'Giga Impact', 150),
#  ('Donphan', 'Hyper Beam', 150),
#  ('Porygon2', 'Giga Impact', 150),
#  ('Porygon2', 'Hyper Beam', 150),
#  ('Stantler', 'Giga Impact', 150),
#  ('Elekid', 'Focus Punch', 150),
#  ('Magby', 'Focus Punch', 150),
#  ('Miltank', 'Giga Impact', 150),
#  ('Miltank', 'Focus Punch', 150),
#  ('Miltank', 'Hyper Beam', 150),
#  ('Blissey', 'Giga Impact', 150),
#  ('Blissey', 'Focus Punch', 150),
#  ('Blissey', 'Hyper Beam', 150),
#  ('Raikou', 'Giga Impact', 150),
#  ('Raikou', 'Hyper Beam', 150),
#  ('Entei', 'Giga Impact', 150),
#  ('Entei', 'Hyper Beam', 150),
#  ('Suicune', 'Giga Impact', 150),
#  ('Suicune', 'Hyper Beam', 150),
#  ('Larvitar', 'Hyper Beam', 150),
#  ('Pupitar', 'Hyper Beam', 150),
#  ('Tyranitar', 'Giga Impact', 150),
#  ('Tyranitar', 'Focus Punch', 150),
#  ('Tyranitar', 'Hyper Beam', 150),
#  ('Lugia', 'Giga Impact', 150),
#  ('Lugia', 'Hyper Beam', 150),
#  ('Ho-oh', 'Giga Impact', 150),
#  ('Ho-oh', 'Hyper Beam', 150),
#  ('Celebi', 'Giga Impact', 150),
#  ('Celebi', 'Hyper Beam', 150),
#  ('Treecko', 'Frenzy Plant', 150),
#  ('Treecko', 'Focus Punch', 150),
#  ('Grovyle', 'Frenzy Plant', 150),
#  ('Grovyle', 'Focus Punch', 150),
#  ('Sceptile', 'Giga Impact', 150),
#  ('Sceptile', 'Frenzy Plant', 150),
#  ('Sceptile', 'Focus Punch', 150),
#  ('Sceptile', 'Hyper Beam', 150),
#  ('Torchic', 'Blast Burn', 150),
#  ('Combusken', 'Blast Burn', 150),
#  ('Combusken', 'Focus Punch', 150),
#  ('Blaziken', 'Giga Impact', 150),
#  ('Blaziken', 'Blast Burn', 150),
#  ('Blaziken', 'Focus Punch', 150),
#  ('Blaziken', 'Hyper Beam', 150),
#  ('Mudkip', 'Hydro Cannon', 150),
#  ('Marshtomp', 'Hydro Cannon', 150),
#  ('Swampert', 'Giga Impact', 150),
#  ('Swampert', 'Hydro Cannon', 150),
#  ('Swampert', 'Focus Punch', 150),
#  ('Swampert', 'Hyper Beam', 150),
#  ('Mightyena', 'Giga Impact', 150),
#  ('Mightyena', 'Hyper Beam', 150),
#  ('Linoone', 'Giga Impact', 150),
#  ('Linoone', 'Hyper Beam', 150),
#  ('Beautifly', 'Giga Impact', 150),
#  ('Beautifly', 'Hyper Beam', 150),
#  ('Dustox', 'Giga Impact', 150),
#  ('Dustox', 'Hyper Beam', 150),
#  ('Ludicolo', 'Giga Impact', 150),
#  ('Ludicolo', 'Focus Punch', 150),
#  ('Ludicolo', 'Hyper Beam', 150),
#  ('Seedot', 'Explosion', 250),
#  ('Nuzleaf', 'Explosion', 250),
#  ('Nuzleaf', 'Hyper Beam', 150),
#  ('Shiftry', 'Giga Impact', 150),
#  ('Shiftry', 'Explosion', 250),
#  ('Shiftry', 'Hyper Beam', 150),
#  ('Swellow', 'Giga Impact', 150),
#  ('Swellow', 'Hyper Beam', 150),
#  ('Pelipper', 'Giga Impact', 150),
#  ('Pelipper', 'Hyper Beam', 150),
#  ('Gardevoir', 'Giga Impact', 150),
#  ('Gardevoir', 'Hyper Beam', 150),
#  ('Masquerain', 'Giga Impact', 150),
#  ('Masquerain', 'Hyper Beam', 150),
#  ('Shroomish', 'Focus Punch', 150),
#  ('Breloom', 'Giga Impact', 150),
#  ('Breloom', 'Focus Punch', 150),
#  ('Breloom', 'Hyper Beam', 150),
#  ('Slakoth', 'Focus Punch', 150),
#  ('Vigoroth', 'Focus Punch', 150),
#  ('Slaking', 'Giga Impact', 150),
#  ('Slaking', 'Focus Punch', 150),
#  ('Slaking', 'Hyper Beam', 150),
#  ('Ninjask', 'Giga Impact', 150),
#  ('Ninjask', 'Hyper Beam', 150),
#  ('Shedinja', 'Giga Impact', 150),
#  ('Shedinja', 'Hyper Beam', 150),
#  ('Exploud', 'Giga Impact', 150),
#  ('Exploud', 'Hyper Beam', 150),
#  ('Makuhita', 'Focus Punch', 150),
#  ('Hariyama', 'Giga Impact', 150),
#  ('Hariyama', 'Focus Punch', 150),
#  ('Hariyama', 'Hyper Beam', 150),
#  ('Nosepass', 'Explosion', 250),
#  ('Delcatty', 'Giga Impact', 150),
#  ('Delcatty', 'Hyper Beam', 150),
#  ('Sableye', 'Focus Punch', 150),
#  ('Mawile', 'Giga Impact', 150),
#  ('Mawile', 'Focus Punch', 150),
#  ('Mawile', 'Hyper Beam', 150),
#  ('Aron', 'Head Smash', 150),
#  ('Lairon', 'Head Smash', 150),
#  ('Aggron', 'Head Smash', 150),
#  ('Aggron', 'Giga Impact', 150),
#  ('Aggron', 'Focus Punch', 150),
#  ('Aggron', 'Hyper Beam', 150),
#  ('Meditite', 'Focus Punch', 150),
#  ('Medicham', 'Giga Impact', 150),
#  ('Medicham', 'Focus Punch', 150),
#  ('Medicham', 'Hyper Beam', 150),
#  ('Manectric', 'Giga Impact', 150),
#  ('Manectric', 'Hyper Beam', 150),
#  ('Volbeat', 'Focus Punch', 150),
#  ('Illumise', 'Focus Punch', 150),
#  ('Gulpin', 'Explosion', 250),
#  ('Swalot', 'Giga Impact', 150),
#  ('Swalot', 'Explosion', 250),
#  ('Swalot', 'Hyper Beam', 150),
#  ('Sharpedo', 'Giga Impact', 150),
#  ('Sharpedo', 'Hyper Beam', 150),
#  ('Wailord', 'Giga Impact', 150),
#  ('Wailord', 'Hyper Beam', 150),
#  ('Camerupt', 'Giga Impact', 150),
#  ('Camerupt', 'Explosion', 250),
#  ('Camerupt', 'Hyper Beam', 150),
#  ('Torkoal', 'Giga Impact', 150),
#  ('Torkoal', 'Explosion', 250),
#  ('Torkoal', 'Hyper Beam', 150),
#  ('Grumpig', 'Giga Impact', 150),
#  ('Grumpig', 'Focus Punch', 150),
#  ('Grumpig', 'Hyper Beam', 150),
#  ('Spinda', 'Focus Punch', 150),
#  ('Trapinch', 'Hyper Beam', 150),
#  ('Vibrava', 'Hyper Beam', 150),
#  ('Flygon', 'Giga Impact', 150),
#  ('Flygon', 'Hyper Beam', 150),
#  ('Cacnea', 'Focus Punch', 150),
#  ('Cacturne', 'Giga Impact', 150),
#  ('Cacturne', 'Focus Punch', 150),
#  ('Cacturne', 'Hyper Beam', 150),
#  ('Altaria', 'Giga Impact', 150),
#  ('Altaria', 'Hyper Beam', 150),
#  ('Zangoose', 'Focus Punch', 150),
#  ('Lunatone', 'Giga Impact', 150),
#  ('Lunatone', 'Explosion', 250),
#  ('Lunatone', 'Hyper Beam', 150),
#  ('Solrock', 'Giga Impact', 150),
#  ('Solrock', 'Explosion', 250),
#  ('Solrock', 'Hyper Beam', 150),
#  ('Whiscash', 'Giga Impact', 150),
#  ('Whiscash', 'Hyper Beam', 150),
#  ('Crawdaunt', 'Giga Impact', 150),
#  ('Crawdaunt', 'Hyper Beam', 150),
#  ('Baltoy', 'Explosion', 250),
#  ('Baltoy', 'Self-Destruct', 200),
#  ('Claydol', 'Giga Impact', 150),
#  ('Claydol', 'Explosion', 250),
#  ('Claydol', 'Self-Destruct', 200),
#  ('Claydol', 'Hyper Beam', 150),
#  ('Cradily', 'Giga Impact', 150),
#  ('Cradily', 'Hyper Beam', 150),
#  ('Armaldo', 'Giga Impact', 150),
#  ('Armaldo', 'Hyper Beam', 150),
#  ('Milotic', 'Giga Impact', 150),
#  ('Milotic', 'Hyper Beam', 150),
#  ('Kecleon', 'Focus Punch', 150),
#  ('Banette', 'Giga Impact', 150),
#  ('Banette', 'Hyper Beam', 150),
#  ('Dusclops', 'Giga Impact', 150),
#  ('Dusclops', 'Focus Punch', 150),
#  ('Dusclops', 'Hyper Beam', 150),
#  ('Tropius', 'Giga Impact', 150),
#  ('Tropius', 'Hyper Beam', 150),
#  ('Absol', 'Giga Impact', 150),
#  ('Absol', 'Hyper Beam', 150),
#  ('Glalie', 'Giga Impact', 150),
#  ('Glalie', 'Explosion', 250),
#  ('Glalie', 'Hyper Beam', 150),
#  ('Walrein', 'Giga Impact', 150),
#  ('Walrein', 'Hyper Beam', 150),
#  ('Huntail', 'Giga Impact', 150),
#  ('Huntail', 'Hyper Beam', 150),
#  ('Gorebyss', 'Giga Impact', 150),
#  ('Gorebyss', 'Hyper Beam', 150),
#  ('Relicanth', 'Head Smash', 150),
#  ('Relicanth', 'Giga Impact', 150),
#  ('Relicanth', 'Hyper Beam', 150),
#  ('Salamence', 'Giga Impact', 150),
#  ('Salamence', 'Hyper Beam', 150),
#  ('Metang', 'Explosion', 250),
#  ('Metang', 'Hyper Beam', 150),
#  ('Metagross', 'Giga Impact', 150),
#  ('Metagross', 'Explosion', 250),
#  ('Metagross', 'Hyper Beam', 150),
#  ('Regirock', 'Giga Impact', 150),
#  ('Regirock', 'Focus Punch', 150),
#  ('Regirock', 'Explosion', 250),
#  ('Regirock', 'Hyper Beam', 150),
#  ('Regice', 'Giga Impact', 150),
#  ('Regice', 'Focus Punch', 150),
#  ('Regice', 'Explosion', 250),
#  ('Regice', 'Hyper Beam', 150),
#  ('Registeel', 'Giga Impact', 150),
#  ('Registeel', 'Focus Punch', 150),
#  ('Registeel', 'Explosion', 250),
#  ('Registeel', 'Hyper Beam', 150),
#  ('Latias', 'Giga Impact', 150),
#  ('Latias', 'Hyper Beam', 150),
#  ('Latios', 'Giga Impact', 150),
#  ('Latios', 'Hyper Beam', 150),
#  ('Kyogre', 'Giga Impact', 150),
#  ('Kyogre', 'Hyper Beam', 150),
#  ('Groudon', 'Giga Impact', 150),
#  ('Groudon', 'Hyper Beam', 150),
#  ('Rayquaza', 'Giga Impact', 150),
#  ('Rayquaza', 'Hyper Beam', 150),
#  ('Jirachi', 'Giga Impact', 150),
#  ('Jirachi', 'Hyper Beam', 150),
#  ('Turtwig', 'Frenzy Plant', 150),
#  ('Grotle', 'Frenzy Plant', 150),
#  ('Torterra', 'Giga Impact', 150),
#  ('Torterra', 'Frenzy Plant', 150),
#  ('Torterra', 'Hyper Beam', 150),
#  ('Chimchar', 'Blast Burn', 150),
#  ('Chimchar', 'Focus Punch', 150),
#  ('Monferno', 'Blast Burn', 150),
#  ('Monferno', 'Focus Punch', 150),
#  ('Infernape', 'Giga Impact', 150),
#  ('Infernape', 'Blast Burn', 150),
#  ('Infernape', 'Focus Punch', 150),
#  ('Infernape', 'Hyper Beam', 150),
#  ('Piplup', 'Hydro Cannon', 150),
#  ('Prinplup', 'Hydro Cannon', 150),
#  ('Empoleon', 'Giga Impact', 150),
#  ('Empoleon', 'Hydro Cannon', 150),
#  ('Empoleon', 'Hyper Beam', 150),
#  ('Staraptor', 'Giga Impact', 150),
#  ('Staraptor', 'Hyper Beam', 150),
#  ('Bibarel', 'Giga Impact', 150),
#  ('Bibarel', 'Focus Punch', 150),
#  ('Bibarel', 'Hyper Beam', 150),
#  ('Kricketune', 'Giga Impact', 150),
#  ('Kricketune', 'Hyper Beam', 150),
#  ('Luxray', 'Giga Impact', 150),
#  ('Luxray', 'Hyper Beam', 150),
#  ('Roserade', 'Giga Impact', 150),
#  ('Roserade', 'Hyper Beam', 150),
#  ('Cranidos', 'Head Smash', 150),
#  ('Rampardos', 'Head Smash', 150),
#  ('Rampardos', 'Giga Impact', 150),
#  ('Rampardos', 'Focus Punch', 150),
#  ('Rampardos', 'Hyper Beam', 150),
#  ('Bastiodon', 'Giga Impact', 150),
#  ('Bastiodon', 'Hyper Beam', 150),
#  ('Mothim', 'Giga Impact', 150),
#  ('Mothim', 'Hyper Beam', 150),
#  ('Vespiquen', 'Giga Impact', 150),
#  ('Vespiquen', 'Hyper Beam', 150),
#  ('Buizel', 'Focus Punch', 150),
#  ('Floatzel', 'Giga Impact', 150),
#  ('Floatzel', 'Focus Punch', 150),
#  ('Floatzel', 'Hyper Beam', 150),
#  ('Cherrim', 'Giga Impact', 150),
#  ('Cherrim', 'Hyper Beam', 150),
#  ('Gastrodon', 'Giga Impact', 150),
#  ('Gastrodon', 'Hyper Beam', 150),
#  ('Ambipom', 'Giga Impact', 150),
#  ('Ambipom', 'Focus Punch', 150),
#  ('Ambipom', 'Hyper Beam', 150),
#  ('Drifloon', 'Explosion', 250),
#  ('Drifblim', 'Giga Impact', 150),
#  ('Drifblim', 'Explosion', 250),
#  ('Drifblim', 'Hyper Beam', 150),
#  ('Buneary', 'Focus Punch', 150),
#  ('Lopunny', 'Giga Impact', 150),
#  ('Lopunny', 'Focus Punch', 150),
#  ('Lopunny', 'Hyper Beam', 150),
#  ('Mismagius', 'Giga Impact', 150),
#  ('Mismagius', 'Hyper Beam', 150),
#  ('Honchkrow', 'Giga Impact', 150),
#  ('Honchkrow', 'Hyper Beam', 150),
#  ('Purugly', 'Giga Impact', 150),
#  ('Purugly', 'Hyper Beam', 150),
#  ('Stunky', 'Explosion', 250),
#  ('Skuntank', 'Giga Impact', 150),
#  ('Skuntank', 'Explosion', 250),
#  ('Skuntank', 'Hyper Beam', 150),
#  ('Bronzong', 'Giga Impact', 150),
#  ('Bronzong', 'Explosion', 250),
#  ('Bronzong', 'Hyper Beam', 150),
#  ('Bonsly', 'Explosion', 250),
#  ('Bonsly', 'Self-Destruct', 200),
#  ('Mime Jr.', 'Focus Punch', 150),
#  ('Spiritomb', 'Giga Impact', 150),
#  ('Spiritomb', 'Hyper Beam', 150),
#  ('Garchomp', 'Giga Impact', 150),
#  ('Garchomp', 'Hyper Beam', 150),
#  ('Munchlax', 'Focus Punch', 150),
#  ('Munchlax', 'Self-Destruct', 200),
#  ('Riolu', 'Focus Punch', 150),
#  ('Lucario', 'Giga Impact', 150),
#  ('Lucario', 'Focus Punch', 150),
#  ('Lucario', 'Hyper Beam', 150),
#  ('Hippowdon', 'Giga Impact', 150),
#  ('Hippowdon', 'Hyper Beam', 150),
#  ('Drapion', 'Giga Impact', 150),
#  ('Drapion', 'Hyper Beam', 150),
#  ('Croagunk', 'Focus Punch', 150),
#  ('Toxicroak', 'Giga Impact', 150),
#  ('Toxicroak', 'Focus Punch', 150),
#  ('Toxicroak', 'Hyper Beam', 150),
#  ('Carnivine', 'Giga Impact', 150),
#  ('Carnivine', 'Hyper Beam', 150),
#  ('Lumineon', 'Giga Impact', 150),
#  ('Lumineon', 'Hyper Beam', 150),
#  ('Abomasnow', 'Giga Impact', 150),
#  ('Abomasnow', 'Focus Punch', 150),
#  ('Abomasnow', 'Hyper Beam', 150),
#  ('Weavile', 'Giga Impact', 150),
#  ('Weavile', 'Focus Punch', 150),
#  ('Weavile', 'Hyper Beam', 150),
#  ('Magnezone', 'Giga Impact', 150),
#  ('Magnezone', 'Explosion', 250),
#  ('Magnezone', 'Hyper Beam', 150),
#  ('Lickilicky', 'Giga Impact', 150),
#  ('Lickilicky', 'Focus Punch', 150),
#  ('Lickilicky', 'Explosion', 250),
#  ('Lickilicky', 'Hyper Beam', 150),
#  ('Rhyperior', 'Rock Wrecker', 150),
#  ('Rhyperior', 'Giga Impact', 150),
#  ('Rhyperior', 'Focus Punch', 150),
#  ('Rhyperior', 'Hyper Beam', 150),
#  ('Tangrowth', 'Giga Impact', 150),
#  ('Tangrowth', 'Hyper Beam', 150),
#  ('Electivire', 'Giga Impact', 150),
#  ('Electivire', 'Focus Punch', 150),
#  ('Electivire', 'Hyper Beam', 150),
#  ('Magmortar', 'Giga Impact', 150),
#  ('Magmortar', 'Focus Punch', 150),
#  ('Magmortar', 'Hyper Beam', 150),
#  ('Togekiss', 'Giga Impact', 150),
#  ('Togekiss', 'Focus Punch', 150),
#  ('Togekiss', 'Hyper Beam', 150),
#  ('Yanmega', 'Giga Impact', 150),
#  ('Yanmega', 'Hyper Beam', 150),
#  ('Leafeon', 'Giga Impact', 150),
#  ('Leafeon', 'Hyper Beam', 150),
#  ('Glaceon', 'Giga Impact', 150),
#  ('Glaceon', 'Hyper Beam', 150),
#  ('Gliscor', 'Giga Impact', 150),
#  ('Gliscor', 'Hyper Beam', 150),
#  ('Mamoswine', 'Giga Impact', 150),
#  ('Mamoswine', 'Hyper Beam', 150),
#  ('Porygon-Z', 'Giga Impact', 150),
#  ('Porygon-Z', 'Hyper Beam', 150),
#  ('Gallade', 'Giga Impact', 150),
#  ('Gallade', 'Focus Punch', 150),
#  ('Gallade', 'Hyper Beam', 150),
#  ('Probopass', 'Giga Impact', 150),
#  ('Probopass', 'Explosion', 250),
#  ('Probopass', 'Hyper Beam', 150),
#  ('Dusknoir', 'Giga Impact', 150),
#  ('Dusknoir', 'Focus Punch', 150),
#  ('Dusknoir', 'Hyper Beam', 150),
#  ('Froslass', 'Giga Impact', 150),
#  ('Froslass', 'Hyper Beam', 150),
#  ('Uxie', 'Giga Impact', 150),
#  ('Uxie', 'Hyper Beam', 150),
#  ('Mesprit', 'Giga Impact', 150),
#  ('Mesprit', 'Hyper Beam', 150),
#  ('Azelf', 'Giga Impact', 150),
#  ('Azelf', 'Explosion', 250),
#  ('Azelf', 'Hyper Beam', 150),
#  ('Dialga', 'Roar of Time', 150),
#  ('Dialga', 'Giga Impact', 150),
#  ('Dialga', 'Hyper Beam', 150),
#  ('Palkia', 'Giga Impact', 150),
#  ('Palkia', 'Focus Punch', 150),
#  ('Palkia', 'Hyper Beam', 150),
#  ('Heatran', 'Giga Impact', 150),
#  ('Heatran', 'Explosion', 250),
#  ('Heatran', 'Hyper Beam', 150),
#  ('Regigigas', 'Giga Impact', 150),
#  ('Regigigas', 'Focus Punch', 150),
#  ('Regigigas', 'Hyper Beam', 150),
#  ('Cresselia', 'Giga Impact', 150),
#  ('Cresselia', 'Hyper Beam', 150),
#  ('Manaphy', 'Giga Impact', 150),
#  ('Manaphy', 'Hyper Beam', 150),
#  ('Darkrai', 'Giga Impact', 150),
#  ('Darkrai', 'Focus Punch', 150),
#  ('Darkrai', 'Hyper Beam', 150),
#  ('Arceus', 'Giga Impact', 150),
#  ('Arceus', 'Hyper Beam', 150),
#  ('Victini', 'Giga Impact', 150),
#  ('Victini', 'Hyper Beam', 150),
#  ('Snivy', 'Frenzy Plant', 150),
#  ('Servine', 'Frenzy Plant', 150),
#  ('Serperior', 'Giga Impact', 150),
#  ('Serperior', 'Frenzy Plant', 150),
#  ('Serperior', 'Hyper Beam', 150),
#  ('Tepig', 'Head Smash', 150),
#  ('Tepig', 'Blast Burn', 150),
#  ('Pignite', 'Head Smash', 150),
#  ('Pignite', 'Blast Burn', 150),
#  ('Pignite', 'Focus Punch', 150),
#  ('Emboar', 'Head Smash', 150),
#  ('Emboar', 'Giga Impact', 150),
#  ('Emboar', 'Blast Burn', 150),
#  ('Emboar', 'Focus Punch', 150),
#  ('Emboar', 'Hyper Beam', 150),
#  ('Oshawott', 'Hydro Cannon', 150),
#  ('Dewott', 'Hydro Cannon', 150),
#  ('Samurott', 'Giga Impact', 150),
#  ('Samurott', 'Hydro Cannon', 150),
#  ('Samurott', 'Hyper Beam', 150),
#  ('Watchog', 'Giga Impact', 150),
#  ('Watchog', 'Focus Punch', 150),
#  ('Watchog', 'Hyper Beam', 150),
#  ('Lillipup', 'Giga Impact', 150),
#  ('Herdier', 'Giga Impact', 150),
#  ('Stoutland', 'Giga Impact', 150),
#  ('Stoutland', 'Hyper Beam', 150),
#  ('Liepard', 'Giga Impact', 150),
#  ('Liepard', 'Hyper Beam', 150),
#  ('Pansage', 'Frenzy Plant', 150),
#  ('Pansage', 'Focus Punch', 150),
#  ('Simisage', 'Giga Impact', 150),
#  ('Simisage', 'Frenzy Plant', 150),
#  ('Simisage', 'Focus Punch', 150),
#  ('Simisage', 'Hyper Beam', 150),
#  ('Pansear', 'Blast Burn', 150),
#  ('Pansear', 'Focus Punch', 150),
#  ('Simisear', 'Giga Impact', 150),
#  ('Simisear', 'Blast Burn', 150),
#  ('Simisear', 'Focus Punch', 150),
#  ('Simisear', 'Hyper Beam', 150),
#  ('Panpour', 'Hydro Cannon', 150),
#  ('Panpour', 'Focus Punch', 150),
#  ('Simipour', 'Giga Impact', 150),
#  ('Simipour', 'Hydro Cannon', 150),
#  ('Simipour', 'Focus Punch', 150),
#  ('Simipour', 'Hyper Beam', 150),
#  ('Musharna', 'Giga Impact', 150),
#  ('Musharna', 'Hyper Beam', 150),
#  ('Unfezant', 'Giga Impact', 150),
#  ('Unfezant', 'Hyper Beam', 150),
#  ('Zebstrika', 'Giga Impact', 150),
#  ('Zebstrika', 'Hyper Beam', 150),
#  ('Roggenrola', 'Explosion', 250),
#  ('Boldore', 'Explosion', 250),
#  ('Gigalith', 'Giga Impact', 150),
#  ('Gigalith', 'Explosion', 250),
#  ('Gigalith', 'Hyper Beam', 150),
#  ('Swoobat', 'Giga Impact', 150),
#  ('Swoobat', 'Hyper Beam', 150),
#  ('Excadrill', 'Giga Impact', 150),
#  ('Excadrill', 'Hyper Beam', 150),
#  ('Audino', 'Focus Punch', 150),
#  ('Audino', 'Hyper Beam', 150),
#  ('Timburr', 'Focus Punch', 150),
#  ('Gurdurr', 'Focus Punch', 150),
#  ('Conkeldurr', 'Giga Impact', 150),
#  ('Conkeldurr', 'Focus Punch', 150),
#  ('Conkeldurr', 'Hyper Beam', 150),
#  ('Palpitoad', 'Focus Punch', 150),
#  ('Seismitoad', 'Giga Impact', 150),
#  ('Seismitoad', 'Focus Punch', 150),
#  ('Seismitoad', 'Hyper Beam', 150),
#  ('Throh', 'Giga Impact', 150),
#  ('Throh', 'Focus Punch', 150),
#  ('Sawk', 'Giga Impact', 150),
#  ('Sawk', 'Focus Punch', 150),
#  ('Leavanny', 'Giga Impact', 150),
#  ('Leavanny', 'Hyper Beam', 150),
#  ('Scolipede', 'Giga Impact', 150),
#  ('Scolipede', 'Hyper Beam', 150),
#  ('Whimsicott', 'Giga Impact', 150),
#  ('Whimsicott', 'Hyper Beam', 150),
#  ('Lilligant', 'Giga Impact', 150),
#  ('Lilligant', 'Hyper Beam', 150),
#  ('Krokorok', 'Focus Punch', 150),
#  ('Krookodile', 'Giga Impact', 150),
#  ('Krookodile', 'Focus Punch', 150),
#  ('Krookodile', 'Hyper Beam', 150),
#  ('Darumaka', 'Focus Punch', 150),
#  ('Dwebble', 'Rock Wrecker', 150),
#  ('Crustle', 'Rock Wrecker', 150),
#  ('Crustle', 'Giga Impact', 150),
#  ('Crustle', 'Hyper Beam', 150),
#  ('Scraggy', 'Head Smash', 150),
#  ('Scraggy', 'Focus Punch', 150),
#  ('Scrafty', 'Head Smash', 150),
#  ('Scrafty', 'Giga Impact', 150),
#  ('Scrafty', 'Focus Punch', 150),
#  ('Scrafty', 'Hyper Beam', 150),
#  ('Sigilyph', 'Hyper Beam', 150),
#  ('Cofagrigus', 'Giga Impact', 150),
#  ('Cofagrigus', 'Hyper Beam', 150),
#  ('Carracosta', 'Giga Impact', 150),
#  ('Carracosta', 'Hyper Beam', 150),
#  ('Archen', 'Head Smash', 150),
#  ('Archeops', 'Head Smash', 150),
#  ('Archeops', 'Giga Impact', 150),
#  ('Archeops', 'Hyper Beam', 150),
#  ('Trubbish', 'Explosion', 250),
#  ('Trubbish', 'Self-Destruct', 200),
#  ('Garbodor', 'Giga Impact', 150),
#  ('Garbodor', 'Explosion', 250),
#  ('Garbodor', 'Self-Destruct', 200),
#  ('Garbodor', 'Hyper Beam', 150),
#  ('Zoroark', 'Giga Impact', 150),
#  ('Zoroark', 'Hyper Beam', 150),
#  ('Cinccino', 'Giga Impact', 150),
#  ('Cinccino', 'Hyper Beam', 150),
#  ('Gothitelle', 'Giga Impact', 150),
#  ('Gothitelle', 'Hyper Beam', 150),
#  ('Solosis', 'Explosion', 250),
#  ('Duosion', 'Explosion', 250),
#  ('Reuniclus', 'Giga Impact', 150),
#  ('Reuniclus', 'Focus Punch', 150),
#  ('Reuniclus', 'Explosion', 250),
#  ('Reuniclus', 'Hyper Beam', 150),
#  ('Swanna', 'Giga Impact', 150),
#  ('Swanna', 'Hyper Beam', 150),
#  ('Vanillite', 'Explosion', 250),
#  ('Vanillish', 'Explosion', 250),
#  ('Vanilluxe', 'Giga Impact', 150),
#  ('Vanilluxe', 'Explosion', 250),
#  ('Vanilluxe', 'Hyper Beam', 150),
#  ('Sawsbuck', 'Giga Impact', 150),
#  ('Sawsbuck', 'Hyper Beam', 150),
#  ('Escavalier', 'Giga Impact', 150),
#  ('Escavalier', 'Hyper Beam', 150),
#  ('Amoonguss', 'Giga Impact', 150),
#  ('Amoonguss', 'Hyper Beam', 150),
#  ('Jellicent', 'Giga Impact', 150),
#  ('Jellicent', 'Hyper Beam', 150),
#  ('Galvantula', 'Giga Impact', 150),
#  ('Galvantula', 'Hyper Beam', 150),
#  ('Ferroseed', 'Explosion', 250),
#  ('Ferroseed', 'Self-Destruct', 200),
#  ('Ferrothorn', 'Giga Impact', 150),
#  ('Ferrothorn', 'Explosion', 250),
#  ('Ferrothorn', 'Self-Destruct', 200),
#  ('Ferrothorn', 'Hyper Beam', 150),
#  ('Klink', 'Hyper Beam', 150),
#  ('Klang', 'Hyper Beam', 150),
#  ('Klinklang', 'Giga Impact', 150),
#  ('Klinklang', 'Hyper Beam', 150),
#  ('Eelektross', 'Giga Impact', 150),
#  ('Eelektross', 'Focus Punch', 150),
#  ('Eelektross', 'Hyper Beam', 150),
#  ('Beheeyem', 'Giga Impact', 150),
#  ('Beheeyem', 'Hyper Beam', 150),
#  ('Chandelure', 'Giga Impact', 150),
#  ('Chandelure', 'Hyper Beam', 150),
#  ('Axew', 'Giga Impact', 150),
#  ('Fraxure', 'Giga Impact', 150),
#  ('Haxorus', 'Giga Impact', 150),
#  ('Haxorus', 'Hyper Beam', 150),
#  ('Cubchoo', 'Focus Punch', 150),
#  ('Beartic', 'Giga Impact', 150),
#  ('Beartic', 'Focus Punch', 150),
#  ('Beartic', 'Hyper Beam', 150),
#  ('Cryogonal', 'Explosion', 250),
#  ('Cryogonal', 'Hyper Beam', 150),
#  ('Accelgor', 'Giga Impact', 150),
#  ('Accelgor', 'Hyper Beam', 150),
#  ('Mienfoo', 'Focus Punch', 150),
#  ('Mienshao', 'Giga Impact', 150),
#  ('Mienshao', 'Focus Punch', 150),
#  ('Mienshao', 'Hyper Beam', 150),
#  ('Druddigon', 'Giga Impact', 150),
#  ('Druddigon', 'Hyper Beam', 150),
#  ('Golett', 'Focus Punch', 150),
#  ('Golurk', 'Giga Impact', 150),
#  ('Golurk', 'Focus Punch', 150),
#  ('Golurk', 'Hyper Beam', 150),
#  ('Bisharp', 'Giga Impact', 150),
#  ('Bisharp', 'Hyper Beam', 150),
#  ('Bouffalant', 'Giga Impact', 150),
#  ('Braviary', 'Giga Impact', 150),
#  ('Braviary', 'Hyper Beam', 150),
#  ('Mandibuzz', 'Giga Impact', 150),
#  ('Mandibuzz', 'Hyper Beam', 150),
#  ('Heatmor', 'Giga Impact', 150),
#  ('Heatmor', 'Focus Punch', 150),
#  ('Durant', 'Giga Impact', 150),
#  ('Deino', 'Head Smash', 150),
#  ('Zweilous', 'Head Smash', 150),
#  ('Hydreigon', 'Head Smash', 150),
#  ('Hydreigon', 'Giga Impact', 150),
#  ('Hydreigon', 'Hyper Beam', 150),
#  ('Volcarona', 'Giga Impact', 150),
#  ('Volcarona', 'Hyper Beam', 150),
#  ('Cobalion', 'Giga Impact', 150),
#  ('Cobalion', 'Hyper Beam', 150),
#  ('Terrakion', 'Giga Impact', 150),
#  ('Terrakion', 'Hyper Beam', 150),
#  ('Virizion', 'Giga Impact', 150),
#  ('Virizion', 'Hyper Beam', 150),
#  ('Reshiram', 'Giga Impact', 150),
#  ('Reshiram', 'Hyper Beam', 150),
#  ('Zekrom', 'Giga Impact', 150),
#  ('Zekrom', 'Hyper Beam', 150),
#  ('Kyurem', 'Giga Impact', 150),
#  ('Kyurem', 'Hyper Beam', 150),
#  ('Genesect', 'Giga Impact', 150),
#  ('Genesect', 'Explosion', 250),
#  ('Genesect', 'Self-Destruct', 200),
#  ('Genesect', 'Hyper Beam', 150),
#  ('Chespin', 'Frenzy Plant', 150),
#  ('Chespin', 'Focus Punch', 150),
#  ('Quilladin', 'Frenzy Plant', 150),
#  ('Quilladin', 'Focus Punch', 150),
#  ('Chesnaught', 'Giga Impact', 150),
#  ('Chesnaught', 'Frenzy Plant', 150),
#  ('Chesnaught', 'Focus Punch', 150),
#  ('Chesnaught', 'Hyper Beam', 150),
#  ('Fennekin', 'Blast Burn', 150),
#  ('Braixen', 'Blast Burn', 150),
#  ('Delphox', 'Giga Impact', 150),
#  ('Delphox', 'Blast Burn', 150),
#  ('Delphox', 'Hyper Beam', 150),
#  ('Froakie', 'Hydro Cannon', 150),
#  ('Frogadier', 'Hydro Cannon', 150),
#  ('Greninja', 'Giga Impact', 150),
#  ('Greninja', 'Hydro Cannon', 150),
#  ('Greninja', 'Hyper Beam', 150),
#  ('Diggersby', 'Giga Impact', 150),
#  ('Diggersby', 'Focus Punch', 150),
#  ('Diggersby', 'Hyper Beam', 150),
#  ('Talonflame', 'Giga Impact', 150),
#  ('Talonflame', 'Hyper Beam', 150),
#  ('Vivillon', 'Giga Impact', 150),
#  ...]

# %% [markdown]
# # Find pokemon with base attack of at lest __ that can learn a priority move. Get the Pokemon's name, attack stat, and name of the move with its priorityF

# %%
q16= """SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
JOIN move
WHERE (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(
    SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move1 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0
            
GROUP BY type_1);"""

strong_priority_data = read_query(connection, q16)
display(strong_priority_data)
# Out:
# [('Scizor', 'Bug', 130, 'Feint', 2),
#  ('Breloom', 'Grass', 130, 'Mach Punch', 1),
#  ('Archeops', 'Rock', 140, 'Quick Attack', 1),
#  ('Pangoro', 'Fighting', 124, 'Bullet Punch', 1),
#  ('Golisopod', 'Bug', 125, 'First Impression', 2)]

# %%
stupid_string2 = ""

for x in range(175): 
    stupid_string2 += ("""OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move""" +str(x)+""" LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)\n""")
    
print(stupid_string2)
# Out:
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move0 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move1 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move2 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move3 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move4 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move5 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move6 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move7 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move8 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move9 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move10 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move11 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move12 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move13 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move14 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move15 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move16 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move17 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move18 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move19 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move20 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move21 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move22 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move23 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move24 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move25 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move26 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move27 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move28 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move29 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move30 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move31 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move32 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move33 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move34 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move35 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move36 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move37 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move38 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move39 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move40 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move41 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move42 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move43 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move44 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move45 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move46 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move47 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move48 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move49 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move50 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move51 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move52 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move53 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move54 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move55 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move56 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move57 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move58 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move59 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move60 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move61 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move62 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move63 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move64 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move65 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move66 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move67 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move68 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move69 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move70 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move71 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move72 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move73 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move74 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move75 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move76 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move77 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move78 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move79 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move80 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move81 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move82 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move83 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move84 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move85 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move86 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move87 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move88 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move89 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move90 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move91 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move92 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move93 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move94 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move95 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move96 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move97 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move98 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move99 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move100 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move101 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move102 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move103 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move104 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move105 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move106 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move107 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move108 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move109 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move110 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move111 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move112 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move113 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move114 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move115 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move116 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move117 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move118 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move119 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move120 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# ...
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move135 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move136 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move137 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move138 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move139 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move140 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move141 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move142 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move143 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move144 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move145 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move146 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move147 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move148 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move149 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move150 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move151 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move152 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move153 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move154 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move155 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move156 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move157 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move158 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move159 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move160 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move161 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move162 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move163 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move164 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move165 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move166 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move167 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move168 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move169 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move170 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move171 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move172 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move173 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)
# OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
#         JOIN move
#         JOIN moveset ON pokemon.name = moveset.species AND moveset.move174 LIKE CONCAT('%', move.move, '%')
#         WHERE move.priority > 0
#             AND pokemon.attack > 120
#             AND move.power > 0)

# %%
q17= """SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
JOIN move
WHERE (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(
    SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move1 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
            
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move2 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move3 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move4 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move5 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move6 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move7 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move8 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move9 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move10 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move11 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move12 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move13 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move14 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move15 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move16 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move17 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move18 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move19 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move20 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move21 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move22 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move23 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move24 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move25 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move26 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move27 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move28 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move29 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move30 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move31 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move32 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move33 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move34 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move35 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move36 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move37 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move38 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move39 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move40 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move41 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move42 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move43 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move44 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move45 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move46 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move47 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move48 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move49 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move50 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move51 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move52 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move53 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move54 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move55 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move56 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move57 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move58 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move59 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move60 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move61 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move62 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move63 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move64 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move65 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move66 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move67 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move68 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move69 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move70 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move71 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move72 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move73 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move74 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move75 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move76 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move77 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move78 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move79 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move80 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move81 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move82 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move83 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move84 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move85 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move86 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move87 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move88 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move89 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move90 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move91 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move92 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move93 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move94 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move95 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move96 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move97 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move98 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move99 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move100 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move101 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move102 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move103 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move104 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move105 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move106 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move107 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move108 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move109 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move110 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move111 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move112 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move113 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move114 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move115 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move116 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move117 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move118 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move119 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move120 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move121 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move122 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move123 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move124 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move125 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move126 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move127 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move128 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move129 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move130 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move131 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move132 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move133 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move134 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move135 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move136 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move137 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move138 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move139 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move140 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move141 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move142 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move143 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move144 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move145 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move146 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move147 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move148 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move149 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move150 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move151 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move152 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move153 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move154 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move155 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move156 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move157 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move158 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move159 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move160 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move161 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move162 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move163 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move164 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move165 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move166 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move167 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move168 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move169 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move170 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move171 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move172 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move173 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
OR (pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority) IN(SELECT pokemon.name, pokemon.type_1, pokemon.attack, move.move, move.priority FROM pokemon
        JOIN move
        JOIN moveset ON pokemon.name = moveset.species AND moveset.move174 LIKE CONCAT('%', move.move, '%')
        WHERE move.priority > 0
            AND pokemon.attack > 120
            AND move.power > 0)
ORDER BY pokemon.type_1            
;"""

strong_priority_data = read_query(connection, q17)
display(strong_priority_data)
# Out:
# [('Scizor', 'Bug', 130, 'Bullet Punch', 1),
#  ('Pinsir', 'Bug', 125, 'Feint', 2),
#  ('Pinsir', 'Bug', 125, 'Quick Attack', 1),
#  ('Pheromosa', 'Bug', 137, 'Feint', 2),
#  ('Scizor', 'Bug', 130, 'Vacuum Wave', 1),
#  ('Scizor', 'Bug', 130, 'Feint', 2),
#  ('Scizor', 'Bug', 130, 'Quick Attack', 1),
#  ('Heracross', 'Bug', 125, 'Feint', 2),
#  ('Golisopod', 'Bug', 125, 'Sucker Punch', 1),
#  ('Golisopod', 'Bug', 125, 'First Impression', 2),
#  ('Golisopod', 'Bug', 125, 'Aqua Jet', 1),
#  ('Escavalier', 'Bug', 135, 'Feint', 2),
#  ('Bisharp', 'Dark', 125, 'Sucker Punch', 1),
#  ('Yveltal', 'Dark', 131, 'Sucker Punch', 1),
#  ('Bisharp', 'Dark', 125, 'Feint', 2),
#  ('Absol', 'Dark', 130, 'Sucker Punch', 1),
#  ('Absol', 'Dark', 130, 'Feint', 2),
#  ('Absol', 'Dark', 130, 'Quick Attack', 1),
#  ('Honchkrow', 'Dark', 125, 'Sucker Punch', 1),
#  ('Honchkrow', 'Dark', 125, 'Feint', 2),
#  ('Dragonite', 'Dragon', 134, 'Aqua Jet', 1),
#  ('Dragonite', 'Dragon', 134, 'Extreme Speed', 2),
#  ('Rayquaza', 'Dragon', 150, 'Extreme Speed', 2),
#  ('Electivire', 'Electric', 123, 'Feint', 2),
#  ('Electivire', 'Electric', 123, 'Quick Attack', 1),
#  ('Conkeldurr', 'Fighting', 140, 'Mach Punch', 1),
#  ('Mienshao', 'Fighting', 125, 'Feint', 2),
#  ('Mienshao', 'Fighting', 125, 'Fake Out', 3),
#  ('Pangoro', 'Fighting', 124, 'Bullet Punch', 1),
#  ('Machamp', 'Fighting', 130, 'Bullet Punch', 1),
#  ('Marshadow', 'Fighting', 125, 'Shadow Sneak', 1),
#  ('Marshadow', 'Fighting', 125, 'Sucker Punch', 1),
#  ('Marshadow', 'Fighting', 125, 'Feint', 2),
#  ('Emboar', 'Fire', 123, 'Sucker Punch', 1),
#  ('Flareon', 'Fire', 130, 'Quick Attack', 1),
#  ('Breloom', 'Grass', 130, 'Mach Punch', 1),
#  ('Breloom', 'Grass', 130, 'Feint', 2),
#  ('Kartana', 'Grass', 181, 'Vacuum Wave', 1),
#  ('Mamoswine', 'Ice', 130, 'Ice Shard', 1),
#  ('Beartic', 'Ice', 130, 'Aqua Jet', 1),
#  ('Slaking', 'Normal', 160, 'Feint', 2),
#  ('Ursaring', 'Normal', 130, 'Feint', 2),
#  ('Gallade', 'Psychic', 125, 'Shadow Sneak', 1),
#  ('Gallade', 'Psychic', 125, 'Feint', 2),
#  ('Archeops', 'Rock', 140, 'Quick Attack', 1),
#  ('Armaldo', 'Rock', 125, 'Aqua Jet', 1),
#  ('Terrakion', 'Rock', 129, 'Quick Attack', 1),
#  ('Metagross', 'Steel', 135, 'Bullet Punch', 1)]

# %%
# create DataFrame using data
strong_priority_df = pd.DataFrame(strong_priority_data, columns =['Pokemon', 'Primary Type', 'Base Attack', 'Move', 'Priority'])
  
display(strong_priority_df)
# Out:
#        Pokemon Primary Type  Base Attack              Move  Priority
# 0       Scizor          Bug          130      Bullet Punch         1
# 1       Pinsir          Bug          125             Feint         2
# 2       Pinsir          Bug          125      Quick Attack         1
# 3    Pheromosa          Bug          137             Feint         2
# 4       Scizor          Bug          130       Vacuum Wave         1
# 5       Scizor          Bug          130             Feint         2
# 6       Scizor          Bug          130      Quick Attack         1
# 7    Heracross          Bug          125             Feint         2
# 8    Golisopod          Bug          125      Sucker Punch         1
# 9    Golisopod          Bug          125  First Impression         2
# 10   Golisopod          Bug          125          Aqua Jet         1
# 11  Escavalier          Bug          135             Feint         2
# 12     Bisharp         Dark          125      Sucker Punch         1
# 13     Yveltal         Dark          131      Sucker Punch         1
# 14     Bisharp         Dark          125             Feint         2
# 15       Absol         Dark          130      Sucker Punch         1
# 16       Absol         Dark          130             Feint         2
# 17       Absol         Dark          130      Quick Attack         1
# 18   Honchkrow         Dark          125      Sucker Punch         1
# 19   Honchkrow         Dark          125             Feint         2
# 20   Dragonite       Dragon          134          Aqua Jet         1
# 21   Dragonite       Dragon          134     Extreme Speed         2
# 22    Rayquaza       Dragon          150     Extreme Speed         2
# 23  Electivire     Electric          123             Feint         2
# 24  Electivire     Electric          123      Quick Attack         1
# 25  Conkeldurr     Fighting          140        Mach Punch         1
# 26    Mienshao     Fighting          125             Feint         2
# 27    Mienshao     Fighting          125          Fake Out         3
# 28     Pangoro     Fighting          124      Bullet Punch         1
# 29     Machamp     Fighting          130      Bullet Punch         1
# 30   Marshadow     Fighting          125      Shadow Sneak         1
# 31   Marshadow     Fighting          125      Sucker Punch         1
# 32   Marshadow     Fighting          125             Feint         2
# 33      Emboar         Fire          123      Sucker Punch         1
# 34     Flareon         Fire          130      Quick Attack         1
# 35     Breloom        Grass          130        Mach Punch         1
# 36     Breloom        Grass          130             Feint         2
# 37     Kartana        Grass          181       Vacuum Wave         1
# 38   Mamoswine          Ice          130         Ice Shard         1
# 39     Beartic          Ice          130          Aqua Jet         1
# 40     Slaking       Normal          160             Feint         2
# 41    Ursaring       Normal          130             Feint         2
# 42     Gallade      Psychic          125      Shadow Sneak         1
# 43     Gallade      Psychic          125             Feint         2
# 44    Archeops         Rock          140      Quick Attack         1
# 45     Armaldo         Rock          125          Aqua Jet         1
# 46   Terrakion         Rock          129      Quick Attack         1
# 47   Metagross        Steel          135      Bullet Punch         1

# %%
strong_priority_df.style.hide_index()\
                 .background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow0_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow0_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow1_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow1_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow2_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow2_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow3_col2 {
#             background-color:  #c8dcf0;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow3_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow4_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow4_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow5_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow5_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow6_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow6_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow7_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow7_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow8_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow8_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow9_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow9_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow10_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow10_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow11_col2 {
#             background-color:  #cfe1f2;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow11_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow12_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow12_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow13_col2 {
#             background-color:  #dce9f6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow13_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow14_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow14_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow15_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow15_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow16_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow16_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow17_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow17_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow18_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow18_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow19_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow19_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow20_col2 {
#             background-color:  #d2e3f3;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow20_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow21_col2 {
#             background-color:  #d2e3f3;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow21_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow22_col2 {
#             background-color:  #79b5d9;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow22_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow23_col2 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow23_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow24_col2 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow24_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow25_col2 {
#             background-color:  #b8d5ea;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow25_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow26_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow26_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow27_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow27_col4 {
#             background-color:  #08306b;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow28_col2 {
#             background-color:  #f4f9fe;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow28_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow29_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow29_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow30_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow30_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow31_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow31_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow32_col2 {
#             background-color:  #f1f7fd;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow32_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow33_col2 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow33_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow34_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow34_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow35_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow35_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow36_col2 {
#             background-color:  #dfecf7;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow36_col4 {
#             background-color:  #6aaed6;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow37_col2 {
#             background-color:  #08306b;
#         }    #T_6aee1440_add4_11eb_9ca4_94659cbb63cbrow37_col4 {
#             background-color:  #f7fbff;
#         }    #T_6aee144

# %% [markdown]
# # Get Pokemon with highest base stat total of each type and organize them by base stat total

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database

#thank you kind internet person!

q19 = """SELECT p1.name, p1.type_1, p1.type_2, p1.total_points
FROM pokemon p1
INNER JOIN
(
    SELECT type_1, MAX(total_points) AS max_stats
    FROM pokemon
    GROUP BY type_1
) p2
    ON p1.type_1 = p2.type_1 AND p1.total_points = p2.max_stats
ORDER BY p1.total_points DESC, type_1
;"""
# Out:
# MySQL Database connection successful

# %%
#fetchall method (used by read_query) returns a list of tuples
base_stat_by_type_data = read_query(connection, q19)
display(base_stat_by_type_data)
# Out:
# [('Eternatus Eternamax', 'Poison', 'Dragon', 1125),
#  ('Mega Rayquaza', 'Dragon', 'Flying', 780),
#  ('Mega Mewtwo X', 'Psychic', 'Fighting', 780),
#  ('Mega Mewtwo Y', 'Psychic', None, 780),
#  ('Primal Groudon', 'Ground', 'Fire', 770),
#  ('Primal Kyogre', 'Water', None, 770),
#  ('Zacian Crowned Sword', 'Fairy', 'Steel', 720),
#  ('Zamazenta Crowned Shield', 'Fighting', 'Steel', 720),
#  ('Arceus', 'Normal', None, 720),
#  ('Mega Diancie', 'Rock', 'Fairy', 700),
#  ('Mega Tyranitar', 'Rock', 'Dark', 700),
#  ('Mega Metagross', 'Steel', 'Psychic', 700),
#  ('Yveltal', 'Dark', 'Flying', 680),
#  ('Ho-oh', 'Fire', 'Flying', 680),
#  ('Giratina Origin Forme', 'Ghost', 'Dragon', 680),
#  ('Giratina Altered Forme', 'Ghost', 'Dragon', 680),
#  ('Mega Sceptile', 'Grass', 'Dragon', 630),
#  ('Mega Ampharos', 'Electric', 'Dragon', 610),
#  ('Genesect', 'Bug', 'Steel', 600),
#  ('Mega Pinsir', 'Bug', 'Flying', 600),
#  ('Mega Heracross', 'Bug', 'Fighting', 600),
#  ('Mega Scizor', 'Bug', 'Steel', 600),
#  ('Tornadus Incarnate Forme', 'Flying', None, 580),
#  ('Tornadus Therian Forme', 'Flying', None, 580),
#  ('Regice', 'Ice', None, 580),
#  ('Mega Glalie', 'Ice', None, 580),
#  ('Glastrier', 'Ice', None, 580),
#  ('Articuno', 'Ice', 'Flying', 580)]

# %%
# create DataFrame using data
base_stat_by_type_df = pd.DataFrame(base_stat_by_type_data, columns =['Pokemon', 'Type 1', 'Type 2', 'Base Stat Total'])
  
base_stat_by_type_df.style.hide_index()\
                 .background_gradient(cmap='Reds')\
                 .highlight_null(null_color='Grey')

    
#Can I make all the types have a different color?
# Out:
# <style  type="text/css" >
#     #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow0_col3 {
#             background-color:  #67000d;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow1_col3 {
#             background-color:  #fc9576;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow2_col3 {
#             background-color:  #fc9576;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow3_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow3_col3 {
#             background-color:  #fc9576;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow4_col3 {
#             background-color:  #fc9b7c;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow5_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow5_col3 {
#             background-color:  #fc9b7c;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow6_col3 {
#             background-color:  #fcb99f;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow7_col3 {
#             background-color:  #fcb99f;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow8_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow8_col3 {
#             background-color:  #fcb99f;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow9_col3 {
#             background-color:  #fcc4ad;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow10_col3 {
#             background-color:  #fcc4ad;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow11_col3 {
#             background-color:  #fcc4ad;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow12_col3 {
#             background-color:  #fdd0bc;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow13_col3 {
#             background-color:  #fdd0bc;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow14_col3 {
#             background-color:  #fdd0bc;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow15_col3 {
#             background-color:  #fdd0bc;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow16_col3 {
#             background-color:  #fee6da;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow17_col3 {
#             background-color:  #ffece3;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow18_col3 {
#             background-color:  #ffefe8;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow19_col3 {
#             background-color:  #ffefe8;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow20_col3 {
#             background-color:  #ffefe8;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow21_col3 {
#             background-color:  #ffefe8;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow22_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow22_col3 {
#             background-color:  #fff5f0;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow23_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow23_col3 {
#             background-color:  #fff5f0;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow24_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow24_col3 {
#             background-color:  #fff5f0;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow25_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow25_col3 {
#             background-color:  #fff5f0;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow26_col2 {
#             background-color:  Grey;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow26_col3 {
#             background-color:  #fff5f0;
#             : ;
#         }    #T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow27_col3 {
#             background-color:  #fff5f0;
#             : ;
#         }</style>
# <table id="T_e86c899c_b19a_11eb_8e04_94659cbb63cb" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Pokemon</th>
#         <th class="col_heading level0 col1" >Type 1</th>
#         <th class="col_heading level0 col2" >Type 2</th>
#         <th class="col_heading level0 col3" >Base Stat Total</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow0_col0" class="data row0 col0" >Eternatus Eternamax</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow0_col1" class="data row0 col1" >Poison</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow0_col2" class="data row0 col2" >Dragon</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow0_col3" class="data row0 col3" >1125</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow1_col0" class="data row1 col0" >Mega Rayquaza</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow1_col1" class="data row1 col1" >Dragon</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow1_col2" class="data row1 col2" >Flying</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow1_col3" class="data row1 col3" >780</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow2_col0" class="data row2 col0" >Mega Mewtwo X</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow2_col1" class="data row2 col1" >Psychic</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow2_col2" class="data row2 col2" >Fighting</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow2_col3" class="data row2 col3" >780</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow3_col0" class="data row3 col0" >Mega Mewtwo Y</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow3_col1" class="data row3 col1" >Psychic</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow3_col2" class="data row3 col2" >None</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow3_col3" class="data row3 col3" >780</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow4_col0" class="data row4 col0" >Primal Groudon</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow4_col1" class="data row4 col1" >Ground</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow4_col2" class="data row4 col2" >Fire</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow4_col3" class="data row4 col3" >770</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow5_col0" class="data row5 col0" >Primal Kyogre</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow5_col1" class="data row5 col1" >Water</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow5_col2" class="data row5 col2" >None</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow5_col3" class="data row5 col3" >770</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow6_col0" class="data row6 col0" >Zacian Crowned Sword</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow6_col1" class="data row6 col1" >Fairy</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow6_col2" class="data row6 col2" >Steel</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow6_col3" class="data row6 col3" >720</td>
#     </tr>    <tr>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow7_col0" class="data row7 col0" >Zamazenta Crowned Shield</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow7_col1" class="data row7 col1" >Fighting</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow7_col2" class="data row7 col2" >Steel</td>
#         <td id="T_e86c899c_b19a_11eb_8e04_94659cbb63cbrow7_col3" class=

# %%
# function that assigns color based on string value in dataframe
def color_type(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: green'` for positive
    strings, black otherwise.
    """
    if val == 'Fire':
        background_color = '#F08030'
    elif val == 'Water':
        background_color = 'Blue'
    elif val == 'Electric':
        background_color = 'Yellow'
    elif val == 'Poison':
        background_color = 'Purple'
    elif val == 'Fairy':
        background_color = 'Pink'
    elif val == 'Grass':
        background_color = 'Green'
    elif val == 'Ice':
        background_color = 'Lightblue'
    elif val == 'Steel':
        background_color = 'Grey'
    elif val == 'Ground':
        background_color = '#E0C068'
    elif val == 'Psychic':
        background_color = '#FF17D8'
    elif val == 'Dragon':
        background_color = '#7038F8'
    elif val == 'Fighting':
        background_color = '#C03028'
    elif val == 'Flying':
        background_color = '#A890F0'
    elif val == 'Ghost':
        background_color = '#705898'
    elif val == 'Bug':
        background_color = '#A8B820'
    elif val == 'Dark':
        background_color = '#705848'
    elif val == 'Normal':
        background_color = '#A8A878'
    elif val == 'Rock':
        background_color = '#B8A038'
    else:
        background_color = 'White'
    return 'background-color: %s' % background_color
  
base_stat_by_type_df.style.applymap(color_type)\
                 .hide_index()\
# Out:
# <style  type="text/css" >
#     #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow0_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow0_col1 {
#             background-color:  Purple;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow0_col2 {
#             background-color:  #7038F8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow0_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow1_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow1_col1 {
#             background-color:  #7038F8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow1_col2 {
#             background-color:  #A890F0;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow1_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow2_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow2_col1 {
#             background-color:  #FF17D8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow2_col2 {
#             background-color:  #C03028;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow2_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow3_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow3_col1 {
#             background-color:  #FF17D8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow3_col2 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow3_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow4_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow4_col1 {
#             background-color:  #E0C068;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow4_col2 {
#             background-color:  #F08030;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow4_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow5_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow5_col1 {
#             background-color:  Blue;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow5_col2 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow5_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow6_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow6_col1 {
#             background-color:  Pink;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow6_col2 {
#             background-color:  Grey;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow6_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow7_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow7_col1 {
#             background-color:  #C03028;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow7_col2 {
#             background-color:  Grey;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow7_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow8_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow8_col1 {
#             background-color:  #A8A878;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow8_col2 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow8_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow9_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow9_col1 {
#             background-color:  #B8A038;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow9_col2 {
#             background-color:  Pink;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow9_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow10_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow10_col1 {
#             background-color:  #B8A038;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow10_col2 {
#             background-color:  #705848;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow10_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow11_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow11_col1 {
#             background-color:  Grey;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow11_col2 {
#             background-color:  #FF17D8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow11_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow12_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow12_col1 {
#             background-color:  #705848;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow12_col2 {
#             background-color:  #A890F0;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow12_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow13_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow13_col1 {
#             background-color:  #F08030;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow13_col2 {
#             background-color:  #A890F0;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow13_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow14_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow14_col1 {
#             background-color:  #705898;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow14_col2 {
#             background-color:  #7038F8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow14_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow15_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow15_col1 {
#             background-color:  #705898;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow15_col2 {
#             background-color:  #7038F8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow15_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow16_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow16_col1 {
#             background-color:  Green;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow16_col2 {
#             background-color:  #7038F8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow16_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow17_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow17_col1 {
#             background-color:  Yellow;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow17_col2 {
#             background-color:  #7038F8;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow17_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow18_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow18_col1 {
#             background-color:  #A8B820;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow18_col2 {
#             background-color:  Grey;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow18_col3 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cbb63cbrow19_col0 {
#             background-color:  White;
#         }    #T_7cfac45e_b19d_11eb_8db3_94659cb

# %% [markdown]
# # Get highest base stat total by type EXCLUDING legendaries

# %%
connection = create_db_connection("localhost", "root", pw, db) # Connect to the Database

q20 = """SELECT p1.name, p1.type_1, p1.type_2, p1.total_points
FROM pokemon p1
INNER JOIN
(
    SELECT name, type_1, MAX(total_points) AS max_stats
    FROM pokemon
    WHERE status = 'Normal'
    GROUP BY type_1
) p2
    ON p1.type_1 = p2.type_1 AND p1.total_points = p2.max_stats AND status = 'Normal'
    
ORDER BY p1.total_points DESC, type_1
;"""
    
#fetchall method (used by read_query) returns a list of tuples
base_stat_non_legend_data = read_query(connection, q20)
display(base_stat_non_legend_data)
# Out:
# MySQL Database connection successful
# [('Mega Salamence', 'Dragon', 'Flying', 700),
#  ('Mega Garchomp', 'Dragon', 'Ground', 700),
#  ('Mega Tyranitar', 'Rock', 'Dark', 700),
#  ('Mega Metagross', 'Steel', 'Psychic', 700),
#  ('Slaking', 'Normal', None, 670),
#  ('Mega Gyarados', 'Water', 'Dark', 640),
#  ('Ash-Greninja', 'Water', 'Dark', 640),
#  ('Mega Charizard X', 'Fire', 'Dragon', 634),
#  ('Mega Charizard Y', 'Fire', 'Flying', 634),
#  ('Mega Sceptile', 'Grass', 'Dragon', 630),
#  ('Mega Lucario', 'Fighting', 'Steel', 625),
#  ('Mega Gardevoir', 'Psychic', 'Fairy', 618),
#  ('Mega Gallade', 'Psychic', 'Fighting', 618),
#  ('Mega Ampharos', 'Electric', 'Dragon', 610),
#  ('Mega Pinsir', 'Bug', 'Flying', 600),
#  ('Mega Scizor', 'Bug', 'Steel', 600),
#  ('Mega Heracross', 'Bug', 'Fighting', 600),
#  ('Mega Houndoom', 'Dark', 'Fire', 600),
#  ('Hydreigon', 'Dark', 'Dragon', 600),
#  ('Mega Gengar', 'Ghost', 'Poison', 600),
#  ('Mega Glalie', 'Ice', None, 580),
#  ('Florges', 'Fairy', None, 552),
#  ('Noivern', 'Flying', 'Dragon', 535),
#  ('Rhyperior', 'Ground', 'Rock', 535),
#  ('Crobat', 'Poison', 'Flying', 535)]

# %%
# create DataFrame using data
base_stat_non_legend_df = pd.DataFrame(base_stat_non_legend_data, columns =['Pokemon', 'Type 1', 'Type 2', 'Base Stat Total'])
  
base_stat_non_legend_df.style.applymap(color_type)\
                 .hide_index()\
# Out:
# <style  type="text/css" >
#     #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow0_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow0_col1 {
#             background-color:  #7038F8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow0_col2 {
#             background-color:  #A890F0;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow0_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow1_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow1_col1 {
#             background-color:  #7038F8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow1_col2 {
#             background-color:  #E0C068;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow1_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow2_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow2_col1 {
#             background-color:  #B8A038;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow2_col2 {
#             background-color:  #705848;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow2_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow3_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow3_col1 {
#             background-color:  Grey;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow3_col2 {
#             background-color:  #FF17D8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow3_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow4_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow4_col1 {
#             background-color:  #A8A878;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow4_col2 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow4_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow5_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow5_col1 {
#             background-color:  Blue;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow5_col2 {
#             background-color:  #705848;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow5_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow6_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow6_col1 {
#             background-color:  Blue;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow6_col2 {
#             background-color:  #705848;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow6_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow7_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow7_col1 {
#             background-color:  Red;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow7_col2 {
#             background-color:  #7038F8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow7_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow8_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow8_col1 {
#             background-color:  Red;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow8_col2 {
#             background-color:  #A890F0;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow8_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow9_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow9_col1 {
#             background-color:  Green;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow9_col2 {
#             background-color:  #7038F8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow9_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow10_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow10_col1 {
#             background-color:  #C03028;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow10_col2 {
#             background-color:  Grey;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow10_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow11_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow11_col1 {
#             background-color:  #FF17D8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow11_col2 {
#             background-color:  Pink;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow11_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow12_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow12_col1 {
#             background-color:  #FF17D8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow12_col2 {
#             background-color:  #C03028;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow12_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow13_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow13_col1 {
#             background-color:  Yellow;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow13_col2 {
#             background-color:  #7038F8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow13_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow14_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow14_col1 {
#             background-color:  #A8B820;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow14_col2 {
#             background-color:  #A890F0;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow14_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow15_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow15_col1 {
#             background-color:  #A8B820;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow15_col2 {
#             background-color:  Grey;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow15_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow16_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow16_col1 {
#             background-color:  #A8B820;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow16_col2 {
#             background-color:  #C03028;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow16_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow17_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow17_col1 {
#             background-color:  #705848;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow17_col2 {
#             background-color:  Red;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow17_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow18_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow18_col1 {
#             background-color:  #705848;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow18_col2 {
#             background-color:  #7038F8;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow18_col3 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63cbrow19_col0 {
#             background-color:  White;
#         }    #T_6c435d10_b19c_11eb_ba34_94659cbb63c
